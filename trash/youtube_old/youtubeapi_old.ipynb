# %%
import urllib.request
import json
import urllib
from googleapiclient.discovery import build

# %%
videoID = "XZJc1p6RE78" #Id de la vidéo à connaitre

#Request parameters
params = {"format": "json", "url": "https://www.youtube.com/watch?v=%s" % videoID}
url = "https://www.youtube.com/oembed"
query_string = urllib.parse.urlencode(params)
url = url + "?" + query_string

# %%
with urllib.request.urlopen(url) as response:
    response_text = response.read()
    data = json.loads(response_text.decode())
    print(data['title'])
    print(data['author_name'])

# %%
api_key = 'AIzaSyAXqXQDwF_SDj_Ce1KT5F9OlpdbM8WvB2o'
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
VideoID = "XZJc1p6RE78" #Id du vidéo à connaitre

params = {"format": "json", "url": "https://www.youtube.com/watch?v=%s" % VideoID}
url = "https://www.youtube.com/oembed"
query_string = urllib.parse.urlencode(params)
url = url + "?" + query_string

# %%
api_key = 'AIzaSyAXqXQDwF_SDj_Ce1KT5F9OlpdbM8WvB2o'
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
list_videos_id = []
for i in range(result_video_length):
    list_videos_id.append(response['items'][i]['id']['videoId'])

print(list_videos_id)
# Out:
# ['jPhJbKBuNnA', 'JTxsNm9IdYU', '7uljoeHgN4g', 'sTeoEFzVNSc', 'rSCNW1OCk_M', 'WPBWIcprLxc', 'iWhlrkfJrCQ', 'WizoCwjEKsg', 'K7z0jlE61IM', 'wnNp-zT3JmY', 'AXn2XVLf7d0', 'pOmpqdlVCoo', 'MIdv9ku1TfU', 'ey1kHYVu19c', 'RCBZ-Xj2dgQ', 'YNEb3EK4rNY', 'kQPUWryXwag', 'CtNsdVtQsf0', 'lGSGTrn5INA', '-WSQEyT2Mu0', 'Fw5ybNwwSbg', '40Kp_fa8vIw', '5MYJtKx-ebE', 'Hrv4UP3wBRg', 'o5MutYFWsM8']

# %%
print(response_comments['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨‍💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.

# %%
print(response_comments['items'][1])
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'g-tUUT6iBx1CqqAiKsFkY0CFbRI', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'L_U3CQypLa2r9_ypFLFVWUQuDx8', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '“I&#39;ve come up with a set of rules that describe our reactions to technologies:<br>1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.<br>2. Anything that&#39;s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.<br>3. Anything invented after you&#39;re thirty-five is against the natural order of things.”<br><br>- Douglas Adams', 'textOriginal': "“I've come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that's invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you're thirty-five is against the natural order of things.”\n\n- Douglas Adams", 'authorDisplayName': 'SmallAdvantages ', 'authorProfileImageUrl': 'https://yt3.ggpht.com/JM58K3s0lYuoNryWm9twIvO2v6peYhx8aouIjJ7Yj1eof6uIFGtslYDXoY1GDUGSYd_l6KlIDw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCskEPRzGlsYHs_a5SJyCXag', 'authorChannelId': {'value': 'UCskEPRzGlsYHs_a5SJyCXag'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 8807, 'publishedAt': '2023-02-19T07:16:30Z', 'updatedAt': '2023-02-19T07:16:30Z'}}, 'canReply': True, 'totalReplyCount': 192, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'HjPCPww6dFbNf77PE_KXpN0mAAM', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mkvgDYBGKb', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '@Thinking <br>Thinking &amp; rgemail <br>                = <br>   dumb &amp; dumber', 'textOriginal': '@Thinking \nThinking & rgemail \n                = \n   dumb & dumber', 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': 'medrano m', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaqqJXotmrcSAW72CLCAyD4Ssh3sx0OAahynT1=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCFA1QBOHtR87_h7MXXHWp7w', 'authorChannelId': {'value': 'UCFA1QBOHtR87_h7MXXHWp7w'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-02T13:13:17Z', 'updatedAt': '2023-03-02T13:13:17Z'}}, {'kind': 'youtube#comment', 'etag': 'uB1IlZ9KAlRsWf94c5ImM1hLOoM', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mjUU1QWULH', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '@Pat The Batman Fan you too buddy.', 'textOriginal': '@Pat The Batman Fan you too buddy.', 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': '88RangeRoverClassic', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJURfzeWgdBuba8iBd6iGSXDXiGMBw_S8Cr57Q=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCeTh7gC13gzC8A92kXd640g', 'authorChannelId': {'value': 'UCeTh7gC13gzC8A92kXd640g'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-01T23:47:34Z', 'updatedAt': '2023-03-01T23:47:34Z'}}, {'kind': 'youtube#comment', 'etag': 'aamjugOytW9BFtiMpcSepErULIw', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mhOovoEjKP', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'textOriginal': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': 'Rob Stoltz', 'authorProfileImageUrl': 'https:/ ...

# %% [markdown]
# Replies

# %%
print(response_comments['items'][0]['replies']['comments'][1]['snippet']['textOriginal'])
# Out:
# Nord sells Data.....

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']
# Out:
# {'videoId': 'jPhJbKBuNnA',
#  'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#  'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#  'authorDisplayName': 'Tom Scott',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/channel/UCBa659QWEk1AI4Tg--mrJ2A',
#  'authorChannelId': {'value': 'UCBa659QWEk1AI4Tg--mrJ2A'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 8963,
#  'publishedAt': '2023-02-08T05:47:56Z',
#  'updatedAt': '2023-02-08T05:47:56Z'}

# %%
import json

# Define a dictionary
my_dict = response_comments['items'][0]['snippet']['topLevelComment']['snippet']

# Open a file for writing
with open('testYoutube.json', 'w') as f:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(my_dict, f)

# %%
response_comments
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Y4-cyYTyrKrik9SptJHkx8LbZHA',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Vzrx8AirO_wTzchkGUm1icrbde4',
#    'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'g4msMgdM6EdTQ3uvNJJDsUmBdu0',
#      'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#       'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#       'authorDisplayName': 'Tom Scott',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCBa659QWEk1AI4Tg--mrJ2A',
#       'authorChannelId': {'value': 'UCBa659QWEk1AI4Tg--mrJ2A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8963,
#       'publishedAt': '2023-02-08T05:47:56Z',
#       'updatedAt': '2023-02-08T05:47:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 223,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'ZZAhAQExTlVJM-f5BNJzCHHUXMM',
#       'id': 'UgyxI2ZLYhdwdGVcde54AaABAg.9lrUEAw9OZq9mfpD8rISR5',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Timo Pint All of the VPN providers sell your data.',
#        'textOriginal': '@Timo Pint All of the VPN providers sell your data.',
#        'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#        'authorDisplayName': 'Alberta Wheat',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/Q809zhuv1HIDoY7FvWwxVAn9qSfMXs9iAN9UTR6kugKJmlkZSkDYQx8wRYAk2Hr1BhBPlwKr=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCoEFFOsmzcKLMUQdssHu7Wg',
#        'authorChannelId': {'value': 'UCoEFFOsmzcKLMUQdssHu7Wg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T13:40:33Z',
#        'updatedAt': '2023-02-28T13:40:33Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Ua0pXLc0ykY1EP3BsgMskZWloEI',
#       'id': 'UgyxI2ZLYhdwdGVcde54AaABAg.9lrUEAw9OZq9mfjlLBhvjk',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Nord sells Data.....',
#        'textOriginal': 'Nord sells Data.....',
#        'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#        'authorDisplayName': 'Timo Pint',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX4v6VfuwcEdI8yxkFdIbtVw82yVoFfcM-9bA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCKvMTb60Hs6QIyWbcs_iccg',
#        'authorChannelId': {'value': 'UCKvMTb60Hs6QIyWbcs_iccg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T12:52:55Z',
#        'updatedAt': '2023-02-28T12:52:55Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '81qizBVhWayq0e20vGxfXZZ9_Ak',
#       'id': 'UgyxI2ZLYhdwdGVcde54AaABAg.9lrUEAw9OZq9mde7Ozb0e6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Amaris Frede He never said he didn&#39;t like VPN&#39;s, he would just never lie about what a VPN did for the consumer',
#        'textOriginal': "@Amaris Frede He never said he didn't like VPN's, he would just never lie about what a VPN did for the consumer",
#        'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#        'authorDisplayName': 'Mads_Miskat',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUh7XBYJ8kpWg5aOCRYM8bK_Y9I3-g7RtauL1Z8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCJi43Wzn88yqU0fEO6NOfsQ',
#        'authorChannelId': {'value': 'UCJi43Wzn88yqU0fEO6NOfsQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T17:25:09Z',
#        'updatedAt': '2023-02-27T17:25:09Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'boPFeTUoZQsUxl4wesv8skFvrow',
#       'id': 'UgyxI2ZLYhdwdGVcde54AaABAg.9lrUEAw9OZq9mbP3o7k_B_',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'This is just the beginning. Everything is about to change. And much faster than anyone&#39;s prepared for.',
#        'textOriginal': "This is just the beginning. Everything is about to change. And much faster than anyone's prepared for.",
#        'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#        'authorDisplayName': 'Александр Гончаренко',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVWFSSKokrXfWpruRuuRlaLKwZqPFIkPMbR0G-UuZU=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCIguJsyh48EmY5_mZ3dPuMw',
#        'authorChannelId': {'value': 'UCIguJsyh48EmY5_mZ3dPuMw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-26T20:26:23Z',
#        'updatedAt': '2023-02-26T20:26:23Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'l91d3nU1FYYU8xDLkGi3_JFET4E',
#       'id': 'UgyxI2ZLYhdwdGVcde54AaABAg.9lrUEAw9OZq9mXgKJ-k3hC',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'VPN&#39;s aren&#39;t fooling the NSA...Nice bit of security illusion though.',
#        'textOriginal': "VPN's aren't fooling the NSA...Nice bit of security illusion though.",
#        'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#        'authorDisplayName': 'Alberta Wheat',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/Q809zhuv1HIDoY7FvWwxVAn9qSfMXs9iAN9UTR6kugKJmlkZSkDYQx8wRYAk2Hr1BhBPlwKr=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCoEFFOsmzcKLMUQdssHu7Wg',
#        'authorChannelId': {'value': 'UCoEFFOsmzcKLMUQdssHu7Wg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-25T00:29:43Z',
#        'updatedAt': '2023-02-25T00:29:43Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'g-tUUT6iBx1CqqAiKsFkY0CFbRI',
#    'id': 'UgyFk62AH8GwgbDPFK54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'L_U3CQypLa2r9_ypFLFVWUQuDx8',
#      'id': 'UgyFk62AH8GwgbDPFK54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': '“I&#39;ve come up with a set of rules that describe our reactions to technologies:<br>1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.<br>2. Anything that&#39;s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.<br>3. Anything invented after you&#39;re thirty-five is against the natural order of things.”<br><br>- Douglas Adams',
#       'textOriginal': "“I've come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that's invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you're thirty-five is against the natural order of things.”\n\n- Douglas Adams",
#       'authorDisplayName': 'SmallAdvantages ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/JM58K3s0lYuoNryWm9twIvO2v6peYhx8aouIjJ7Yj1eof6uIFGtslYDXoY1GDUGSYd_l6KlIDw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCskEPRzGlsYHs_a5SJyCXag',
#       'authorChannelId': {'value': 'UCskEPRzGlsYHs_a5SJyCXag'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8807,
#       'publishedAt': '2023-02-19T07:16:30Z',
#       'updatedAt': '2023-02-19T07:16:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 192,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'HjPCPww6dFbNf77PE_KXpN0mAAM',
#       'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mkvgDYBGKb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Thinking <br>Thinking &amp; rgemail <br>                = <br>   dumb &amp; dumber',
#        'textOriginal': '@Thinking \nThinking & rgemail \n                = \n   dumb & dumber',
#        'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg',
#        'authorDisplayName': 'medrano m',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaqqJXotmrcSAW72CLCAyD4Ssh3sx0OAahynT1=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCFA1QBOHtR87_h7MXXHWp7w',
#        'authorChannelId': {'value': 'UCFA1QBOHtR87_h7MXXHWp7w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T13:13:17Z',
#        'updatedAt': '2023-03-02T13:13:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uB1IlZ9KAlRsWf94c5ImM1hLOoM',
#       'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mjUU1QWULH',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Pat The Batman Fan you too buddy.',
#        'textOriginal': '@Pat The Batman Fan you too buddy.',
#        'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg',
#        'authorDisplayName': '88RangeRoverClassic',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJURfzeWgdBuba8iBd6iGSXDXiGMBw_S8Cr57Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCeTh7gC13gzC8A92kXd640g',
#        'authorChannelId': {'value': 'UCeTh7gC13gzC8A92kXd640g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T23:47:34Z',
#        'updatedAt': '2023-03-01T23:47:34Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'aamjugOytW9BFtiMpcSepErULIw',
#       'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mhOovoEjKP',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.',
#        'textOriginal': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.',
#        'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg',
#        'authorDisplayName': 'Rob Stoltz',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUYgsHes4k6uR0zb7erqPLQ5EH_t7ZFuK5IGA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC2X0D-R5-ISF06kTPqPwTuA',
#        'authorChannelId': {'value': 'UC2X0D-R5-ISF06kTPqPwTuA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T04:19:39Z',
#        'updatedAt': '2023-03-01T04:19:39Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Z98D3WIPp_UNLlXVnykJhiEKcls',
#       'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mdUNz3abFC',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@seededsoul he’s 39',
#        'textOriginal': '@seededsoul he’s 39',
#        'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg',
#        'authorDisplayName': 'Sri Ram Saravana',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV4_4Qneo89MkDoEZ-ngfl5ekOM33gdkNzatSGiGg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCUIlAfZdwMPpoAyGljjlkLg',
#        'authorChannelId': {'value': 'UCUIlAfZdwMPpoAyGljjlkLg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T15:51:18Z',
#        'updatedAt': '2023-02-27T15:51:18Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '6T-E4HYFnBY7uXmLw0qsqNh5Y4M',
#       'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mcySrHL99C',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'No. When you&#39;re 35, you&#39;re mature enough to see how wrong things are.',
#        'textOriginal': "No. When you're 35, you're mature enough to see how wrong things are.",
#        'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg',
#        'authorDisplayName': 'Fractal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/d3BgJp9beGrNXh05gT3jlKuKoKvS3ABPjKoZtVFmnPUMNiHRDYvRyVLdULh42lkDhciC_2z3jw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCBwgqpCCJSQEsDpDXA5lZ1A',
#        'authorChannelId': {'value': 'UCBwgqpCCJSQEsDpDXA5lZ1A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T11:03:37Z',
#        'updatedAt': '2023-02-27T11:03:37Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'lgVj7nv08_n5BnYCsgZKgaHTvLc',
#    'id': 'UgxGGDU-796qT6j-ipp4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SgveL1al5Ndpssf7tVnllZWOHhU',
#      'id': 'UgxGGDU-796qT6j-ipp4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I was genuinely expecting and terrified that the end of this video would be Tom confessing that the entire script was written by ChatGPT',
#       'textOriginal': 'I was genuinely expecting and terrified that the end of this video would be Tom confessing that the entire script was written by ChatGPT',
#       'authorDisplayName': 'SkyKnight34',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVlwyQ-QdCr7H_vk0TA23Rt2JNjRfjFMETqXsmS=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCK7tlnWujz3ZAV1phBOT5Pg',
#       'authorChannelId': {'value': 'UCK7tlnWujz3ZAV1phBOT5Pg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1106,
#       'publishedAt': '2023-02-23T20:36:15Z',
#       'updatedAt': '2023-02-23T20:36:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 10,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'Uzxsuatjql0qdllVlLnjWTH8OPw',
#       'id': 'UgxGGDU-796qT6j-ipp4AaABAg.9mUgoSheAvd9midcJc3nkD',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@ritish Why is that perplexing?',
#        'textOriginal': '@ritish Why is that perplexing?',
#        'parentId': 'UgxGGDU-796qT6j-ipp4AaABAg',
#        'authorDisplayName': 'Darkzeroprojects',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXWzgIvXR5_OAcRGtKfHxust7jsQ1l-FRoKBX_6=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCAlgnYS4rhqGYvUHA-kHoWw',
#        'authorChannelId': {'value': 'UCAlgnYS4rhqGYvUHA-kHoWw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T15:56:59Z',
#        'updatedAt': '2023-03-01T15:56:59Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '6eAIXUwzp3GVABMspYyhuzSlDTA',
#       'id': 'UgxGGDU-796qT6j-ipp4AaABAg.9mUgoSheAvd9miOgp2Xo-C',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'No... but your entire script was. <b>cues the x-files music</b>',
#        'textOriginal': 'No... but your entire script was. *cues the x-files music*',
#        'parentId': 'UgxGGDU-796qT6j-ipp4AaABAg',
#        'authorDisplayName': '20xitysix',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWdAS-bOm4uC5MubV_hb2cmSI6zWaZWvUMK2Dml0q6I8Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCDWMzZ9yont-A82R5BlZNlg',
#        'authorChannelId': {'value': 'UCDWMzZ9yont-A82R5BlZNlg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T13:37:47Z',
#        'updatedAt': '2023-03-01T13:37:47Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '-n8Mx1m9Ckx5W_Pva4Wc7dyWtU4',
#       'id': 'UgxGGDU-796qT6j-ipp4AaABAg.9mUgoSheAvd9mbGpxpcrqO',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Michal Wiktorow <br><br>That&#39;s a very real… and terrifying thought.',
#        'textOriginal': "@Michal Wiktorow \n\nThat's a very real… and terrifying thought.",
#        'parentId': 'UgxGGDU-796qT6j-ipp4AaABAg',
#        'authorDisplayName': 'Ciara',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/LGf30lWR5KkY1gdIoWYQWDbuSSHbrr24WXFKf0mbDVGIbPysCkACjib3RI0hZ28ezvgbbbFhlA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCssDVhuVIc6SEKG_Un3T1gw',
#        'authorChannelId': {'value': 'UCssDVhuVIc6SEKG_Un3T1gw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T19:14:27Z',
#        'updatedAt': '2023-02-26T19:14:27Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ezstUvDNhDM_QRsMcBAdIBwBpNE',
#       'id': 'UgxGGDU-796qT6j-ipp4AaABAg.9mUgoSheAvd9map9lWju3i',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@ritish because normies think its skynet and really its just an interface intermediary making it so you can almost tell your computer to program itself',
#        'textOriginal': '@ritish because normies think its skynet and really its just an interface intermediary making it so you can almost tell your computer to program itself',
#        'parentId': 'UgxGGDU-796qT6j-ipp4AaABAg',
#        'authorDisplayName': 'James Cheddar',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWfoQRQYSYc4DCc8kMJ8TI_ART2pesNLpLlcrCsVjpvEvzsAcmBTKl37HGRT6tG=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCiTwmUpuJUiB1_mOyfvuIpA',
#        'authorChannelId': {'value': 'UCiTwmUpuJUiB1_mOyfvuIpA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-26T15:03:53Z',
#        'updatedAt': '2023-02-26T15:03:53Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'J_92VPPXFlfoefyLy4fNrdg0yxk',
#       'id': 'UgxGGDU-796qT6j-ipp4AaABAg.9mUgoSheAvd9m_pFxhZgsQ',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When you can’t tell, isn’t that enough proof?',
#        'textOriginal': 'When you can’t tell, isn’t that enough proof?',
#        'parentId': 'UgxGGDU-796qT6j-ipp4AaABAg',
#        'authorDisplayName': 'loverrlee',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/kE2soZWHhu632x8kzIxy_OOzmWGjMvo2pXIlpDw45_3-9s6tiv9QySh6qyhqecf6dGDYiHDWPg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3reUX46AqqZ5t8gKQRKjWw',
#        'authorChannelId': {'value': 'UC3reUX46AqqZ5t8gKQRKjWw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-02-26T05:45:29Z',
#        'updatedAt': '2023-02-26T05:45:29Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'y4GPa3B2mrvSJpYOl-oG4A9dCaM',
#    'id': 'UgwwOi76QT3WN6ioPi94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 's3_vrn-KA6KI4ULR4dUfM6s9RW4',
#      'id': 'UgwwOi76QT3WN6ioPi94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'This was a rollercoaster, from &quot;gmail&#39;s label system sucks&quot; to &quot;EVERYTHING IS GOING TO CHANGE&quot;',
#       'textOriginal': 'This was a rollercoaster, from "gmail\'s label system sucks" to "EVERYTHING IS GOING TO CHANGE"',
#       'authorDisplayName': 'Rogue8146',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWl89dZtUpWQW6tYN7Cbgj5p2ZlrA0vTaD_wN0GVYhW2gHWU51eoF-DSacDyWav=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCRP9-9EUS9tzL9N8fxVabfA',
#       'authorChannelId': {'value': 'UCRP9-9EUS9tzL9N8fxVabfA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 656,
#       'publishedAt': '2023-02-20T23:37:21Z',
#       'updatedAt': '2023-02-20T23:37:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 5,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'UIHQPBrp0fz_7t97wBAt7yb3MJI',
#       'id': 'UgwwOi76QT3WN6ioPi94AaABAg.9mNI9I64_b-9mX3g9NteGY',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '+',
#        'textOriginal': '+',
#        'parentId': 'UgwwOi76QT3WN6ioPi94AaABAg',
#        'authorDisplayName': 'cc',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUc0dL86V8t_ptIiw5nmM2dYrRwPRbdK5RaUmtCzw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCRGcTZouNdLDaOsHUlSL82g',
#        'authorChannelId': {'value': 'UCRGcTZouNdLDaOsHUlSL82g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-24T18:43:18Z',
#        'updatedAt': '2023-02-24T18:43:18Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'wa66u79qCsePL32EA3PN6WjlAJk',
#       'id': 'UgwwOi76QT3WN6ioPi94AaABAg.9mNI9I64_b-9mShhdCy_Ot',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@CryptoScam It wasn&#39;t an answer',
#        'textOriginal': "@CryptoScam It wasn't an answer",
#        'parentId': 'UgwwOi76QT3WN6ioPi94AaABAg',
#        'authorDisplayName': 'Rogue8146',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWl89dZtUpWQW6tYN7Cbgj5p2ZlrA0vTaD_wN0GVYhW2gHWU51eoF-DSacDyWav=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCRP9-9EUS9tzL9N8fxVabfA',
#        'authorChannelId': {'value': 'UCRP9-9EUS9tzL9N8fxVabfA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 14,
#        'publishedAt': '2023-02-23T02:05:34Z',
#        'updatedAt': '2023-02-23T02:05:34Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'cu_01xKqM8wot3r6vFNt2eUwi9E',
#       'id': 'UgwwOi76QT3WN6ioPi94AaABAg.9mNI9I64_b-9mSaFuRoLt_',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Who asked',
#        'textOriginal': 'Who asked',
#        'parentId': 'UgwwOi76QT3WN6ioPi94AaABAg',
#        'authorDisplayName': 'CryptoScam',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/k4c2Imx-lKvltKl7GVTFb32yfxpqjbVOpfuNxx_HNXDgkcZVV_KCZYAhGL_1zdg_B2qpGrnijNo=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCCXh_VMCg9b1IhrRvwoaPqQ',
#        'authorChannelId': {'value': 'UCCXh_VMCg9b1IhrRvwoaPqQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-23T01:00:29Z',
#        'updatedAt': '2023-02-23T01:00:29Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ZUAzw8nVJgk7x58WikXs8GXujYc',
#       'id': 'UgwwOi76QT3WN6ioPi94AaABAg.9mNI9I64_b-9mSXc2gB7M0',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Written &amp; Scripted Out of Hollywood/ Military Propaganda 🪖 101',
#        'textOriginal': 'Written & Scripted Out of Hollywood/ Military Propaganda 🪖 101',
#        'parentId': 'UgwwOi76QT3WN6ioPi94AaABAg',
#        'authorDisplayName': 'Create A. Googleaccount',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZ_JPg7xHQ_i7F8TXeiHyMpffOusPB_25fknHN1EXqlv1G2O5MPkWnvYBK4FBC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UChteANI-UpaQfvWDNOPDD-w',
#        'authorChannelId': {'value': 'UChteANI-UpaQfvWDNOPDD-w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-23T00:28:41Z',
#        'updatedAt': '2023-02-23T00:28:41Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uFAqq_mffJcAhJfVko8jqsJ5WGg',
#       'id': 'UgwwOi76QT3WN6ioPi94AaABAg.9mNI9I64_b-9mS7X-orHAm',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Good thing Tom&#39;s learned to at least stomach those',
#        'textOriginal': "Good thing Tom's learned to at least stomach those",
#        'parentId': 'UgwwOi76QT3WN6ioPi94AaABAg',
#        'authorDisplayName': 'ailaG',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVUW_bMH9Djeltft8QMzZLNvC4bD5cVriSqoZsm=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UChZXQU9lLnYn2Vi1IMNAMcw',
#        'authorChannelId': {'value': 'UChZXQU9lLnYn2Vi1IMNAMcw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2023-02-22T20:40:40Z',
#        'updatedAt': '2023-02-22T20:40:40Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4cqUtoWIpFa745vnrsFooYIaPa4',
#    'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Usq_jS8wNv4TrALVfYXUZ05BmCk',
#      'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': '“Surprise is just a fancy word for being wrong about what comes next.” That hit hard',
#       'textOriginal': '“Surprise is just a fancy word for being wrong about what comes next.” That hit hard',
#       'authorDisplayName': 'Brandon Miller',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUCh608Uz1eXV_eO4V9Xp7ytsASvIQbmRPX-bLuWw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOf6tUaLD39bn01wMZaTZPg',
#       'authorChannelId': {'value': 'UCOf6tUaLD39bn01wMZaTZPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 713,
#       'publishedAt': '2023-02-21T17:14:50Z',
#       'updatedAt': '2023-02-21T17:14:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 11,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'vFrKaos8ErM7Syx0kFxeNc2xCIo',
#       'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg.9mPBAVcc6kc9mbJfxAw1Tu',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Brandon MillerGlad people like you exist. Hope you&#39;re doing well!',
#        'textOriginal': "\u200b@Brandon MillerGlad people like you exist. Hope you're doing well!",
#        'parentId': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#        'authorDisplayName': 'Vishank',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWtgl1_2W3RqI9bgaS0a5TV1124tqTaVEB53vqNbw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCfKlz06qjO51_Klllkkf7XA',
#        'authorChannelId': {'value': 'UCfKlz06qjO51_Klllkkf7XA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-26T19:39:17Z',
#        'updatedAt': '2023-02-26T19:39:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'v_00mEfLtERWxAfMoeoL_odAsvo',
#       'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg.9mPBAVcc6kc9mZg1YJG9jl',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'That&#39;s how humour works...',
#        'textOriginal': "That's how humour works...",
#        'parentId': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#        'authorDisplayName': 'Dan Newton',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXRnAZUDBDBR0yN007ULl2Ty6eZnvnXFC_MHdG3HOThAjhUl2MnqOkfoWw-ZvvD=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3fXCnyny-caBo7iy_iZ33w',
#        'authorChannelId': {'value': 'UC3fXCnyny-caBo7iy_iZ33w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-25T19:05:38Z',
#        'updatedAt': '2023-02-25T19:05:38Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'WKY0zI8N9QHuHU4a2cbOs81TBbo',
#       'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg.9mPBAVcc6kc9mZeXvz5NrV',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Mika not surprise how a secret birthday, surprise for example of the jokes, You did’nt expect something then you laugh',
#        'textOriginal': '@Mika not surprise how a secret birthday, surprise for example of the jokes, You did’nt expect something then you laugh',
#        'parentId': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#        'authorDisplayName': 'The Sunset',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/461_Rj6yQtpZ8T-0iTl3fts0IBLazJI_n0-AZPdHyOlBUrTSEAiylIgccBLjyYkJ07ysNGgWfg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCzpliIK7zydcApWhn6Tel7g',
#        'authorChannelId': {'value': 'UCzpliIK7zydcApWhn6Tel7g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-25T18:52:35Z',
#        'updatedAt': '2023-02-25T18:52:35Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ZXmgRzJtc0M8x-G2UOh5lhCPZ2Y',
#       'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg.9mPBAVcc6kc9mZXCjo64aR',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Gringote that was a bit condescending. I’m not in a frat. Not sure why you’re so negative. I love you ❤️',
#        'textOriginal': '@Gringote that was a bit condescending. I’m not in a frat. Not sure why you’re so negative. I love you ❤️',
#        'parentId': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#        'authorDisplayName': 'Brandon Miller',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUCh608Uz1eXV_eO4V9Xp7ytsASvIQbmRPX-bLuWw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCOf6tUaLD39bn01wMZaTZPg',
#        'authorChannelId': {'value': 'UCOf6tUaLD39bn01wMZaTZPg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-25T17:39:47Z',
#        'updatedAt': '2023-02-25T17:39:47Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'DlnZ2pZBtF-hitChZ_MhWiL0ioU',
#       'id': 'Ugw5M4EYNB7ds8ufKE94AaABAg.9mPBAVcc6kc9mZDu5ZcsiU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'go tell all ur frat buddies that, i bet theyll be like &quot;whoa bro&quot;',
#        'textOriginal': 'go tell all ur frat buddies that, i bet theyll be like "whoa bro"',
#        'parentId': 'Ugw5M4EYNB7ds8ufKE94AaABAg',
#        'authorDisplayName': 'Gringote',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUdILzpLnw28pwoQmFP0CdvlXoan36t3QTD5mZkjvl1lfkVnuLtj2LiAa5SKAe8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnqpRnS9Az2F4cj7Fl_8prQ',
#        'authorChannelId': {'value': 'UCnqpRnS9Az2F4cj7Fl_8prQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-25T14:51:04Z',
#        'updatedAt': '2023-02-25T14:51:04Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JhI3mizcRwR4pk8O4DzCnKpuEXQ',
#    'id': 'UgzdaHa121A-SBZmziV4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'e5q1rb8GFyhhIGlbp_R1EsCi1Ms',
#      'id': 'UgzdaHa121A-SBZmziV4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'My aunt worked for AT&amp;T in the 80s.  I remember her talking about how in the future, everyone would have a cell phone.  I remember thinking that seemed strange.',
#       'textOriginal': 'My aunt worked for AT&T in the 80s.  I remember her talking about how in the future, everyone would have a cell phone.  I remember thinking that seemed strange.',
#       'authorDisplayName': 'Festyguy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Uust_NcI7qauKDSl9kLsnkNS6BkNIuMcOy-p8_x2UiLDHaAfw5L8-EoEj1iJ_pD_jT7Z7qVpQg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcM-vnGmAHfknb0iNJ22mmw',
#       'authorChannelId': {'value': 'UCcM-vnGmAHfknb0iNJ22mmw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 541,
#       'publishedAt': '2023-02-23T14:29:36Z',
#       'updatedAt': '2023-02-23T14:29:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'NUzMAMU52AsUyzpq2puC854QX7Y',
#       'id': 'UgzdaHa121A-SBZmziV4AaABAg.9mU1r4hkhvX9mXHJBzzkQI',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '<a href="about:invalid#zCSafez"></a> vowed to always have a land line! its been idk',
#        'textOriginal': ' vowed to always have a land line! its been idk',
#        'parentId': 'UgzdaHa121A-SBZmziV4AaABAg',
#        'authorDisplayName': 'Anthony Peters',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVHlvSLcVw8T10bdfNBJwmTXEVwSbAlzZzFw4E=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCa9eTcNAkTw7TffALV-WQGA',
#        'authorChannelId': {'value': 'UCa9eTcNAkTw7TffALV-WQGA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2023-02-24T20:42:22Z',
#        'updatedAt': '2023-02-24T20:42:22Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G5PtUg0JFW7is0Zlwy2XrRVRjW4',
#       'id': 'UgzdaHa121A-SBZmziV4AaABAg.9mU1r4hkhvX9mXBHooKQ2y',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'If you invested money in AT&amp;T stock back then, you would have 80x that now :P',
#        'textOriginal': 'If you invested money in AT&T stock back then, you would have 80x that now :P',
#        'parentId': 'UgzdaHa121A-SBZmziV4AaABAg',
#        'authorDisplayName': 'TTT',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUaeTuMt6BqBVVt9xGQDz67Mw06tfAjFbTnbDEU=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC9QSDrp4wkyMIfiPRBZzjMw',
#        'authorChannelId': {'value': 'UC9QSDrp4wkyMIfiPRBZzjMw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 25,
#        'publishedAt': '2023-02-24T19:49:45Z',
#        'updatedAt': '2023-02-24T19:49:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-Wuztk9hyHkg1-XEvdagxG5dH4A',
#    'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'h0cCKBidfUVNTwb9cGmPGWPrYwo',
#      'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It’s lowkey terrifying being in college trying to plan what I want to do not knowing the world I’m heading into',
#       'textOriginal': 'It’s lowkey terrifying being in college trying to plan what I want to do not knowing the world I’m heading into',
#       'authorDisplayName': 'BudreauxTheKid',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/YbNvZyb5oKu9nEt8rBKMIFMiWlq9sQU-Fa4JaM7EzdRhYAdiNyWXXl863hPHk-5PSqXMSWhd=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCAcuX0a3SPjY6R_PAkEdMdQ',
#       'authorChannelId': {'value': 'UCAcuX0a3SPjY6R_PAkEdMdQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 16029,
#       'publishedAt': '2023-02-13T21:46:05Z',
#       'updatedAt': '2023-02-13T21:46:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 315,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'bC5gOIb_5ThoYCQRNNtc0iYsDXI',
#       'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg.9m53rHEwFxc9mjKZZRy0NG',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Don&#39;t go to college',
#        'textOriginal': "Don't go to college",
#        'parentId': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#        'authorDisplayName': 'tom',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXVSpJPxXtlAnB0D3D4WdLFEONi96Rn9CGCig=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCKTVd7k_jNBM8a56oaruYOg',
#        'authorChannelId': {'value': 'UCKTVd7k_jNBM8a56oaruYOg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T22:20:57Z',
#        'updatedAt': '2023-03-01T22:20:57Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'VXZlcY0IshV9yaH_DdT6QvK7mQo',
#       'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg.9m53rHEwFxc9mgKXC0IDmb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I want to be a robot psychologist (asimov reference) and honestly I think it might happen!',
#        'textOriginal': 'I want to be a robot psychologist (asimov reference) and honestly I think it might happen!',
#        'parentId': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#        'authorDisplayName': 'Kristina Plays',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW_4hbzpc2V9_58fbQQykiOIj5gk0jdYVyvYO62rw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCGGory3YdrRUFImqNE3oPnw',
#        'authorChannelId': {'value': 'UCGGory3YdrRUFImqNE3oPnw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T18:22:54Z',
#        'updatedAt': '2023-02-28T18:22:54Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'YYizUDuEqSNLXY-j1SaAcogPBFo',
#       'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg.9m53rHEwFxc9mSD3KpSFkB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Abyssaljami think you’re probably in a good spot',
#        'textOriginal': '@Abyssaljami think you’re probably in a good spot',
#        'parentId': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#        'authorDisplayName': 'John Herbert',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVCH3yquHBYXfJ3-E57TaTkRFdyYYAeQvsuc3Y43Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCLiH3LSSxHM4wgRT6vHzgCQ',
#        'authorChannelId': {'value': 'UCLiH3LSSxHM4wgRT6vHzgCQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T21:29:03Z',
#        'updatedAt': '2023-02-22T21:29:03Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'HpbX9hBIYi9wHgAWAQiPLfkmyRM',
#       'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg.9m53rHEwFxc9mRzllhNi10',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Learn how to plant food, harvest and store water, build stuff, survival and camping, fishing, hunting skills. Real Life Skills will serve you well in addition to your piece of paper. (or digital copy)',
#        'textOriginal': 'Learn how to plant food, harvest and store water, build stuff, survival and camping, fishing, hunting skills. Real Life Skills will serve you well in addition to your piece of paper. (or digital copy)',
#        'parentId': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#        'authorDisplayName': 'itsalllies',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/zQC1s-AXDnFSeA7w9Id85VGIju99mEHZ5lnVhjbAt9C69jcFlDjcFo9mHRokYarXTnbGmMlZlNs=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCA9UTpaszdMI2-fyAtrtWmg',
#        'authorChannelId': {'value': 'UCA9UTpaszdMI2-fyAtrtWmg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T19:24:11Z',
#        'updatedAt': '2023-02-22T19:24:11Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'tQO9Hv82Bpf5-PyDBgvg0IKx2LE',
#       'id': 'UgxZmR-DNoWnGqlTp0x4AaABAg.9m53rHEwFxc9mRwkROQ-nm',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Go into accounting',
#        'textOriginal': 'Go into accounting',
#        'parentId': 'UgxZmR-DNoWnGqlTp0x4AaABAg',
#        'authorDisplayName': 'The Answer',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVGr3hk-Dswe0ziIULJzhEX7lVCVLSFIykt2w=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCC3VAmls48IIC0la5fblacg',
#        'authorChannelId': {'value': 'UCC3VAmls48IIC0la5fblacg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T18:57:47Z',
#        'updatedAt': '2023-02-22T18:57:47Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'pdBrc01ntPaWK7Mw4rqvnYmuFTw',
#    'id': 'UgzvnWKGApWFmSVNQ714AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'A6XTckytaZbBrpYftPxQhTrZT-E',
#      'id': 'UgzvnWKGApWFmSVNQ714AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I feel the same sense of dread. Like you, I try to convince myself that people won&#39;t be replaced but enhanced, but I&#39;m not so sure anymore. The people developing these models are not going to stop regardless of the consequences and I agree that no one knows or cares where this is going.',
#       'textOriginal': "I feel the same sense of dread. Like you, I try to convince myself that people won't be replaced but enhanced, but I'm not so sure anymore. The people developing these models are not going to stop regardless of the consequences and I agree that no one knows or cares where this is going.",
#       'authorDisplayName': 'JeffyB',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVCgnyiGqNzaLpE4AQsLbAYgws5xffjT87cdg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCeGNI3ZccHwN_nDYBhKMXAQ',
#       'authorChannelId': {'value': 'UCeGNI3ZccHwN_nDYBhKMXAQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 467,
#       'publishedAt': '2023-02-20T22:41:24Z',
#       'updatedAt': '2023-02-20T22:41:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 16,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'pRErwHrjyqv8o-1VRh6gy-zh20I',
#       'id': 'UgzvnWKGApWFmSVNQ714AaABAg.9mNBkXmOI5n9mf_wjMclQ9',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Das It explain why',
#        'textOriginal': '@Das It explain why',
#        'parentId': 'UgzvnWKGApWFmSVNQ714AaABAg',
#        'authorDisplayName': 'A H',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVoswmcUU3SiymrCva4Rw86rdqzvEVSEkSQJg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCbOZkC0E-_GlaYg5XMe9y9g',
#        'authorChannelId': {'value': 'UCbOZkC0E-_GlaYg5XMe9y9g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-28T11:27:06Z',
#        'updatedAt': '2023-02-28T11:27:06Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'MLA5FDFsm2NVDhl2QY1fFiNerWc',
#       'id': 'UgzvnWKGApWFmSVNQ714AaABAg.9mNBkXmOI5n9mewsJWQrnr',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@A H this is not the same',
#        'textOriginal': '@A H this is not the same',
#        'parentId': 'UgzvnWKGApWFmSVNQ714AaABAg',
#        'authorDisplayName': 'Das It',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWiuNEOeR69xH1OrtNTqMkDUedVAIEQGGZ51U22=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCFHP5gElxNWqvdWlI0n9jtw',
#        'authorChannelId': {'value': 'UCFHP5gElxNWqvdWlI0n9jtw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 5,
#        'publishedAt': '2023-02-28T05:28:14Z',
#        'updatedAt': '2023-02-28T05:28:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'IunrzW_MWKRLDdhYOCcSCsS8zc8',
#       'id': 'UgzvnWKGApWFmSVNQ714AaABAg.9mNBkXmOI5n9mdwHMXIMTX',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Das Itwe&#39;ve always had massive shifts in technology and economics and it never ended up causing massive unemployment....<br>Did the invention of a tractor stop the need for people to work on farms?<br>Did the invention of an excavator remove the need for construction workers?<br>No it didnt, it just shifted the labour around, we have more mechanics and operators but less labourers',
#        'textOriginal': "\u200b@Das Itwe've always had massive shifts in technology and economics and it never ended up causing massive unemployment....\nDid the invention of a tractor stop the need for people to work on farms?\nDid the invention of an excavator remove the need for construction workers?\nNo it didnt, it just shifted the labour around, we have more mechanics and operators but less labourers",
#        'parentId': 'UgzvnWKGApWFmSVNQ714AaABAg',
#        'authorDisplayName': 'A H',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVoswmcUU3SiymrCva4Rw86rdqzvEVSEkSQJg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCbOZkC0E-_GlaYg5XMe9y9g',
#        'authorChannelId': {'value': 'UCbOZkC0E-_GlaYg5XMe9y9g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-27T20:03:48Z',
#        'updatedAt': '2023-02-27T20:03:48Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'DbvFlS18e9o3TUpRLDbCSdHQ22A',
#       'id': 'UgzvnWKGApWFmSVNQ714AaABAg.9mNBkXmOI5n9mdBHeNXlID',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I had the same feeling. Things are going to change soon drastically, we&#39;re just at the beginning, LOTS of people will have no real use in the workplace (we can&#39;t all become programmers) and the current economic system we have will not work, it will be a major reform and I&#39;m not sure it will go down smoothly.',
#        'textOriginal': "I had the same feeling. Things are going to change soon drastically, we're just at the beginning, LOTS of people will have no real use in the workplace (we can't all become programmers) and the current economic system we have will not work, it will be a major reform and I'm not sure it will go down smoothly.",
#        'parentId': 'UgzvnWKGApWFmSVNQ714AaABAg',
#        'authorDisplayName': 'Das It',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWiuNEOeR69xH1OrtNTqMkDUedVAIEQGGZ51U22=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCFHP5gElxNWqvdWlI0n9jtw',
#        'authorChannelId': {'value': 'UCFHP5gElxNWqvdWlI0n9jtw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2023-02-27T13:04:25Z',
#        'updatedAt': '2023-02-27T13:04:25Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'D3hL819He2TIbshlOVK-IjTZ4Ws',
#       'id': 'UgzvnWKGApWFmSVNQ714AaABAg.9mNBkXmOI5n9maccp7TswR',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'The people developing these models are people who want to feel recognized, feel proud, get money. Most of them are men. The world has been ruled by mostly men for a long time. Those men always want more and more and more! They forget that:’just because you can, doesn’t mean you should.’ Men will be the destruction of the human kind. Hopefully other species won’t suffer too much because of us humans',
#        'textOriginal': 'The people developing these models are people who want to feel recognized, feel proud, get money. Most of them are men. The world has been ruled by mostly men for a long time. Those men always want more and more and more! They forget that:’just because you can, doesn’t mean you should.’ Men will be the destruction of the human kind. Hopefully other species won’t suffer too much because of us humans',
#        'parentId': 'UgzvnWKGApWFmSVNQ714AaABAg',
#        'authorDisplayName': 'Tifa Strife',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWLS9IiSA8ZBaJX_quQon8XFozlqduz_wpI6Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC4MkYUpNA0A_y1_MFwpPJbg',
#        'authorChannelId': {'value': 'UC4MkYUpNA0A_y1_MFwpPJbg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T13:14:23Z',
#        'updatedAt': '2023-02-26T13:14:23Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'rEudGA8LlCooNla62zH6xQMiRfk',
#    'id': 'UgxQM1UWIGlG79XGuhV4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'S0Qb1NrCsRTzrkpRsqbdiXEGuuI',
#      'id': 'UgxQM1UWIGlG79XGuhV4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'When you talk with ChatGPT, you are really conversing with the living embodiment of the entire internet.',
#       'textOriginal': 'When you talk with ChatGPT, you are really conversing with the living embodiment of the entire internet.',
#       'authorDisplayName': 'Ash Haldane',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVg-Fnvj8UWXhfSIR5WgMuHrL_H_QGwMp-9Vu1eAQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCDYfryG-A2tz74TutGqAvhA',
# ...
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Michael Grindstaff what happens if google starts to slowly distort reality.',
#        'textOriginal': '@Michael Grindstaff what happens if google starts to slowly distort reality.',
#        'parentId': 'UgxeD0A9Z0u7CXtklUp4AaABAg',
#        'authorDisplayName': 'Mika',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/wH4jU3A6VOTKE9g-snO5UGOrdblkfcH1JOjgepT1SzcwsApQRCza6TrLZVjV6SFHLD_GZ18CrA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCmTONSC-IAJBGuYm0cEDDBA',
#        'authorChannelId': {'value': 'UCmTONSC-IAJBGuYm0cEDDBA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-25T01:45:55Z',
#        'updatedAt': '2023-02-25T01:45:55Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nmEmltYtuTqwRN2yKS97t_MN3bI',
#    'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'w54JEHlr8dI7AsUpVbwvmeAzHoQ',
#      'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I&#39;m convinced that successfully growing old is about the ability to see so much change and not let it freak you out so much that you can&#39;t move forward with it (or even ahead of it).',
#       'textOriginal': "I'm convinced that successfully growing old is about the ability to see so much change and not let it freak you out so much that you can't move forward with it (or even ahead of it).",
#       'authorDisplayName': 'Linda B',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXVQd_ieTZ3REXM-dxEZ8PqehJh2RQ7t_DvUg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0Xvbv_cHNmriIq05ztFKZw',
#       'authorChannelId': {'value': 'UC0Xvbv_cHNmriIq05ztFKZw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 220,
#       'publishedAt': '2023-02-22T22:47:15Z',
#       'updatedAt': '2023-02-22T22:47:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 7,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'lGDFxtjndOp1FB9yCKghnpYl6u8',
#       'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg.9mSM04FRQ_C9mj_0kJKnG2',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Poshboy Then it’s a good thing that human lives are relatively short.',
#        'textOriginal': '@Poshboy Then it’s a good thing that human lives are relatively short.',
#        'parentId': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#        'authorDisplayName': 'catgrin',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXPBbhh5PwGPItFv7C1mfQlvyPKlpDbr0EIoA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCF70wYQlw_j1SqWN551fQXw',
#        'authorChannelId': {'value': 'UCF70wYQlw_j1SqWN551fQXw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-02T00:36:00Z',
#        'updatedAt': '2023-03-02T00:36:00Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'D-Q6bk1Fb1iL_6y49cN2sOJGizE',
#       'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg.9mSM04FRQ_C9mj7FP_OYBU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'You can&#39;t keep up and move forward  with everything forever.',
#        'textOriginal': "You can't keep up and move forward  with everything forever.",
#        'parentId': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#        'authorDisplayName': 'Poshboy',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWMqMBezXcGMtbqP9RaDv-MUKXxA_9iJr1YHQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCmxOgQ_rjuwpKQTfkiR__Jg',
#        'authorChannelId': {'value': 'UCmxOgQ_rjuwpKQTfkiR__Jg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T20:24:36Z',
#        'updatedAt': '2023-03-01T20:24:36Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'UCb_RuSaDm__hbT_VAfmL3qiUM8',
#       'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg.9mSM04FRQ_C9mgVEMUvBmH',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Timo Pint To them, there may be no change to see. We react badly to the introduction of new ideas which alter our “normal” lives. If they’re raised after that introduction, thry may only see the evolution of new tech. It’s far less shocking.<br><br>Also, “ignorance is bliss.” Younger people can be very intelligent and still lack the experience needed to build concerns from.',
#        'textOriginal': '@Timo Pint To them, there may be no change to see. We react badly to the introduction of new ideas which alter our “normal” lives. If they’re raised after that introduction, thry may only see the evolution of new tech. It’s far less shocking.\n\nAlso, “ignorance is bliss.” Younger people can be very intelligent and still lack the experience needed to build concerns from.',
#        'parentId': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#        'authorDisplayName': 'catgrin',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXPBbhh5PwGPItFv7C1mfQlvyPKlpDbr0EIoA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCF70wYQlw_j1SqWN551fQXw',
#        'authorChannelId': {'value': 'UCF70wYQlw_j1SqWN551fQXw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-28T19:56:27Z',
#        'updatedAt': '2023-02-28T19:56:27Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'pRVZwAK3UaKU0jKRHnTE9bWsVkg',
#       'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg.9mSM04FRQ_C9mfk95UVJ9G',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'young minds adopting faster and not even realising changes at all.',
#        'textOriginal': 'young minds adopting faster and not even realising changes at all.',
#        'parentId': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#        'authorDisplayName': 'Timo Pint',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX4v6VfuwcEdI8yxkFdIbtVw82yVoFfcM-9bA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCKvMTb60Hs6QIyWbcs_iccg',
#        'authorChannelId': {'value': 'UCKvMTb60Hs6QIyWbcs_iccg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-28T12:56:18Z',
#        'updatedAt': '2023-02-28T12:56:18Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'A7cMPhks1pJjjjERXKBskbF7wwU',
#       'id': 'UgxYvUHjy0EArvvN-Lx4AaABAg.9mSM04FRQ_C9mfg5LVgCa1',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Absolutely',
#        'textOriginal': 'Absolutely',
#        'parentId': 'UgxYvUHjy0EArvvN-Lx4AaABAg',
#        'authorDisplayName': 'Metageist',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWCtJRF72zB8Js1Ue-iVpwR8r2I4bXFl1ygG3Ro=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSwTrr1QvY_iG_5i3IJotEg',
#        'authorChannelId': {'value': 'UCSwTrr1QvY_iG_5i3IJotEg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T12:20:50Z',
#        'updatedAt': '2023-02-28T12:20:50Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'pPRINM6zXxC6JPF2Z8GWZIIIOOQ',
#    'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wpbfhpYqeOupSVA5w6IKi3L_vbQ',
#      'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'We&#39;re at the bottom of the uptake, Tom. Once ChatGPT releases, use and competitors will explode and we&#39;ll be going straight up that curve.',
#       'textOriginal': "We're at the bottom of the uptake, Tom. Once ChatGPT releases, use and competitors will explode and we'll be going straight up that curve.",
#       'authorDisplayName': 'Justin Basinger',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXbHmd24SjB0D0vMTGBJQRJuZ4oa51ZpgiggdhE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpa2JWXEcyVz6WFfGEcxRSQ',
#       'authorChannelId': {'value': 'UCpa2JWXEcyVz6WFfGEcxRSQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 247,
#       'publishedAt': '2023-02-21T16:18:41Z',
#       'updatedAt': '2023-02-21T16:18:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 9,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'yATbkSe6oit3geO0P1q-UQyxIfM',
#       'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg.9mP4kIlfSda9mieMhUSLx4',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@kungfurykeyboard the rest should just focus their own thing .<br>This is something I think we should take advantage of to compete.<br>Lot of those being replaced leaves more for alot of lesser or smaller businesses to hire.',
#        'textOriginal': '@kungfurykeyboard the rest should just focus their own thing .\nThis is something I think we should take advantage of to compete.\nLot of those being replaced leaves more for alot of lesser or smaller businesses to hire.',
#        'parentId': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#        'authorDisplayName': 'Darkzeroprojects',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXWzgIvXR5_OAcRGtKfHxust7jsQ1l-FRoKBX_6=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCAlgnYS4rhqGYvUHA-kHoWw',
#        'authorChannelId': {'value': 'UCAlgnYS4rhqGYvUHA-kHoWw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T16:03:27Z',
#        'updatedAt': '2023-03-01T16:03:27Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'YkqDuNgSwkbHiRF79iPC5V3ejWg',
#       'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg.9mP4kIlfSda9mbZV1O2bY6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Rex Stark perhaps photonic computing will take its place many experts seem to think that quantum computers won’t take over for complicated reasons, but I never hear about photonics strangely',
#        'textOriginal': '@Rex Stark perhaps photonic computing will take its place many experts seem to think that quantum computers won’t take over for complicated reasons, but I never hear about photonics strangely',
#        'parentId': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#        'authorDisplayName': 'turd blitzer',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXfZtjyFx-Gm7P6T90fzO1ZSt-ffL_SwJyG=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCL0h-1Um9e7rCRZpWi2e67Q',
#        'authorChannelId': {'value': 'UCL0h-1Um9e7rCRZpWi2e67Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T21:57:28Z',
#        'updatedAt': '2023-02-26T21:57:28Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '5y4BEZ2lNXsYLDKp_VsymSSVK2A',
#       'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg.9mP4kIlfSda9mVXbbdepEp',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'straight up? nah we&#39;re going straight down to hell when that happens',
#        'textOriginal': "straight up? nah we're going straight down to hell when that happens",
#        'parentId': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#        'authorDisplayName': 'Magnum',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJViHHRFDIK5aXl-oq8Q6beZbTotRf7yZBcYBaWk=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCuHhQGQey4Yd5_-y_WyzQ8Q',
#        'authorChannelId': {'value': 'UCuHhQGQey4Yd5_-y_WyzQ8Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-24T04:26:21Z',
#        'updatedAt': '2023-02-24T04:26:21Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'oRWjsLXAJh33xlr3BAMPvGm9awU',
#       'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg.9mP4kIlfSda9mUMtXU0SZ9',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@0reo2 True, but that was back in the time where Moore&#39;s law was still in full force. Processors two years apart were magnitudes more powerful than their predecessors. Now we&#39;re hitting component shrinking and heat barriers, and that increase is slowing down. So components 15 years from now won&#39;t be as many magnitudes more powerful compared to today, as our components today are compared to 15 years ago. The best we can hope for is software optimizations, or that we somehow stumble upon a completely different hardware architecture or discover a fantastic new material for making electronics.',
#        'textOriginal': "@0reo2 True, but that was back in the time where Moore's law was still in full force. Processors two years apart were magnitudes more powerful than their predecessors. Now we're hitting component shrinking and heat barriers, and that increase is slowing down. So components 15 years from now won't be as many magnitudes more powerful compared to today, as our components today are compared to 15 years ago. The best we can hope for is software optimizations, or that we somehow stumble upon a completely different hardware architecture or discover a fantastic new material for making electronics.",
#        'parentId': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#        'authorDisplayName': 'Rex Stark',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVFtqa7kvkwyp65kJV7GqEoHFcvlzsT6WnZK0-HCA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCz9zdQIvT2FocqkZtOfMWkA',
#        'authorChannelId': {'value': 'UCz9zdQIvT2FocqkZtOfMWkA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 21,
#        'publishedAt': '2023-02-23T17:33:26Z',
#        'updatedAt': '2023-02-23T17:33:26Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'P0Kd9VQ0B5W4TtV2kRUAVqRLlsQ',
#       'id': 'UgwCRJHGoTrrJ3GUlcp4AaABAg.9mP4kIlfSda9mTZKfYG-3e',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '&quot;we&quot;',
#        'textOriginal': '"we"',
#        'parentId': 'UgwCRJHGoTrrJ3GUlcp4AaABAg',
#        'authorDisplayName': 'staberind',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXQEG5lQX7mgmUbK61ozkD1A0iqhWVewykf1g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCXnV7q0XysiZ98D8husiTyA',
#        'authorChannelId': {'value': 'UCXnV7q0XysiZ98D8husiTyA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-23T10:02:54Z',
#        'updatedAt': '2023-02-23T10:02:54Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'QTsJPpW6kxS5NOIUiSthWtlONSo',
#    'id': 'UgybMHEDSnkZZO51lxp4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OuhcvQ6DZYByTb7og5zth5wSltc',
#      'id': 'UgybMHEDSnkZZO51lxp4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Personally, I&#39;m very excited to see where this goes. Some people may lose jobs, which is unfortunate. But that happens with every major advancement. Lost jobs will lead to entirety new jobs we don&#39;t yet have.',
#       'textOriginal': "Personally, I'm very excited to see where this goes. Some people may lose jobs, which is unfortunate. But that happens with every major advancement. Lost jobs will lead to entirety new jobs we don't yet have.",
#       'authorDisplayName': 'RED',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/vKnLulDYvDoUkKi_6loDhdlcgJsXulmMKdPlfP-OIk7wGCOzGu4A8ni_WUZuuhfAsts0atQC=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpVyxlvJ4rcx8W62C0SCHnQ',
#       'authorChannelId': {'value': 'UCpVyxlvJ4rcx8W62C0SCHnQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-02-28T12:56:36Z',
#       'updatedAt': '2023-02-28T12:56:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    pageToken="..."
    )
response_comments = request_comments.execute()

# %%
response_comments
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'O8943lIE8yFl1Uj4U_AXUhEnuGs',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'NYfWTxUgMuTWMV8MXF5pWo9WwNI',
#    'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'HddZGBNeLcgFn-j3MQKu92RDxQ4',
#      'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. <br>What scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. <br>We have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#       'textOriginal': 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#       'authorDisplayName': 'mikedbarkerhotmail',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXeT98b9sQSI00R49YYSt9S1H4DOPTyAyh9Dg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-rteK65rnTbM1ORE3KDNaw',
#       'authorChannelId': {'value': 'UC-rteK65rnTbM1ORE3KDNaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 6,
#       'publishedAt': '2023-02-26T06:49:08Z',
#       'updatedAt': '2023-02-26T06:49:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0wvF6tzvFZGPSJlVFwgnUmUTcMk',
#    'id': 'UgwXKDa8PdreepuhcOl4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OHHutum4vC1AY_-6j45aBEXFwBA',
#      'id': 'UgwXKDa8PdreepuhcOl4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'When a Tom Scott video is longer than 6 minutes you know gets going to be deep.',
#       'textOriginal': 'When a Tom Scott video is longer than 6 minutes you know gets going to be deep.',
#       'authorDisplayName': 'TheAngryOwl',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX6X0NHzGqXMbNnyk0goPkGtGGsbozbYxlzcQ0VCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgfgWtxpGrh46jZsoAInKlg',
#       'authorChannelId': {'value': 'UCgfgWtxpGrh46jZsoAInKlg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 21874,
#       'publishedAt': '2023-02-13T17:21:50Z',
#       'updatedAt': '2023-02-13T17:21:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 49,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'H0XoQquLeMk8KMNvdAt995cm8_0',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mkc_9m7ogz',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When i see a guy type geta onstead of its you know gets a illiterate person',
#        'textOriginal': 'When i see a guy type geta onstead of its you know gets a illiterate person',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'gmyxt555',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/IUL21_I2Hbd03BIjnm8xBfbo_qwuHCFe0zl5bKEUhWU4la196k3_SQ8uE7fyzpaphXquCTL0bg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSmj4Rg_v_vIAoLbDvXPWbQ',
#        'authorChannelId': {'value': 'UCSmj4Rg_v_vIAoLbDvXPWbQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T10:26:17Z',
#        'updatedAt': '2023-03-02T10:26:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'MNVjco_RCKieKIWkZbPsVJd8bSA',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mbweYSIapQ',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'This was deep? He&#39;s just saying what everyone else is saying. You could go snorkelling at this level.',
#        'textOriginal': "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'mentalmelt',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfANxyp9eKx7j05YUBZP8xJMqGqHhmbrmSe8MuHg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCw7Tf05hehRkX3XloSXA8hQ',
#        'authorChannelId': {'value': 'UCw7Tf05hehRkX3XloSXA8hQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T01:28:37Z',
#        'updatedAt': '2023-02-27T01:28:37Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '9qyC9T-g9dUEX5JUieMzcGcF9Hk',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19maE8Y1I3qv',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'and mo cap',
#        'textOriginal': 'and mo cap',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'Rocket Bunny',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaSdf2aIgwKGEIsiAaFCX5ar_ZKxUVCQhOVDQs9A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCHvKaQYlzBCseI5VFAp1scA',
#        'authorChannelId': {'value': 'UCHvKaQYlzBCseI5VFAp1scA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T09:31:40Z',
#        'updatedAt': '2023-02-26T09:31:40Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'qr2YrI4Pp5wsN9lAqevvau_s3Pg',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mW_Hvj4Su2',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Good try chatgpt - we know it&#39;s you',
#        'textOriginal': "Good try chatgpt - we know it's you",
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'Ean Nane',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVq_n6UgXrpyrrapv6ABBcNbzQd-fj-KfCS=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UChNSc4w5lI_7WuHbeQkEkWg',
#        'authorChannelId': {'value': 'UChNSc4w5lI_7WuHbeQkEkWg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-24T14:08:59Z',
#        'updatedAt': '2023-02-24T14:08:59Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'FxyNvzyr-Vk_YnA9WOgYHcd1ly4',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mSY_AMAZYH',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Utterly boring!',
#        'textOriginal': 'Utterly boring!',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'Derek Gilbert',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXcXEOYgIgtXX5ZtYL70zRfnGUyWJYFIIrNjiFamIFWt0vZYy0YW5jUUXGxarnq=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCxS_sTBI326Wz8NQOfYXDng',
#        'authorChannelId': {'value': 'UCxS_sTBI326Wz8NQOfYXDng'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-23T00:37:02Z',
#        'updatedAt': '2023-02-23T00:37:02Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PT1f_tZcSjH-pObetDVVXFsLQM0',
#    'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zock_xr0LU1dxlrztiDUrdk0UN8',
#      'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'textOriginal': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'authorDisplayName': 'Derek Woods',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXR6puczs1o9QoBYjEitYikAe1ovkGY0p_K5Az3ml8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChgSMVDswJwip74E_DZDSEg',
#       'authorChannelId': {'value': 'UChgSMVDswJwip74E_DZDSEg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 543,
#       'publishedAt': '2023-02-22T04:38:15Z',
#       'updatedAt': '2023-02-22T04:38:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 13,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'mTiUk7Ocw8MrpbXBU8TN_FmOZJY',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5b8BrO6S',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'textOriginal': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T14:48:42Z',
#        'updatedAt': '2023-03-02T14:48:42Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ApLMuFcnO27OfBSnKDwMhNkyS38',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5P86k_Yd',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m not actually sure about that. There&#39;s been a lot of sensationalism around this issue. I know someone who actually works <b>developing</b> this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.',
#        'textOriginal': "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T14:46:56Z',
#        'updatedAt': '2023-03-02T14:46:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '5Ho_u-v7e8tyxnaOeKt3GpKe7wk',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9mYJMHmjlgB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 You are also under the spell. Snap out of it.<br><br>it&#39;s programming. it predicts and responds as it is programmed to do. Nothing more.<br><br>It may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it&#39;s purpose is to gather data and grow that library), but in the end it&#39;s nothing more than programming. <br><br>The general public is a combination of uninterested and also under the spell.<br><br>The future is dark if enough people buy this BS as it&#39;s being advertised. The more people who buy it, the darker it is like to be.',
#        'textOriginal': "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'DRourk',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW7SABHTq6OgFqavy0M5hQbYPnl25U-n7vfEA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCL9mmOumcr-JtxtW6CzOakg',
#        'authorChannelId': {'value': 'UCL9mmOumcr-JtxtW6CzOakg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-25T06:19:31Z',
#        'updatedAt': '2023-02-25T06:19:31Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '9AhZfGAWWxo3ofhi0R3bN7i3-yQ',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9mXjYwlNJNn',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I was aslo thinking how could anyone possibly think that we are anywhere else but at the beginning. The general public (and that is the measure for me) hasn&#39;t even caught on, just a percent of more tech-savvy types.',
#        'textOriginal': "I was aslo thinking how could anyone possibly think that we are anywhere else but at the beginning. The general public (and that is the measure for me) hasn't even caught on, just a percent of more tech-savvy types.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'voidhawk79',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV6tVX-Pt5Gf4QZD_BNKlYPOCGpupTHXnhc-g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCudq4jpCbh2Eij9Gws8YqeQ',
#        'authorChannelId': {'value': 'UCudq4jpCbh2Eij9Gws8YqeQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 6,
#        'publishedAt': '2023-02-25T00:57:55Z',
#        'updatedAt': '2023-02-25T00:57:55Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'pnMW1zneehZJ7WW9d-fKTB20K1o',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9mVk7kvk2jj',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@MLT Ha!... I strike a nerve?',
#        'textOriginal': '\u200b@MLT Ha!... I strike a nerve?',
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'DRourk',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW7SABHTq6OgFqavy0M5hQbYPnl25U-n7vfEA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCL9mmOumcr-JtxtW6CzOakg',
#        'authorChannelId': {'value': 'UCL9mmOumcr-JtxtW6CzOakg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-24T06:24:28Z',
#        'updatedAt': '2023-02-24T06:24:28Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yRitSh3dBqhu7VwNNirIoKDyXjs',
#    'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'aoOOWR-Av2tvqICbUs8Zm18piz8',
#      'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I&#39;m shook. I asked it &quot;Write me an AutoHotkey script to adjust the volume with the arrow keys.&quot; Not only did it do that, but it also mapped a key to mute, which I wasn&#39;t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it&#39;s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'textOriginal': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'authorDisplayName': 'Osprey850glt',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUAC8KRCtcYqrnM4kMwsC9xuCs-jg_Fo7TYUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzDXZwQZHFdbyNZPTujX7qg',
#       'authorChannelId': {'value': 'UCzDXZwQZHFdbyNZPTujX7qg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 14,
#       'publishedAt': '2023-02-24T13:46:02Z',
#       'updatedAt': '2023-02-24T13:46:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'yd2HhRYTaHFSrLHHmf90x-MBJLA',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519mh7Q7bwzY_',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#        'textOriginal': 'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Pat',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUyotuhv_hKleS6qc2HxTGeirp8_4tn99WujhdyyQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCA5ln5Bl3_epk2qBIiwf8Vw',
#        'authorChannelId': {'value': 'UCA5ln5Bl3_epk2qBIiwf8Vw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T01:47:35Z',
#        'updatedAt': '2023-03-01T01:47:35Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'a0HhKYI7M0HLx6BM0CAymW5Aido',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519m_AZmzUxY3',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Dream come true for hackers?',
#        'textOriginal': 'Dream come true for hackers?',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'User_guy',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/XiAhFLhfgkqv-EoshWUZ7m_v7BJc3pkYpWQhLUJeo2zfyzRhf54Utpucs0kctmJGV2RPwBjr=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCOJ1PjK5GUmr4vEEKq2ralw',
#        'authorChannelId': {'value': 'UCOJ1PjK5GUmr4vEEKq2ralw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-25T23:41:11Z',
#        'updatedAt': '2023-02-25T23:41:11Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'fTivulGGhGyydyLMFDZ98Nriwdw',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519mZb_jLyKJV',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'It literally knows how to code in the strangest programming languages, which is really cool.',
#        'textOriginal': 'It literally knows how to code in the strangest programming languages, which is really cool.',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Stefan Maring',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaWwVhJd4b89I3FG-ZM2HxsImMum9ejkUFUbhMQg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCK8_AQWiU_fWkba7oYWInDg',
#        'authorChannelId': {'value': 'UCK8_AQWiU_fWkba7oYWInDg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-25T18:26:45Z',
#        'updatedAt': '2023-02-25T18:26:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VRrLCPgTEQPR761gs8TrJ0JFCwY',
#    'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NWjiD5E54xuBU0Syht8LUtWtc1g',
#      'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn&#39;t believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.',
#       'textOriginal': "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#       'authorDisplayName': 'doobyboy21',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/j6Li8CLYzmclgYoMQJed-gABKHu8fPzeHhAloLb5MsMuQVCJeGSVnYJoHdj6_o0PC14Fj_MAYg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCEbRckbxiCDm7PgBuvQq1hQ',
#       'authorChannelId': {'value': 'UCEbRckbxiCDm7PgBuvQq1hQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 56,
#       'publishedAt': '2023-02-22T14:08:19Z',
#       'updatedAt': '2023-02-22T14:08:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'S0AsQgtlzg2AGU_73tyjzpBhxWI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgFaF694HA',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I remember my elementary school&#39;s teacher workroom being as smoky as a pool hall',
#        'textOriginal': "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Nolan McKinney',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV-xoC7uaFWVo_TC7TJ7uzS6cInHa5DE6LYD5lAXw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCCbYhC1yPa-_r7nu1WzzGvA',
#        'authorChannelId': {'value': 'UCCbYhC1yPa-_r7nu1WzzGvA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T17:39:46Z',
#        'updatedAt': '2023-02-28T17:39:46Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jI3KEREhIV-0em0eAVQSmaCrFwo',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgB1ZmjsRb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David And once in a while some teacher came and chased away the under 16&#39;s who were caught smoking.',
#        'textOriginal': "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T16:59:56Z',
#        'updatedAt': '2023-02-28T16:59:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uE3837X4b6XAwBlJDQekU4O8xEI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mWdWdjj6sE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I laughed at that but then realized that so did we.',
#        'textOriginal': '@David I laughed at that but then realized that so did we.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Are',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUH6Dhs4uaLTzHDjjg9_5TnwLVL5e7RAPwXi97w=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCzssRp9ZfPhRvOp_jz_LIrg',
#        'authorChannelId': {'value': 'UCzssRp9ZfPhRvOp_jz_LIrg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2023-02-24T14:45:56Z',
#        'updatedAt': '2023-02-24T14:45:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uDYjqLu2L0cboAVMo6z2gxOOcqI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mUoQ_K55Kq',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When I was in high school they had a designated smoking area for the kids.',
#        'textOriginal': 'When I was in high school they had a designated smoking area for the kids.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'David',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXMjfel-oX_0QuvNkpLLAP-V9EVxAeo3blkOJDSsA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC4iF04W04tbSZwwsTc2kMsg',
#        'authorChannelId': {'value': 'UC4iF04W04tbSZwwsTc2kMsg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 11,
#        'publishedAt': '2023-02-23T21:42:45Z',
#        'updatedAt': '2023-02-23T21:42:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'eL7sGvF0BjbXXWoa1yw_cACCTvE',
#    'id': 'Ugwel4ZETQqO4tJAWz54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YAHONnk0FZpJcsgIW_9NisnSZfE',
#      'id': 'Ugwel4ZETQqO4tJAWz54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'chat gbt has actually taught me more than all of my highschool tech class did',
#       'textOriginal': 'chat gbt has actually taught me more than all of my highschool tech class did',
#       'authorDisplayName': 'James Braendle',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUmnEWYSfZLMCy4iyWRi10UJpfWByEUabZ-f1em3A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqNgKNtTixfdDAwvOeHwaUA',
#       'authorChannelId': {'value': 'UCqNgKNtTixfdDAwvOeHwaUA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 4,
#       'publishedAt': '2023-02-27T15:47:59Z',
#       'updatedAt': '2023-02-27T15:47:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'k7XcBfvClWpoCJ7Mkjp5A6zOJdI',
#       'id': 'Ugwel4ZETQqO4tJAWz54AaABAg.9mdU-d3OUGF9mexhymIyLb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'g&quot;p&quot;t',
#        'textOriginal': 'g"p"t',
#        'parentId': 'Ugwel4ZETQqO4tJAWz54AaABAg',
#        'authorDisplayName': 'Varun shah',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWpp5B24wa7HQga-upb0gl-KLcFMrUeyWNb5V2N3f4=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCTvdYstWa90GC4QVXyg2Itw',
#        'authorChannelId': {'value': 'UCTvdYstWa90GC4QVXyg2Itw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T05:35:33Z',
#        'updatedAt': '2023-02-28T05:35:33Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'aHuUD-vv41T6yF2sSiNNrpebGiU',
#    'id': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'XmrkBQ-aEk30xEebUuy4Eyo-2ys',
#      'id': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I know this wasn&#39;t the point you were making but in the back of my mind I kept thinking of the Douglas Adams quote: <br>&quot;I&#39;ve come up with a set of rules that describe our reactions to technologies:<br>1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.<br>2. Anything that&#39;s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.<br>3. Anything invented after you&#39;re thirty-five is against the natural order of things.&quot;',
#       'textOriginal': 'I know this wasn\'t the point you were making but in the back of my mind I kept thinking of the Douglas Adams quote: \n"I\'ve come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that\'s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you\'re thirty-five is against the natural order of things."',
#       'authorDisplayName': 'smith22041',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUikGjuMp8wmHowDrkWadlfQjJf7Kw4vHiXIA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCczZqh0v-PJT_fY1GEBwG2A',
#       'authorChannelId': {'value': 'UCczZqh0v-PJT_fY1GEBwG2A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2101,
#       'publishedAt': '2023-02-13T16:53:47Z',
#       'updatedAt': '2023-02-13T16:56:00Z'}},
#     'canReply': True,
#     'totalReplyCount': 30,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'BqHAN1BqaObAZh-ns7ZNMSJrwSQ',
#       'id': 'UgzgRPBxpB70-tIZGgt4AaABAg.9m4YPOC1H6x9mbBt1b-nR1',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'This may have been true at one point, but not now. Adams lived in a different time. He couldn&#39;t have foreseen this.',
#        'textOriginal': "This may have been true at one point, but not now. Adams lived in a different time. He couldn't have foreseen this.",
#        'parentId': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#        'authorDisplayName': 'Allen Crawford',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/J347EjgY-XHifoWF4T1XGlaUyYwdfjSKQQtLR3p-yRO-w19ztx0GqFvLO7h3qWxZBzni_pZL6Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCgJM2oVhJsCLAh6WZ757Rtg',
#        'authorChannelId': {'value': 'UCgJM2oVhJsCLAh6WZ757Rtg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T18:31:10Z',
#        'updatedAt': '2023-02-26T18:31:10Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'NhmdTrt8MaYaAyR-Iz5EEpy5Kvw',
#       'id': 'UgzgRPBxpB70-tIZGgt4AaABAg.9m4YPOC1H6x9mUlcqjsruC',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@RogueReplicant there are always exceptions to the rule. Glad you&#39;re part of the few that keep up to date and excited about new tech!',
#        'textOriginal': "\u200b@RogueReplicant there are always exceptions to the rule. Glad you're part of the few that keep up to date and excited about new tech!",
#        'parentId': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#        'authorDisplayName': 'gecko',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ba4LjtyEQHjVZwpv6a2oVDAkeHaCzKT3DjhohpAtycG-s2LOjGc8KCcBFcDeN6SkeeJxXHiU=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCZ74fBHHhHq0sf7EZ44rt3A',
#        'authorChannelId': {'value': 'UCZ74fBHHhHq0sf7EZ44rt3A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-23T21:18:21Z',
#        'updatedAt': '2023-02-23T21:18:21Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'mq-LvTyvjMWqJPkPKBPHkOoDyrg',
#       'id': 'UgzgRPBxpB70-tIZGgt4AaABAg.9m4YPOC1H6x9mQLyfZpugP',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I absolutely disagree. I&#39;m 58 and I still marvel at new inventions. I&#39;ve never felt a new technology is &quot;against the natural order&quot;. New forms of human stupidity (e.g. wokeness) do unnerve me, but not new tech. Admas was wrong 👊',
#        'textOriginal': 'I absolutely disagree. I\'m 58 and I still marvel at new inventions. I\'ve never felt a new technology is "against the natural order". New forms of human stupidity (e.g. wokeness) do unnerve me, but not new tech. Admas was wrong 👊',
#        'parentId': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#        'authorDisplayName': 'RogueReplicant',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV1pLpRI24UYeE-jQCbGCeMA4ePyJwezBB3TsqK=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCZsEbcHSqkc7VyWAyDTQGWg',
#        'authorChannelId': {'value': 'UCZsEbcHSqkc7VyWAyDTQGWg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T04:08:26Z',
#        'updatedAt': '2023-02-22T04:08:26Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'tYInp__YtGV8X3oZlAHOutpFits',
#       'id': 'UgzgRPBxpB70-tIZGgt4AaABAg.9m4YPOC1H6x9mIVFytckv1',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@mikey forrester If your idea of change is coined on the size of your telly and other new phone models.. You might need to reconsider<br><br>Even in the case - that I disagree with but let&#39;s imagine - we&#39;re living in a decade where &quot; nothing has changed &quot;, you might agree that our relation to technologies and progress entered a new phase, something unprecedented in mankind&#39;s History ? We&#39;re, by 2030, about to reach the end of the &quot; numeric revolution &quot; that started somewhere at the end of 20th century, and that stuff might be of bigger impact than industrial revolution honestly',
#        'textOriginal': '@mikey forrester If your idea of change is coined on the size of your telly and other new phone models.. You might need to reconsider\n\nEven in the case - that I disagree with but let\'s imagine - we\'re living in a decade where " nothing has changed ", you might agree that our relation to technologies and progress entered a new phase, something unprecedented in mankind\'s History ? We\'re, by 2030, about to reach the end of the " numeric revolution " that started somewhere at the end of 20th century, and that stuff might be of bigger impact than industrial revolution honestly',
#        'parentId': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#        'authorDisplayName': 'Nicolas Picard',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUD5Ipa8-sYxDn1HEcw_9TM2hIbi21zWyY3Lw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCPSmuYbAWHKrAF0D-3tZWzg',
#        'authorChannelId': {'value': 'UCPSmuYbAWHKrAF0D-3tZWzg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-19T02:55:39Z',
#        'updatedAt': '2023-02-19T02:55:39Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'GM9Sk976o6A11wN72-0Yg6rsb6k',
#       'id': 'UgzgRPBxpB70-tIZGgt4AaABAg.9m4YPOC1H6x9mIULIjYSR4',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@A Wild Snorlax Absolutely, the exponential and blind pace of tehcnological progress is absolute madness..<br>I mean, we need to set a landmark in progress, being something like : when it totally alienates mankind from the world it spawned into and it&#39;s made from, it&#39;s not worth it',
#        'textOriginal': "@A Wild Snorlax Absolutely, the exponential and blind pace of tehcnological progress is absolute madness..\nI mean, we need to set a landmark in progress, being something like : when it totally alienates mankind from the world it spawned into and it's made from, it's not worth it",
#        'parentId': 'UgzgRPBxpB70-tIZGgt4AaABAg',
#        'authorDisplayName': 'Nicolas Picard',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUD5Ipa8-sYxDn1HEcw_9TM2hIbi21zWyY3Lw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCPSmuYbAWHKrAF0D-3tZWzg',
#        'authorChannelId': {'value': 'UCPSmuYbAWHKrAF0D-3tZWzg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-02-19T02:47:39Z',
#        'updatedAt': '2023-02-19T02:47:39Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CF7wA3ZV1zwqE8LblYlTUXKp-VU',
#    'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8gri1dLNDwUfwcm1ytdyginaUSg',
#      'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn&#39;t since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  <br>For me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. <br><br>I hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it&#39;s a damn efficient one.',
#       'textOriginal': "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.",
#       'authorDisplayName': 'Hellequin Maskharat',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV4TStWLBcX8KCPERFSoQSJkqsCgsBq_fNyKl72mw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKB35F97OYM751A7ETu7ADw',
#       'authorChannelId': {'value': 'UCKB35F97OYM751A7ETu7ADw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 29,
#       'publishedAt': '2023-02-20T21:35:51Z',
#       'updatedAt': '2023-02-20T21:35:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': '-CUmROXHPnzVMZd5VdE5VpH3RI8',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mRfuPzcVaU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.<br>at least its how it is the way people are using image generator right now.',
#        'textOriginal': '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'kerawoot',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW4h9rUtOmjNGWmnoDd6_9orK_qlSPbpkO-PQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCNnH0GyEyWNgfWrhRQPMv8g',
#        'authorChannelId': {'value': 'UCNnH0GyEyWNgfWrhRQPMv8g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-22T16:30:36Z',
#        'updatedAt': '2023-02-22T16:30:36Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ufVlbzRMbaoAtq0WOJuXQkPdBqc',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPZ_zdZWDx',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m more concerned  that &quot;anyone&quot; who learns how to &quot;use&quot; the system (chatgtp) will be (potentially) deemed as &quot;competent and confident&quot; in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? &quot;Beware of virtues not earned&quot;',
#        'textOriginal': 'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Stephen Soles',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUxiymoUXElrOQ9z5aPpOPmNKH0NkzUTF0sAg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCylX_6xby1oprDADijbUygA',
#        'authorChannelId': {'value': 'UCylX_6xby1oprDADijbUygA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 5,
#        'publishedAt': '2023-02-21T20:48:10Z',
#        'updatedAt': '2023-02-21T20:48:10Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'dPX8WNC1ytvdPzuc_8-q6qQsfa8',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPRChqxhsI',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'textOriginal': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Walter Stuart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUyECuSdNoTm7z1R92QbaFe5byP_iVSQBaDJenevg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCugvk8-W3vm2P54-9bPxzdA',
#        'authorChannelId': {'value': 'UCugvk8-W3vm2P54-9bPxzdA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T19:34:56Z',
#        'updatedAt': '2023-02-21T19:34:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qolbA_-HsgQQlCta9XNbwqt9yk8',
#    'id': 'Ugx8KZ_S0yu-nemGgwF4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0Wrws7EXv7YSrkPWPmhjvjghHw8',
#      'id': 'Ugx8KZ_S0yu-nemGgwF4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I refuse to believe that it&#39;s a coincidence that Tom listed &quot;morpheus and grokster, and limewire and kazaa&quot; in the same order as in Weird Al&#39;s &quot;Don&#39;t download this song&quot;',
#       'textOriginal': 'I refuse to believe that it\'s a coincidence that Tom listed "morpheus and grokster, and limewire and kazaa" in the same order as in Weird Al\'s "Don\'t download this song"',
#       'authorDisplayName': 'LegoStarWarsGuy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZWZCBYCTaIBP6sFRkUDjkJVcbMeFzwUVfyA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHL41oWxXRXIYVYZG_uq8VA',
#       'authorChannelId': {'value': 'UCHL41oWxXRXIYVYZG_uq8VA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 24,
#       'publishedAt': '2023-02-20T20:27:31Z',
#       'updatedAt': '2023-02-20T20:27:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'ZYxZlzbMtw_9hAEV62Hh1DYvjrs',
#       'id': 'Ugx8KZ_S0yu-nemGgwF4AaABAg.9mMxQueINI79mhERBe3QCO',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Sounded like a reference to me as well.',
#        'textOriginal': 'Sounded like a reference to me as well.',
#        'parentId': 'Ugx8KZ_S0yu-nemGgwF4AaABAg',
#        'authorDisplayName': 'Vykk Draygo',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVRssjsOyoTBkiyBgF7rD5swsX1v_SqWLub9PAC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCOIQjDbEfFsHrqGPMyAP2Ng',
#        'authorChannelId': {'value': 'UCOIQjDbEfFsHrqGPMyAP2Ng'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-01T02:48:54Z',
#        'updatedAt': '2023-03-01T02:48:54Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2YXkEZ0KSC9thjfVLIgldmAS7V4',
#    'id': 'UgxCBVlGX1tCiiyNijF4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5p7xtMjtjZOVuIpzBA0d30ycJSM',
#      'id': 'UgxCBVlGX1tCiiyNijF4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#       'textOriginal': 'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#       'authorDisplayName': 'DailyFrankPeter',
# ...
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'qikvgeMYQryG67vTLdUMRFfW6xc',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mjcbTKxw-A',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I have a Gmail account because of my phone and YT. I rarely check it.<br>I have a Yahoo account that has folders.<br>I don&#39;t really use email when communicating with people.',
#        'textOriginal': "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Free The Birds',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUK2ALJsTFq4NKdNR-BmlbbfPaPJuMkwu9mpM5f=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSV6jnfVxnnvLNvF2nqFekA',
#        'authorChannelId': {'value': 'UCSV6jnfVxnnvLNvF2nqFekA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T01:07:22Z',
#        'updatedAt': '2023-03-02T01:07:22Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jvYzEtx4XarNprRySPc1cXDfHBw',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mfYGE_Ndg8',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'textOriginal': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Angel Heart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVROIsdUQOtJXZr5barH2HdsiXY4T1amDs0r4gA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCn-KTNRp5EMTTn6h9SF5fRg',
#        'authorChannelId': {'value': 'UCn-KTNRp5EMTTn6h9SF5fRg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T11:03:41Z',
#        'updatedAt': '2023-02-28T11:03:41Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GoO3-ju6pBxQ3w2aQIqACbNt1vo',
#    'id': 'UgzTEERz6O0W8SWc2Rd4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uYSPu-2cziOzj-fL9EuLcj0JroY',
#      'id': 'UgzTEERz6O0W8SWc2Rd4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Thanks for putting into words something I&#39;ve felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!',
#       'textOriginal': "Thanks for putting into words something I've felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!",
#       'authorDisplayName': 'Arron Artikai',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJU7OxRVa6DkOyCIqD8EvMhB0mF99fK9gltNqEn45sg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCxBttQLnCFCrdBvtWIw1lXg',
#       'authorChannelId': {'value': 'UCxBttQLnCFCrdBvtWIw1lXg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 6,
#       'publishedAt': '2023-02-24T05:15:49Z',
#       'updatedAt': '2023-02-24T05:15:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'tCNDePjIvK7OfMDaDU9naZX6fGw',
#    'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B2OdKjZzw-pCXEeP-0Swu8EbWVk',
#      'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what&#39;s comming...',
#       'textOriginal': "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#       'authorDisplayName': 'Radosław Wujec',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXfAB7UdK9Eh2U05daFqhmx5m52Fo9r559w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSdT3nFciNpl9NpZXwPm5EQ',
#       'authorChannelId': {'value': 'UCSdT3nFciNpl9NpZXwPm5EQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 25,
#       'publishedAt': '2023-02-21T22:51:57Z',
#       'updatedAt': '2023-02-21T22:51:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'c-Kvvc-DYKfdFNYU-Az1hlml8cs',
#       'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg.9mPmkaGJjgH9mgBNYUciDX',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'textOriginal': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'parentId': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-28T17:02:56Z',
#        'updatedAt': '2023-02-28T17:02:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-g7sAOY8WzptFslZGAmNQlamsLQ',
#    'id': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BU2C23vG2wahzB_McIyDpPvX1s8',
#      'id': 'UgxIZQ8lca0JURrNUh54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I am fascinated how Tom can talk non stop with such perfect structure and occasional timely jokes.',
#       'textOriginal': 'I am fascinated how Tom can talk non stop with such perfect structure and occasional timely jokes.',
#       'authorDisplayName': 'Vasyl Boroviak',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVq5ochLl1nlgpmHPY7tZXHoffx1iExAs9F_lOuoq0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnvs76Ee8-1qizTckD2eDzw',
#       'authorChannelId': {'value': 'UCnvs76Ee8-1qizTckD2eDzw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3902,
#       'publishedAt': '2023-02-14T12:28:45Z',
#       'updatedAt': '2023-02-14T12:28:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 40,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'iy8SW9Nh2lhULpZ0L1N5mwuz01I',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mdk9CUTT1B',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#        'textOriginal': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'dave bento',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWuKBEeloJWn9qyihl91FmBPELGc_HMlKHrYA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCWloOVPTGKatWGnQ8Y1xSMw',
#        'authorChannelId': {'value': 'UCWloOVPTGKatWGnQ8Y1xSMw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T18:17:50Z',
#        'updatedAt': '2023-02-27T18:17:50Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'PAsFcesPIqaVpQEKgpFAzcZxZLc',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mSCn6_xlby',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Senk Ju silenced him easily😂',
#        'textOriginal': '\u200b@Senk Ju silenced him easily😂',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'ilikefish',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/eeNJUft4-VIGopnmUTEF9CIk5aPYUZ9lO9zy7ehVRwqV2rU48zysEOrQg1SME99ZhZK8bopR=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCck_-AOidzq6l6ahgAB4Lhw',
#        'authorChannelId': {'value': 'UCck_-AOidzq6l6ahgAB4Lhw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-22T21:26:42Z',
#        'updatedAt': '2023-02-22T21:26:42Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '4_mc-YDtru8hJ3Ig37oCES23y8E',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mQOr66qurE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Mark Koetsier No more than you or I ..',
#        'textOriginal': '@Mark Koetsier No more than you or I ..',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'blucat4',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/5TlLhyJYqELPzlpo9WcGF5WSMqUEgw5wmiqD5N4-dcKvKEVLG3r9737g2zMCse8hmOeYfQzu=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCmkhEsnWvK1TIcSJ0UlaGbg',
#        'authorChannelId': {'value': 'UCmkhEsnWvK1TIcSJ0UlaGbg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T04:33:37Z',
#        'updatedAt': '2023-02-22T04:33:37Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'DpQlpgeS-DtZNMs67SW6aGxMwCQ',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mPkVG_WNnU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Tom is a bot.',
#        'textOriginal': 'Tom is a bot.',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'Mark Koetsier',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVy6_TL3RimhGIwWNHnLyQovLSbcr5v0MuCsg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCNIEj7-_Qx5OH3dEeWlBJWQ',
#        'authorChannelId': {'value': 'UCNIEj7-_Qx5OH3dEeWlBJWQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T22:32:14Z',
#        'updatedAt': '2023-02-21T22:32:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G1_AgiGTw8uXFzKW7UWbNyihEuY',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mNpSGX4Ov6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#        'textOriginal': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'Create A. Googleaccount',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZ_JPg7xHQ_i7F8TXeiHyMpffOusPB_25fknHN1EXqlv1G2O5MPkWnvYBK4FBC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UChteANI-UpaQfvWDNOPDD-w',
#        'authorChannelId': {'value': 'UChteANI-UpaQfvWDNOPDD-w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-21T04:37:02Z',
#        'updatedAt': '2023-02-21T04:37:02Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7Z2shGxUGVULwrGmI37eBblqp6c',
#    'id': 'Ugy94k8mBGoOx2ISSrt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'CjQtfCp4qRyUMDDwpGXUzeOhED4',
#      'id': 'Ugy94k8mBGoOx2ISSrt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I’m glad I’m not the only one feeling the dread. As a designer AND comms specialist, I’m feeling it on all sides.',
#       'textOriginal': 'I’m glad I’m not the only one feeling the dread. As a designer AND comms specialist, I’m feeling it on all sides.',
#       'authorDisplayName': 'Mark Halvorson',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXPGpQPD9m9qgSwqEcb0VmK3sMTLrjLB6aA1Ocz=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCEvNdIv3V5jvga_GNlVxZGA',
#       'authorChannelId': {'value': 'UCEvNdIv3V5jvga_GNlVxZGA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 30,
#       'publishedAt': '2023-02-21T05:02:29Z',
#       'updatedAt': '2023-02-21T05:02:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '43df05Yq0j8IhJMRgX_icIsdn_s',
#    'id': 'UgwagmBQUjM7N2UzWPp4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AoKhUiJV7dKLRnzulBuqRBJV6FE',
#      'id': 'UgwagmBQUjM7N2UzWPp4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Change is a constant to our universe, and change means opportunity. There is always a way you can win of change. I agree on the &quot;wait, how do we control it tho&quot; part. Like, there is no institution in place to stop people or itself using it for destructive purposes...',
#       'textOriginal': 'Change is a constant to our universe, and change means opportunity. There is always a way you can win of change. I agree on the "wait, how do we control it tho" part. Like, there is no institution in place to stop people or itself using it for destructive purposes...',
#       'authorDisplayName': 'C-MAD',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/y9kADCt_A_OBwjMnf5ScRLebe843KWDbeneYKVcF2fMLrIgiD6-hT6R1apugQyeKSK58wLoI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcF8foDoWHmlKUhoi78v2gQ',
#       'authorChannelId': {'value': 'UCcF8foDoWHmlKUhoi78v2gQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 7,
#       'publishedAt': '2023-02-20T20:00:16Z',
#       'updatedAt': '2023-02-20T20:00:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RYN9-lL5QiiDSAlJMH0r3r2_PnE',
#    'id': 'UgxTp1LyF2YicAozDdB4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0Hl-SNY2uYZVAJYt7BI-yyXb__I',
#      'id': 'UgxTp1LyF2YicAozDdB4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'these sorts of shifts are exactly why its smart for successful creators to be frugal, even if theyre wildly successful. there is nothing money can buy that is greater in functional value than securing the ability to spend your entire life on your own terms.',
#       'textOriginal': 'these sorts of shifts are exactly why its smart for successful creators to be frugal, even if theyre wildly successful. there is nothing money can buy that is greater in functional value than securing the ability to spend your entire life on your own terms.',
#       'authorDisplayName': 'Jesse Mitchell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUY_DV_ETa4gMO8HaNzVpdWRJFPl06idzQ0hGUy=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWGdLhrWgienhyB9yWX6JHw',
#       'authorChannelId': {'value': 'UCWGdLhrWgienhyB9yWX6JHw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 24,
#       'publishedAt': '2023-02-21T03:58:48Z',
#       'updatedAt': '2023-02-21T03:58:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}
