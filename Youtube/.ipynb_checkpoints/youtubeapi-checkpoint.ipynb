# %%
import urllib.request
import json
import urllib
from googleapiclient.discovery import build

# %%
VideoID = "XZJc1p6RE78" #Id du vidéo à connaitre

params = {"format": "json", "url": "https://www.youtube.com/watch?v=%s" % VideoID}
url = "https://www.youtube.com/oembed"
query_string = urllib.parse.urlencode(params)
url = url + "?" + query_string

# %%
with urllib.request.urlopen(url) as response:
    response_text = response.read()
    data = json.loads(response_text.decode())
    print(data['title'])
    print(data['author_name'])
print(data)
# Out:
# Ch(e)at GPT? - Computerphile
# Computerphile
# {'title': 'Ch(e)at GPT? - Computerphile', 'author_name': 'Computerphile', 'author_url': 'https://www.youtube.com/@Computerphile', 'type': 'video', 'height': 113, 'width': 200, 'version': '1.0', 'provider_name': 'YouTube', 'provider_url': 'https://www.youtube.com/', 'thumbnail_height': 360, 'thumbnail_width': 480, 'thumbnail_url': 'https://i.ytimg.com/vi/XZJc1p6RE78/hqdefault.jpg', 'html': '<iframe width="200" height="113" src="https://www.youtube.com/embed/XZJc1p6RE78?feature=oembed" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen title="Ch(e)at GPT? - Computerphile"></iframe>'}

# %%
api_key = 'AIzaSyAXqXQDwF_SDj_Ce1KT5F9OlpdbM8WvB2o'
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
request = youtube.search().list(
        part="snippet",
        maxResults=25,
        order="viewCount",
        q="chatgpt"
    )
response = request.execute()

# %%
result_video_length = len(response['items'])

# %%
list_videos_id = []
for i in range(result_video_length):
    list_videos_id.append(response['items'][i]['id']['videoId'])

print(list_videos_id)
# Out:
# ['jPhJbKBuNnA', 'JTxsNm9IdYU', '7uljoeHgN4g', 'sTeoEFzVNSc', 'rSCNW1OCk_M', 'WPBWIcprLxc', 'iWhlrkfJrCQ', 'WizoCwjEKsg', 'K7z0jlE61IM', 'wnNp-zT3JmY', 'AXn2XVLf7d0', 'pOmpqdlVCoo', 'MIdv9ku1TfU', 'ey1kHYVu19c', 'RCBZ-Xj2dgQ', 'YNEb3EK4rNY', 'kQPUWryXwag', 'CtNsdVtQsf0', 'lGSGTrn5INA', '-WSQEyT2Mu0', 'Fw5ybNwwSbg', '40Kp_fa8vIw', '5MYJtKx-ebE', 'Hrv4UP3wBRg', 'o5MutYFWsM8']

# %% [markdown]
# Comments without replies

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    )
response_comments = request_comments.execute()

# %%
print(response_comments['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨‍💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.

# %%
print(response_comments['items'][1])
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'eB1Lcycnb8hciWK_fQfd9Fcatdg', 'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'CYBbbRX7K1YiNOVc37z8z4YQHYc', 'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': 'I love Tom Scott&#39;s dedication to do a one take for each segment. It&#39;s very difficult for those who haven&#39;t done it before.', 'textOriginal': "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.", 'authorDisplayName': 'Luke Maximo Bell', 'authorProfileImageUrl': 'https://yt3.ggpht.com/s9PrKA9XK4vvu_dW8WmyWx-q1vZcSLGITXldTBjhNMFWqtqIpg3gHnMdANOhu5LL9TwWsy1PQA=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCHJ-02TEGNS2GeD2wYetHSQ', 'authorChannelId': {'value': 'UCHJ-02TEGNS2GeD2wYetHSQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 3799, 'publis
# ...

# %% [markdown]
# Replies

# %%
print(response_comments['items'][0]['replies']['comments'][1]['snippet']['textOriginal'])
# Out:
# @Timo Pint All of the VPN providers sell your data.

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']
# Out:
# {'videoId': 'jPhJbKBuNnA',
#  'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#  'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#  'authorDisplayName': 'Tom Scott',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/channel/UCBa659QWEk1AI4Tg--mrJ2A',
#  'authorChannelId': {'value': 'UCBa659QWEk1AI4Tg--mrJ2A'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 8993,
#  'publishedAt': '2023-02-08T05:47:56Z',
#  'updatedAt': '2023-02-08T05:47:56Z'}

# %%
import json

# Define a dictionary
my_dict = response_comments['items'][0]['snippet']['topLevelComment']['snippet']

# Open a file for writing
with open('testYoutube.json', 'w') as f:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(my_dict, f)

# %%
response_comments
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'QuAeQvbWc3HSDXGxbDLf5MALIy4',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '6PG5DX_A1TkCkiRbAPbbBMBqS10',
#    'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AW0B1um0irR4Z2c8U82ugcFQ7Xk',
#      'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
# ...

# %%
response_comments['items']
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': '6PG5DX_A1TkCkiRbAPbbBMBqS10',
#   'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'AW0B1um0irR4Z2c8U82ugcFQ7Xk',
#     'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#      'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#      'authorDisplayName': 'Tom Scott',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    pageToken="..."
    )
response_comments = request_comments.execute()

# %%
test  = response_comments['items'][0]['snippet']['topLevelComment']

response_comments['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '6PG5DX_A1TkCkiRbAPbbBMBqS10',
#  'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'AW0B1um0irR4Z2c8U82ugcFQ7Xk',
#    'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#     'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#     'authorDisplayName': 'Tom Scott',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
response_comments['items'][0]['snippet']
# Out:
# {'videoId': 'Sqa8Zo2XWc4',
#  'topLevelComment': {'kind': 'youtube#comment',
#   'etag': 'EhjMNxTATxNJ3q6KQ3xBWDtZJWU',
#   'id': 'Ugw-_ReZn8XXakultPR4AaABAg',
#   'snippet': {'videoId': 'Sqa8Zo2XWc4',
#    'textDisplay': 'IBM&#39;s insight from 1979 is still valid today,: <br>&quot;A computer can never be held accountable <br>  therefore a computer must never make a management decision&quot;',
#    'textOriginal': 'IBM\'s insight from 1979 is still valid today,: \n"A computer can never be held accountable \n  therefore a computer must never make a management decision"',
#    'authorDisplayName': 'Artemissian',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/Gjdx8d9Wmh_ijMP9ERrvqNeEI2woPynvsBX6kg8pLabr5XXoNRafgJ61UzniQVA9yagBZfyW=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCJSSzK9UD4eF9koF-dwvU0A',
#    'authorChannelId': {'value': 'UCJSSzK9UD4eF9koF-dwvU0A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 926,
# ...

# %%
length = len(response_comments['items'])
print(length)
for i in range(length):
    print(response_comments['items'][i])
# Out:
# 20
# ...

# %%
response_comments['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '6PG5DX_A1TkCkiRbAPbbBMBqS10',
#  'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'AW0B1um0irR4Z2c8U82ugcFQ7Xk',
#    'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#     'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#     'authorDisplayName': 'Tom Scott',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
response_comments['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '6PG5DX_A1TkCkiRbAPbbBMBqS10',
#  'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'AW0B1um0irR4Z2c8U82ugcFQ7Xk',
#    'id': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'textDisplay': 'It&#39;s an opinion piece this week! Been a while since I&#39;ve done one of these. ■ AD: 👨\u200d💻 NordVPN&#39;s best deal is here: <a href="https://nordvpn.com/tomscott">https://nordvpn.com/tomscott</a> - with a 30-day money-back guarantee.',
#     'textOriginal': "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.",
#     'authorDisplayName': 'Tom Scott',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUJgzwii8Ei8BsgrOp_DmMT3skUrUwOTu-0PGowLw=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
import json

# Define a dictionary
my_dict = response_comments['items'][0]['snippet']['topLevelComment']['snippet']

# Open a file for writing
with open('testYoutube.json', 'w') as f:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(my_dict, f)

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# "It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨\u200d💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee."

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName']
# Out:
# 'Tom Scott'

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']['authorChannelUrl']
# Out:
# 'http://www.youtube.com/channel/UCBa659QWEk1AI4Tg--mrJ2A'

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']['likeCount']
# Out:
# 8993

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']
# Out:
# '2023-02-08T05:47:56Z'

# %%
response_comments['items'][0]['snippet']['totalReplyCount']
# Out:
# 224

# %%
response_comments['items'][0]['replies']['comments'][0]['snippet']
# Out:
# {'videoId': 'jPhJbKBuNnA',
#  'textDisplay': 'Tom scott',
#  'textOriginal': 'Tom scott',
#  'parentId': 'UgyxI2ZLYhdwdGVcde54AaABAg',
#  'authorDisplayName': 'Righteous 2k',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/sdEG3VFT7Gyx9YMC8n207QtQrkKAWudMVEwCNxj5FUhMZr3BlslbB_hw4u8kudx9nAIzJJXCIyo=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/channel/UC7jOomH47gzA9Tism2shFrw',
#  'authorChannelId': {'value': 'UC7jOomH47gzA9Tism2shFrw'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 0,
#  'publishedAt': '2023-03-02T23:44:35Z',
#  'updatedAt': '2023-03-02T23:44:35Z'}

# %%
response_comments['items'][0]['replies']['comments'][0]['snippet']['textOriginal']
