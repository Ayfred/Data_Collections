# %%
import urllib.request
import json
import urllib
from googleapiclient.discovery import build

# %%
VideoID = "XZJc1p6RE78" #Id du vidéo à connaitre

params = {"format": "json", "url": "https://www.youtube.com/watch?v=%s" % VideoID}
url = "https://www.youtube.com/oembed"
query_string = urllib.parse.urlencode(params)
url = url + "?" + query_string

# %%
with urllib.request.urlopen(url) as response:
    response_text = response.read()
    data = json.loads(response_text.decode())
    print(data['title'])
    print(data['author_name'])
print(data)
# Out:
# Ch(e)at GPT? - Computerphile
# Computerphile
# {'title': 'Ch(e)at GPT? - Computerphile', 'author_name': 'Computerphile', 'author_url': 'https://www.youtube.com/@Computerphile', 'type': 'video', 'height': 113, 'width': 200, 'version': '1.0', 'provider_name': 'YouTube', 'provider_url': 'https://www.youtube.com/', 'thumbnail_height': 360, 'thumbnail_width': 480, 'thumbnail_url': 'https://i.ytimg.com/vi/XZJc1p6RE78/hqdefault.jpg', 'html': '<iframe width="200" height="113" src="https://www.youtube.com/embed/XZJc1p6RE78?feature=oembed" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen title="Ch(e)at GPT? - Computerphile"></iframe>'}

# %%
with urllib.request.urlopen(url) as response:
    response_text = response.read()
    data = json.loads(response_text.decode())
    print(data['title'])
    print(data['author_name'])
print(data)
# Out:
# Ch(e)at GPT? - Computerphile
# Computerphile
# {'title': 'Ch(e)at GPT? - Computerphile', 'author_name': 'Computerphile', 'author_url': 'https://www.youtube.com/@Computerphile', 'type': 'video', 'height': 113, 'width': 200, 'version': '1.0', 'provider_name': 'YouTube', 'provider_url': 'https://www.youtube.com/', 'thumbnail_height': 360, 'thumbnail_width': 480, 'thumbnail_url': 'https://i.ytimg.com/vi/XZJc1p6RE78/hqdefault.jpg', 'html': '<iframe width="200" height="113" src="https://www.youtube.com/embed/XZJc1p6RE78?feature=oembed" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen title="Ch(e)at GPT? - Computerphile"></iframe>'}

# %%
api_key = 'AIzaSyAXqXQDwF_SDj_Ce1KT5F9OlpdbM8WvB2o'
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
request = youtube.search().list(
        part="snippet",
        maxResults=50,
        order="viewCount",
        q="chatgpt"
    )
response = request.execute()

# %%
result_video_length = len(response['items'])

# %%
list_videos_id = []
for i in range(result_video_length):
    list_videos_id.append(response['items'][i]['id']['videoId'])

print(list_videos_id)
# Out:
# ['jPhJbKBuNnA', 'Sqa8Zo2XWc4', 'JTxsNm9IdYU', 'kh5dN72GTQ8', '7uljoeHgN4g', '0uQqMxXoNVs', 'sTeoEFzVNSc', 'rSCNW1OCk_M', '8I3NTE4cn5s', 'Nh5i5obZ8OY', 'WPBWIcprLxc', 'kuTTAuUorsI', 'iWhlrkfJrCQ', 'WizoCwjEKsg', 'JYtZ2zsdE_s', 'K7z0jlE61IM', 'gtgA4u8V_TQ', '_eHjifELI-k', 'wnNp-zT3JmY', 'ng438SIXyW4', 'AXn2XVLf7d0', 'BYGWMArFNRE', 'pOmpqdlVCoo', 'MIdv9ku1TfU', 'RCBZ-Xj2dgQ', 'ey1kHYVu19c', 'kPV4BgmoXz8', 'YNEb3EK4rNY', 'kQPUWryXwag', 'CtNsdVtQsf0', 'X6MykhFaP5U', 'Ku-I7KVmqdw', 'pc8ftlzB2D0', 'lGSGTrn5INA', '1EeYEkrlD8k', 'UNbyT7wPwk4', '-WSQEyT2Mu0', 'Fw5ybNwwSbg', '40Kp_fa8vIw', 'Hrv4UP3wBRg', '5MYJtKx-ebE', 'qLh1GIPBXhc', 'o5MutYFWsM8', '3vr3wcCAZbY', 'W3sk8gPpmcc', 'ya-fUBldJio', 'svwzjVq09es', 'y3iLOxBTuy4', 'cHikHtiVwXU', 'zNRvAMJOfAI']

# %% [markdown]
# Comments without replies

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    )
response_comments = request_comments.execute()

# %%
print(response_comments['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# It's an opinion piece this week! Been a while since I've done one of these. ■ AD: 👨‍💻 NordVPN's best deal is here: https://nordvpn.com/tomscott - with a 30-day money-back guarantee.

# %%
print(response_comments['items'][1])
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'OJNWKnLTehQgWHQmpvkK0F2ICZg', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'jt8JPyRXyFdkk2LDaXb5SITHCdk', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '“I&#39;ve come up with a set of rules that describe our reactions to technologies:<br>1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.<br>2. Anything that&#39;s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.<br>3. Anything invented after you&#39;re thirty-five is against the natural order of things.”<br><br>- Douglas Adams', 'textOriginal': "“I've come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that's invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you're thirty-five is against the natural order of things.”\n\n- Douglas Adams", 'authorDisplayName': 'SmallAdvantages ', 'authorProfileImageUrl': 'https://yt3.ggpht.com/JM58K3s0lYuoNryWm9twIvO2v6peYhx8aouIjJ7Yj1eof6uIFGtslYDXoY1GDUGSYd_l6KlIDw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCskEPRzGlsYHs_a5SJyCXag', 'authorChannelId': {'value': 'UCskEPRzGlsYHs_a5SJyCXag'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 9721, 'publishedAt': '2023-02-19T07:16:30Z', 'updatedAt': '2023-02-19T07:16:30Z'}}, 'canReply': True, 'totalReplyCount': 193, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'mb9Z7xmvqlMsuqhGktrvsHFFvB8', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mtH17wEgA0', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': 'We couldn&#39;t end the world with a flatscreen, dude. We&#39;ve been calling this particular problem out since Asimov.', 'textOriginal': "We couldn't end the world with a flatscreen, dude. We've been calling this particular problem out since Asimov.", 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': 'Preaplanes', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWXtPPCC3jypTbB_Sly7wYvUv4LBHPnkLogpxwz=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCI6HdQhRsGwpG3Yj5v5wHtw', 'authorChannelId': {'value': 'UCI6HdQhRsGwpG3Yj5v5wHtw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-05T19:02:26Z', 'updatedAt': '2023-03-05T19:02:26Z'}}, {'kind': 'youtube#comment', 'etag': 'uB1IlZ9KAlRsWf94c5ImM1hLOoM', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mjUU1QWULH', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '@Pat The Batman Fan you too buddy.', 'textOriginal': '@Pat The Batman Fan you too buddy.', 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': '88RangeRoverClassic', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJURfzeWgdBuba8iBd6iGSXDXiGMBw_S8Cr57Q=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCeTh7gC13gzC8A92kXd640g', 'authorChannelId': {'value': 'UCeTh7gC13gzC8A92kXd640g'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-01T23:47:34Z', 'updatedAt': '2023-03-01T23:47:34Z'}}, {'kind': 'youtube#comment', 'etag': 'aamjugOytW9BFtiMpcSepErULIw', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mhOovoEjKP', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'textOriginal': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'parentId': 'UgyFk62AH8GwgbDPFK ...

# %% [markdown]
# Replies

# %%
import json

# Define a dictionary
my_dict = response_comments['items'][0]['snippet']['topLevelComment']['snippet']

# Open a file for writing
with open('testYoutube.json', 'w') as f:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(my_dict, f)

# %%
print(response_comments['items'][0]['replies']['comments'][1]['snippet']['textOriginal'])
# Out:
# Playing runescape sense 99.

# %%
print(response_comments['items'][1])
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'OJNWKnLTehQgWHQmpvkK0F2ICZg', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'jt8JPyRXyFdkk2LDaXb5SITHCdk', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '“I&#39;ve come up with a set of rules that describe our reactions to technologies:<br>1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.<br>2. Anything that&#39;s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.<br>3. Anything invented after you&#39;re thirty-five is against the natural order of things.”<br><br>- Douglas Adams', 'textOriginal': "“I've come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that's invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you're thirty-five is against the natural order of things.”\n\n- Douglas Adams", 'authorDisplayName': 'SmallAdvantages ', 'authorProfileImageUrl': 'https://yt3.ggpht.com/JM58K3s0lYuoNryWm9twIvO2v6peYhx8aouIjJ7Yj1eof6uIFGtslYDXoY1GDUGSYd_l6KlIDw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCskEPRzGlsYHs_a5SJyCXag', 'authorChannelId': {'value': 'UCskEPRzGlsYHs_a5SJyCXag'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 9721, 'publishedAt': '2023-02-19T07:16:30Z', 'updatedAt': '2023-02-19T07:16:30Z'}}, 'canReply': True, 'totalReplyCount': 193, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'mb9Z7xmvqlMsuqhGktrvsHFFvB8', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mtH17wEgA0', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': 'We couldn&#39;t end the world with a flatscreen, dude. We&#39;ve been calling this particular problem out since Asimov.', 'textOriginal': "We couldn't end the world with a flatscreen, dude. We've been calling this particular problem out since Asimov.", 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': 'Preaplanes', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWXtPPCC3jypTbB_Sly7wYvUv4LBHPnkLogpxwz=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCI6HdQhRsGwpG3Yj5v5wHtw', 'authorChannelId': {'value': 'UCI6HdQhRsGwpG3Yj5v5wHtw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-05T19:02:26Z', 'updatedAt': '2023-03-05T19:02:26Z'}}, {'kind': 'youtube#comment', 'etag': 'uB1IlZ9KAlRsWf94c5ImM1hLOoM', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mjUU1QWULH', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '@Pat The Batman Fan you too buddy.', 'textOriginal': '@Pat The Batman Fan you too buddy.', 'parentId': 'UgyFk62AH8GwgbDPFK54AaABAg', 'authorDisplayName': '88RangeRoverClassic', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJURfzeWgdBuba8iBd6iGSXDXiGMBw_S8Cr57Q=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCeTh7gC13gzC8A92kXd640g', 'authorChannelId': {'value': 'UCeTh7gC13gzC8A92kXd640g'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-03-01T23:47:34Z', 'updatedAt': '2023-03-01T23:47:34Z'}}, {'kind': 'youtube#comment', 'etag': 'aamjugOytW9BFtiMpcSepErULIw', 'id': 'UgyFk62AH8GwgbDPFK54AaABAg.9mIy6QtrIbv9mhOovoEjKP', 'snippet': {'videoId': 'jPhJbKBuNnA', 'textDisplay': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'textOriginal': '\u200b@Fluffyudders I like to have ChatGPT tell me bedtime stories in the style of Douglas Adams. It is wonderfully good at it.', 'parentId': 'UgyFk62AH8GwgbDPFK ...

# %% [markdown]
# response_comments

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    pageToken="..."
    )
response_comments = request_comments.execute()

# %%
response_comments['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'BDdSM56uA7IEnIur5ECxLzhp5co',
#  'id': 'UgweAR7prPbBynWlcH54AaABAg',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'WXerAFYhWzPEDMv2J-Z2MuYrUqs',
#    'id': 'UgweAR7prPbBynWlcH54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'textDisplay': 'For the record, you&#39;re definitely not the only one annoyed by Gmail labels, there&#39;s dozens of us!<br>And as an aside i too, got the same feeling, so if you&#39;re wrong, you won&#39;t be the only one.',
#     'textOriginal': "For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#     'authorDisplayName': 'jherazob',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUu6BFwok6IEUQdMw67v8wA7Qd4WRxnWCokHSZp=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCgh-joIi0mMjKKTxSLKxApg',
#     'authorChannelId': {'value': 'UCgh-joIi0mMjKKTxSLKxApg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1364,
#     'publishedAt': '2023-02-14T11:26:30Z',
#     'updatedAt': '2023-02-14T11:26:30Z'}},
#   'canReply': True,
#   'totalReplyCount': 29,
#   'isPublic': True},
#  'replies': {'comments': [{'kind': 'youtube#comment',
#     'etag': 'UOU2uxxkTi_3ElJRQ221OSfwoFc',
#     'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mOS34qdfJi',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': '@András Rácz Well that proves you know nothing.  Case closed for you.',
#      'textOriginal': '@András Rácz Well that proves you know nothing.  Case closed for you.',
#      'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#      'authorDisplayName': 'Karl with a K',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#      'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2023-02-21T10:23:07Z',
#      'updatedAt': '2023-02-21T10:23:07Z'}},
#    {'kind': 'youtube#comment',
#     'etag': 'opXlEmjrmGh4wNNTGCVvSPT1lHs',
#     'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mNKsssG8QW',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': '@Karl with a K that&#39;s false 🤷',
#      'textOriginal': "@Karl with a K that's false 🤷",
#      'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#      'authorDisplayName': 'András Rácz',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWEFqWU0rgISLgDG5_BD3pobpUb8SMuc_wgDA9fSks=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCGCuuyYKXnmvxujG6C6MWGw',
#      'authorChannelId': {'value': 'UCGCuuyYKXnmvxujG6C6MWGw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2023-02-21T00:01:11Z',
#      'updatedAt': '2023-02-21T00:01:11Z'}},
#    {'kind': 'youtube#comment',
#     'etag': '8ciR6H7-E-EBk7FvLNZN-kpBnmk',
#     'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHbiiH0Pz',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': '@András Rácz I mean 100% of what you store on their computer with your email is available to whoever wants it.  Every thing about your email life is fully available to anyone they want.',
#      'textOriginal': '@András Rácz I mean 100% of what you store on their computer with your email is available to whoever wants it.  Every thing about your email life is fully available to anyone they want.',
#      'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#      'authorDisplayName': 'Karl with a K',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#      'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2023-02-17T02:20:14Z',
#      'updatedAt': '2023-02-17T02:20:14Z'}},
#    {'kind': 'youtube#comment',
#     'etag': 'M4ON6ELZ-w21KLOqfowRCv_7nic',
#     'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHTHvCDg6',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': '@eekee So can every single person that works at Fastmail, so can the CEO, so can the intern.  Every single thing you saved all visible to them and anyone they feel like sending your information too.',
#      'textOriginal': '@eekee So can every single person that works at Fastmail, so can the CEO, so can the intern.  Every single thing you saved all visible to them and anyone they feel like sending your information too.',
#      'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#      'authorDisplayName': 'Karl with a K',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#      'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2023-02-17T02:18:56Z',
#      'updatedAt': '2023-02-17T02:18:56Z'}},
#    {'kind': 'youtube#comment',
#     'etag': 'NzNTjFVYJmXUk3k60eohBGcU7SA',
#     'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHP6dxM39',
#     'snippet': {'videoId': 'jPhJbKBuNnA',
#      'textDisplay': 'I actually prefer the label structure and not the folder structure, but this same problem Tom had -- where labels aren&#39;t included on subsequent threaded emails -- has been a huge pain in the ass for me quite a few times, even without backing anything up. Ugh',
#      'textOriginal': "I actually prefer the label structure and not the folder structure, but this same problem Tom had -- where labels aren't included on subsequent threaded emails -- has been a huge pain in the ass for me quite a few times, even without backing anything up. Ugh",
#      'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#      'authorDisplayName': 'The Darkness T',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX4ofhRPzIR3dpFXxznUFGFs55UlM3GI3C5_A=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCv94hMtQCYz4jkOGsproGRQ',
#      'authorChannelId': {'value': 'UCv94hMtQCYz4jkOGsproGRQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2023-02-17T02:18:22Z',
#      'updatedAt': '2023-02-17T02:18:22Z'}}]}}

# %%
response_comments['items'][0]['snippet']
# Out:
# {'videoId': 'jPhJbKBuNnA',
#  'topLevelComment': {'kind': 'youtube#comment',
#   'etag': 'WXerAFYhWzPEDMv2J-Z2MuYrUqs',
#   'id': 'UgweAR7prPbBynWlcH54AaABAg',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': 'For the record, you&#39;re definitely not the only one annoyed by Gmail labels, there&#39;s dozens of us!<br>And as an aside i too, got the same feeling, so if you&#39;re wrong, you won&#39;t be the only one.',
#    'textOriginal': "For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#    'authorDisplayName': 'jherazob',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUu6BFwok6IEUQdMw67v8wA7Qd4WRxnWCokHSZp=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCgh-joIi0mMjKKTxSLKxApg',
#    'authorChannelId': {'value': 'UCgh-joIi0mMjKKTxSLKxApg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1364,
#    'publishedAt': '2023-02-14T11:26:30Z',
#    'updatedAt': '2023-02-14T11:26:30Z'}},
#  'canReply': True,
#  'totalReplyCount': 29,
#  'isPublic': True}

# %%
response_comments['items'][0]['snippet']['topLevelComment']['snippet']
# Out:
# {'videoId': 'jPhJbKBuNnA',
#  'textDisplay': 'For the record, you&#39;re definitely not the only one annoyed by Gmail labels, there&#39;s dozens of us!<br>And as an aside i too, got the same feeling, so if you&#39;re wrong, you won&#39;t be the only one.',
#  'textOriginal': "For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#  'authorDisplayName': 'jherazob',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUu6BFwok6IEUQdMw67v8wA7Qd4WRxnWCokHSZp=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/channel/UCgh-joIi0mMjKKTxSLKxApg',
#  'authorChannelId': {'value': 'UCgh-joIi0mMjKKTxSLKxApg'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 1364,
#  'publishedAt': '2023-02-14T11:26:30Z',
#  'updatedAt': '2023-02-14T11:26:30Z'}

# %%
videoId = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['videoId']
comment = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal']
author = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName']
authorChannelUrl = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['authorChannelUrl']
likeCount = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['likeCount']
publishedAt = response_comments['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']

# %%
nextPageToken = response_comments['nextPageToken']
# Out:
# '...'

# %%
response_comments
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'lvSJbRd-BUl95O-L2rNrrIiwwUg',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'BDdSM56uA7IEnIur5ECxLzhp5co',
#    'id': 'UgweAR7prPbBynWlcH54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WXerAFYhWzPEDMv2J-Z2MuYrUqs',
#      'id': 'UgweAR7prPbBynWlcH54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'For the record, you&#39;re definitely not the only one annoyed by Gmail labels, there&#39;s dozens of us!<br>And as an aside i too, got the same feeling, so if you&#39;re wrong, you won&#39;t be the only one.',
#       'textOriginal': "For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#       'authorDisplayName': 'jherazob',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUu6BFwok6IEUQdMw67v8wA7Qd4WRxnWCokHSZp=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgh-joIi0mMjKKTxSLKxApg',
#       'authorChannelId': {'value': 'UCgh-joIi0mMjKKTxSLKxApg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1364,
#       'publishedAt': '2023-02-14T11:26:30Z',
#       'updatedAt': '2023-02-14T11:26:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 29,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'UOU2uxxkTi_3ElJRQ221OSfwoFc',
#       'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mOS34qdfJi',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@András Rácz Well that proves you know nothing.  Case closed for you.',
#        'textOriginal': '@András Rácz Well that proves you know nothing.  Case closed for you.',
#        'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#        'authorDisplayName': 'Karl with a K',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#        'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T10:23:07Z',
#        'updatedAt': '2023-02-21T10:23:07Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'opXlEmjrmGh4wNNTGCVvSPT1lHs',
#       'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mNKsssG8QW',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Karl with a K that&#39;s false 🤷',
#        'textOriginal': "@Karl with a K that's false 🤷",
#        'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#        'authorDisplayName': 'András Rácz',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWEFqWU0rgISLgDG5_BD3pobpUb8SMuc_wgDA9fSks=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCGCuuyYKXnmvxujG6C6MWGw',
#        'authorChannelId': {'value': 'UCGCuuyYKXnmvxujG6C6MWGw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-21T00:01:11Z',
#        'updatedAt': '2023-02-21T00:01:11Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '8ciR6H7-E-EBk7FvLNZN-kpBnmk',
#       'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHbiiH0Pz',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@András Rácz I mean 100% of what you store on their computer with your email is available to whoever wants it.  Every thing about your email life is fully available to anyone they want.',
#        'textOriginal': '@András Rácz I mean 100% of what you store on their computer with your email is available to whoever wants it.  Every thing about your email life is fully available to anyone they want.',
#        'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#        'authorDisplayName': 'Karl with a K',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#        'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-17T02:20:14Z',
#        'updatedAt': '2023-02-17T02:20:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'M4ON6ELZ-w21KLOqfowRCv_7nic',
#       'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHTHvCDg6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@eekee So can every single person that works at Fastmail, so can the CEO, so can the intern.  Every single thing you saved all visible to them and anyone they feel like sending your information too.',
#        'textOriginal': '@eekee So can every single person that works at Fastmail, so can the CEO, so can the intern.  Every single thing you saved all visible to them and anyone they feel like sending your information too.',
#        'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#        'authorDisplayName': 'Karl with a K',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/VGRgwcQ0mbUqb0dWQnCRDvDrIi9qp8ABbCZvYeTg47iCcTYmBw3ivL9HvvSgSHS-IuLfJVTn=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCEoYUvscb5FOjNYyPD1ajfA',
#        'authorChannelId': {'value': 'UCEoYUvscb5FOjNYyPD1ajfA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-17T02:18:56Z',
#        'updatedAt': '2023-02-17T02:18:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'NzNTjFVYJmXUk3k60eohBGcU7SA',
#       'id': 'UgweAR7prPbBynWlcH54AaABAg.9m6Xk3uQpRS9mDHP6dxM39',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I actually prefer the label structure and not the folder structure, but this same problem Tom had -- where labels aren&#39;t included on subsequent threaded emails -- has been a huge pain in the ass for me quite a few times, even without backing anything up. Ugh',
#        'textOriginal': "I actually prefer the label structure and not the folder structure, but this same problem Tom had -- where labels aren't included on subsequent threaded emails -- has been a huge pain in the ass for me quite a few times, even without backing anything up. Ugh",
#        'parentId': 'UgweAR7prPbBynWlcH54AaABAg',
#        'authorDisplayName': 'The Darkness T',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX4ofhRPzIR3dpFXxznUFGFs55UlM3GI3C5_A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCv94hMtQCYz4jkOGsproGRQ',
#        'authorChannelId': {'value': 'UCv94hMtQCYz4jkOGsproGRQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-17T02:18:22Z',
#        'updatedAt': '2023-02-17T02:18:22Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2B0d5lvcnCVGBruV3d7QOnP3M3c',
#    'id': 'Ugw7K28jeelZK_YPIG14AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'fNgXzR9BzbDfq7aOg6gzMMjEQmA',
#      'id': 'Ugw7K28jeelZK_YPIG14AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': '&quot;Tom Scott tries to predict the future, 2023, colorized.&quot;<br><br>In a few years Tom should do a prediction compilation and see how many he got right.',
#       'textOriginal': '"Tom Scott tries to predict the future, 2023, colorized."\n\nIn a few years Tom should do a prediction compilation and see how many he got right.',
#       'authorDisplayName': 'Chokyo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUb2QQ36eK8_g1KGp4Gs6MfBMSP8uDpgzrnslatag=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbLlVjakgyj7H4rgPklc2gA',
#       'authorChannelId': {'value': 'UCbLlVjakgyj7H4rgPklc2gA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 22663,
#       'publishedAt': '2023-02-13T16:24:02Z',
#       'updatedAt': '2023-02-13T16:24:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 53,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'ny9WUINjzbsrudc7FbvLUg1abgk',
#       'id': 'Ugw7K28jeelZK_YPIG14AaABAg.9m4V-PUTx2W9mEAlSxziYJ',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Damn',
#        'textOriginal': 'Damn',
#        'parentId': 'Ugw7K28jeelZK_YPIG14AaABAg',
#        'authorDisplayName': 'lokanantazain n',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWoD7o9OmDeRRdHSpUPPzSq1aNr2Vj4vSRPHjA3=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCsPHhU_riCsWTpTOswE0VNQ',
#        'authorChannelId': {'value': 'UCsPHhU_riCsWTpTOswE0VNQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-17T10:39:38Z',
#        'updatedAt': '2023-02-17T10:39:38Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'bgGFTB0RclaYlJoadt1u8z6mq4I',
#       'id': 'Ugw7K28jeelZK_YPIG14AaABAg.9m4V-PUTx2W9m7fV-u92he',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Tom should ask Chat GPT to predict the future, then review those predictions in 5 years',
#        'textOriginal': 'Tom should ask Chat GPT to predict the future, then review those predictions in 5 years',
#        'parentId': 'Ugw7K28jeelZK_YPIG14AaABAg',
#        'authorDisplayName': 'Cody Tarbotton',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWhipkBtjwc3MyvNEd0hNoEDPBa-iBK5FhrxDZ0Q8NsEU1_hOGbNOOoFmP6OuSV=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCdCZXUweDEWS1wNh3BK7qBQ',
#        'authorChannelId': {'value': 'UCdCZXUweDEWS1wNh3BK7qBQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-14T22:02:11Z',
#        'updatedAt': '2023-02-14T22:10:33Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '6pdnu38p61qCflRUG9f82Db3M5A',
#       'id': 'Ugw7K28jeelZK_YPIG14AaABAg.9m4V-PUTx2W9m7csXJYSgp',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'xd',
#        'textOriginal': 'xd',
#        'parentId': 'Ugw7K28jeelZK_YPIG14AaABAg',
#        'authorDisplayName': 'Mike',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV0HT9OLXkG0hYAydrW2mcNrU1FNzoQWa2CJzFa1A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCGjWEkexkpWi4y3da6iEQPw',
#        'authorChannelId': {'value': 'UCGjWEkexkpWi4y3da6iEQPw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-14T21:39:19Z',
#        'updatedAt': '2023-02-14T21:39:19Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '3Hu_JQjQysPFNKNm8GX3_opByRo',
#       'id': 'Ugw7K28jeelZK_YPIG14AaABAg.9m4V-PUTx2W9m7XwyeE6OM',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I agree',
#        'textOriginal': 'I agree',
#        'parentId': 'Ugw7K28jeelZK_YPIG14AaABAg',
#        'authorDisplayName': 'visij',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUOZx-DRbk68bJia7k2-uA1nFbuqhIL-H8zucbK2Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCdzk6VLM8MsTTaAOEmZEbWg',
#        'authorChannelId': {'value': 'UCdzk6VLM8MsTTaAOEmZEbWg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-14T20:47:30Z',
#        'updatedAt': '2023-02-14T20:47:30Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'D4T8WC6hqOhqlBWDRmlQD4Dzysw',
#       'id': 'Ugw7K28jeelZK_YPIG14AaABAg.9m4V-PUTx2W9m768iI7Y1X',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Stormbird3000 Literally what I was about to point out! ;)',
#        'textOriginal': '@Stormbird3000 Literally what I was about to point out! ;)',
#        'parentId': 'Ugw7K28jeelZK_YPIG14AaABAg',
#        'authorDisplayName': 'Tricia K',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX0SOvqYEQkd9V7gzn9J7VIWzRxx3NeMAcu6g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCHKVgy7a94pDVPY26gkyRNA',
#        'authorChannelId': {'value': 'UCHKVgy7a94pDVPY26gkyRNA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-14T16:44:34Z',
#        'updatedAt': '2023-02-14T16:44:34Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LeVHHw96kMYr-v74YSOX5p2LtvM',
#    'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4MPcIcyhJ1eVRpr-GACxgEjZPiQ',
#      'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn&#39;t believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.',
#       'textOriginal': "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#       'authorDisplayName': 'doobyboy21',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/j6Li8CLYzmclgYoMQJed-gABKHu8fPzeHhAloLb5MsMuQVCJeGSVnYJoHdj6_o0PC14Fj_MAYg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCEbRckbxiCDm7PgBuvQq1hQ',
#       'authorChannelId': {'value': 'UCEbRckbxiCDm7PgBuvQq1hQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 72,
#       'publishedAt': '2023-02-22T14:08:19Z',
#       'updatedAt': '2023-02-22T14:08:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'S0AsQgtlzg2AGU_73tyjzpBhxWI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgFaF694HA',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I remember my elementary school&#39;s teacher workroom being as smoky as a pool hall',
#        'textOriginal': "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Nolan McKinney',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV-xoC7uaFWVo_TC7TJ7uzS6cInHa5DE6LYD5lAXw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCCbYhC1yPa-_r7nu1WzzGvA',
#        'authorChannelId': {'value': 'UCCbYhC1yPa-_r7nu1WzzGvA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T17:39:46Z',
#        'updatedAt': '2023-02-28T17:39:46Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jI3KEREhIV-0em0eAVQSmaCrFwo',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgB1ZmjsRb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David And once in a while some teacher came and chased away the under 16&#39;s who were caught smoking.',
#        'textOriginal': "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T16:59:56Z',
#        'updatedAt': '2023-02-28T16:59:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'yqdCbiypwGDgpu7YmBbVhQYKntc',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mWdWdjj6sE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I laughed at that but then realized that so did we.',
#        'textOriginal': '@David I laughed at that but then realized that so did we.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Are',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUH6Dhs4uaLTzHDjjg9_5TnwLVL5e7RAPwXi97w=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCzssRp9ZfPhRvOp_jz_LIrg',
#        'authorChannelId': {'value': 'UCzssRp9ZfPhRvOp_jz_LIrg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-02-24T14:45:56Z',
#        'updatedAt': '2023-02-24T14:45:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uDYjqLu2L0cboAVMo6z2gxOOcqI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mUoQ_K55Kq',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When I was in high school they had a designated smoking area for the kids.',
#        'textOriginal': 'When I was in high school they had a designated smoking area for the kids.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'David',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXMjfel-oX_0QuvNkpLLAP-V9EVxAeo3blkOJDSsA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC4iF04W04tbSZwwsTc2kMsg',
#        'authorChannelId': {'value': 'UC4iF04W04tbSZwwsTc2kMsg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 11,
#        'publishedAt': '2023-02-23T21:42:45Z',
#        'updatedAt': '2023-02-23T21:42:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CymXKLJn_WdZdBc_tuEoJgFjMKQ',
#    'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0DW2vGk-IyFENBQalNkVR_z4CFU',
#      'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what&#39;s comming...',
#       'textOriginal': "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#       'authorDisplayName': 'Radosław Wujec',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXfAB7UdK9Eh2U05daFqhmx5m52Fo9r559w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSdT3nFciNpl9NpZXwPm5EQ',
#       'authorChannelId': {'value': 'UCSdT3nFciNpl9NpZXwPm5EQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 38,
#       'publishedAt': '2023-02-21T22:51:57Z',
#       'updatedAt': '2023-02-21T22:51:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'XDc_gIbReynzNiWUa1hFUp2dZW4',
#       'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg.9mPmkaGJjgH9msQiorg0qc',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Achim Take home exams are already banned in many universities for that exact reason. Even before AIs you could simply hire someone to do it for you. It was such a problem that actual companies were created for that purpose: you paid them some amount of money and then their staff do the assignments you give them for you',
#        'textOriginal': '@Achim Take home exams are already banned in many universities for that exact reason. Even before AIs you could simply hire someone to do it for you. It was such a problem that actual companies were created for that purpose: you paid them some amount of money and then their staff do the assignments you give them for you',
#        'parentId': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#        'authorDisplayName': 'Alain Térieur',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJU1nrOSdKajm_yz12FCtu4F4_CJpeQPlsFRH-qojw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCA479uCl1ZtRNPwgemlO4Iw',
#        'authorChannelId': {'value': 'UCA479uCl1ZtRNPwgemlO4Iw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-05T11:07:56Z',
#        'updatedAt': '2023-03-05T11:13:35Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '5ZWdfLSG3a5EHD-zjHmetjd7eQU',
#       'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg.9mPmkaGJjgH9mgBNYUciDX',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'textOriginal': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'parentId': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 7,
#        'publishedAt': '2023-02-28T17:02:56Z',
#        'updatedAt': '2023-02-28T17:02:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hdT6mwBYQMKUwpnR8Iu_Xs9N6Oc',
#    'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'kn2XAlKv2OojILzWUjNbPlWP5Eg',
#      'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'textOriginal': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'authorDisplayName': 'Derek Woods',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXR6puczs1o9QoBYjEitYikAe1ovkGY0p_K5Az3ml8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChgSMVDswJwip74E_DZDSEg',
#       'authorChannelId': {'value': 'UChgSMVDswJwip74E_DZDSEg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 618,
#       'publishedAt': '2023-02-22T04:38:15Z',
#       'updatedAt': '2023-02-22T04:38:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 15,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'hjofvp_8QFP9ZbI-n_ySjGePFOE',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9moYztAFcEa',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Peppermint Gal Why does he think the potential is limited? I&#39;m asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don&#39;t see any reason to be sceptical about the emergence of AGI within the next decade.',
#        'textOriginal': "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Max Khovanski',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWvX3RvAGYM1tcr3lKfBBXIpU9qC8V_CDoQSIMHgtI=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3CmO-Mxq9f1xte8iePKq_w',
#        'authorChannelId': {'value': 'UC3CmO-Mxq9f1xte8iePKq_w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-03T23:03:13Z',
#        'updatedAt': '2023-03-03T23:03:13Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'eiL4eGymqC_lCVb0ZBCynlLnZmo',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9moOeD3LZA6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Peppermint Gal<br>Wrong. The current danger of chat GPT isn&#39;t just writing code on its own. The main danger isn&#39;t allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.<br><br>This will lead to massive layoffs in the tech industry. The only question is when.',
#        'textOriginal': "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': '101IQ',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVGWqRtgMUxqd6jdaZT3Zdk3sGhBojSBLSOBhUmt38kbA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCJtym3nRvJCv1VKeQv8KngQ',
#        'authorChannelId': {'value': 'UCJtym3nRvJCv1VKeQv8KngQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-03T21:32:52Z',
#        'updatedAt': '2023-03-03T21:32:52Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'RhH2endsfPjxJkfl7LLzMFHtVSI',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5b8BrO6S',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'textOriginal': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-03-02T14:48:42Z',
#        'updatedAt': '2023-03-02T14:48:42Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G_sjHyTBrSpba17x4DOESCfWv1k',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5P86k_Yd',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m not actually sure about that. There&#39;s been a lot of sensationalism around this issue. I know someone who actually works <b>developing</b> this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.',
#        'textOriginal': "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-03-02T14:46:56Z',
#        'updatedAt': '2023-03-02T14:46:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jFlnTZeXaynVPR0DrgknyvJ8q38',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9mYJMHmjlgB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 You are also under the spell. Snap out of it.<br><br>it&#39;s programming. it predicts and responds as it is programmed to do. Nothing more.<br><br>It may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it&#39;s purpose is to gather data and grow that library), but in the end it&#39;s nothing more than programming. <br><br>The general public is a combination of uninterested and also under the spell.<br><br>The future is dark if enough people buy this BS as it&#39;s being advertised. The more people who buy it, the darker it is like to be.',
#        'textOriginal': "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'DRourk',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW7SABHTq6OgFqavy0M5hQbYPnl25U-n7vfEA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCL9mmOumcr-JtxtW6CzOakg',
#        'authorChannelId': {'value': 'UCL9mmOumcr-JtxtW6CzOakg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-25T06:19:31Z',
#        'updatedAt': '2023-02-25T06:19:31Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LUYnCLlJEsvfP_ymQERP8AsZkkk',
#    'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '81wQVb8zv1XJXVl1WoOnddbA9vw',
#      'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I love Tom Scott&#39;s dedication to do a one take for each segment. It&#39;s very difficult for those who haven&#39;t done it before.',
#       'textOriginal': "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.",
#       'authorDisplayName': 'Luke Maximo Bell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/s9PrKA9XK4vvu_dW8WmyWx-q1vZcSLGITXldTBjhNMFWqtqIpg3gHnMdANOhu5LL9TwWsy1PQA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHJ-02TEGNS2GeD2wYetHSQ',
#       'authorChannelId': {'value': 'UCHJ-02TEGNS2GeD2wYetHSQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3907,
#       'publishedAt': '2023-02-14T15:55:34Z',
#       'updatedAt': '2023-02-14T15:55:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 17,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'QD4-bRDo9lekybKLErRIR01bj3E',
#       'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg.9m70Xm05bR29mqUJqVcJlA',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'fr youtubers be like using cuts every 3 seconds',
#        'textOriginal': 'fr youtubers be like using cuts every 3 seconds',
#        'parentId': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#        'authorDisplayName': 'Joelhodoborgas',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/y9C-O6ER74Rhj_0OdGRXCpwINuyGV70PK3J5EKlODVVpdNGN01XqFyYxDDyh9uu1_iNDO8gdiSA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UClWNiFcuzRthFfcRTI4l7oA',
#        'authorChannelId': {'value': 'UClWNiFcuzRthFfcRTI4l7oA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-04T17:00:52Z',
#        'updatedAt': '2023-03-04T17:00:52Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G_IAauAQOrwaRR4vDor0vFvgEHQ',
#       'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg.9m70Xm05bR29mZj3lKYZ9f',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I wish just thinking the same!!',
#        'textOriginal': 'I wish just thinking the same!!',
#        'parentId': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#        'authorDisplayName': 'Priscilla Yoshida吉田',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/aIXQSVTDqda0-60DbAEomFLzi7chJ44eFJA3-DNOYq7F7PqArCcm_o5UZpMT5PVqBgalwwX_y38=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC9ni_u2woWKwUjrVVP9FpvA',
#        'authorChannelId': {'value': 'UC9ni_u2woWKwUjrVVP9FpvA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-25T19:32:09Z',
#        'updatedAt': '2023-02-25T19:32:09Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jKYsBrx-TK7MPdFgdSwvhLctSow',
#       'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg.9m70Xm05bR29mQF4emZALz',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I’m impressed as hell',
#        'textOriginal': 'I’m impressed as hell',
#        'parentId': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#        'authorDisplayName': 'S Charlesworth',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXy5UNXxB-vPPwBOkxZWpezvjbQ1DSftV_wfjIw2Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCpVIgZ_I-ISl_-uDU7kslxg',
#        'authorChannelId': {'value': 'UCpVIgZ_I-ISl_-uDU7kslxg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T03:08:14Z',
#        'updatedAt': '2023-02-22T03:08:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'g3Bf3kzkddrXmPM4MEAsxhvLEwY',
#       'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg.9m70Xm05bR29mDBCpQRUY1',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'He’s gotten so good at it that I frequently forget it’s all one take',
#        'textOriginal': 'He’s gotten so good at it that I frequently forget it’s all one take',
#        'parentId': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#        'authorDisplayName': 'Max Wilson',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXTa1BaP-GUQv0xRu3d5ROMiKj96DeIVtjGhVpOoQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3ad1pUXI_suCUgTyi0LZUg',
#        'authorChannelId': {'value': 'UC3ad1pUXI_suCUgTyi0LZUg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-17T01:24:16Z',
#        'updatedAt': '2023-02-17T01:24:16Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'AoggAAtRXjbeM6JeK9re2IcpP-A',
#       'id': 'UgwUFyfKSpiuF0W8VuB4AaABAg.9m70Xm05bR29mCp0pZ0auO',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Oh true. There was recently, a few weeks ago, a video from WhatCulture Gaming that was accidentally published unedited (removed now) that it included multiple takes for the same lines of the script. It was refreshing to know that even the public figures we may look up to as these people who have it all together or just like us. They just have editors to make them look great.',
#        'textOriginal': 'Oh true. There was recently, a few weeks ago, a video from WhatCulture Gaming that was accidentally published unedited (removed now) that it included multiple takes for the same lines of the script. It was refreshing to know that even the public figures we may look up to as these people who have it all together or just like us. They just have editors to make them look great.',
#        'parentId': 'UgwUFyfKSpiuF0W8VuB4AaABAg',
#        'authorDisplayName': 'EX0stasis',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV8nwYeIBQvrJBYDtoKveej_ycvIpxf4_v31wD8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3zy6WyG2C-TbKOm07dtFsw',
#        'authorChannelId': {'value': 'UC3zy6WyG2C-TbKOm07dtFsw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2023-02-16T22:01:39Z',
#        'updatedAt': '2023-02-16T22:01:39Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xaJSMXaADW-J95JOuwWX_kcaOP8',
#    'id': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0i522ADG3HIzQoJ4qTn8Vvjb2O8',
#      'id': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I have absolutely always hated Gmail&#39;s label system. It&#39;s absurd and for storing/archiving it&#39;s not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.',
#       'textOriginal': "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.",
#       'authorDisplayName': 'Andrew',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXgOF2PBNNFcIpx_fIcRowm7Ms_uEG7sdZT9va5UMI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCAn4RYo186_C7tSFAf0t2kw',
#       'authorChannelId': {'value': 'UCAn4RYo186_C7tSFAf0t2kw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 31,
#       'publishedAt': '2023-02-25T03:52:18Z',
#       'updatedAt': '2023-02-25T03:52:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'qikvgeMYQryG67vTLdUMRFfW6xc',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mjcbTKxw-A',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I have a Gmail account because of my phone and YT. I rarely check it.<br>I have a Yahoo account that has folders.<br>I don&#39;t really use email when communicating with people.',
#        'textOriginal': "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Free The Birds',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUK2ALJsTFq4NKdNR-BmlbbfPaPJuMkwu9mpM5f=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSV6jnfVxnnvLNvF2nqFekA',
#        'authorChannelId': {'value': 'UCSV6jnfVxnnvLNvF2nqFekA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T01:07:22Z',
#        'updatedAt': '2023-03-02T01:07:22Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jvYzEtx4XarNprRySPc1cXDfHBw',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mfYGE_Ndg8',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'textOriginal': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Angel Heart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVROIsdUQOtJXZr5barH2HdsiXY4T1amDs0r4gA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCn-KTNRp5EMTTn6h9SF5fRg',
#        'authorChannelId': {'value': 'UCn-KTNRp5EMTTn6h9SF5fRg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T11:03:41Z',
#        'updatedAt': '2023-02-28T11:03:41Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'iQzf_na3euqi2ZOM9CMGpPYUlnU',
#    'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8tNygM0tAdT_cKl4o7XgH76JFyY',
#      'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It’s not just the fear of slight change, it’s the fear of replacement',
#       'textOriginal': 'It’s not just the fear of slight change, it’s the fear of replacement',
#       'authorDisplayName': 'None',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/9XcEpHlQrJoCoDWLAIPetWzxFu9Vp9UrtfWEW2liRJzjEBdXoM72l_HW9vXeIE5oBVojAymz=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoFE_65rwBOgtEfDj98w82A',
#       'authorChannelId': {'value': 'UCoFE_65rwBOgtEfDj98w82A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 73,
#       'publishedAt': '2023-02-23T05:37:27Z',
#       'updatedAt': '2023-02-23T05:37:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 't4aAHIiu3M50BAHye_KVlJ6Qw68',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9mutyZ4S2-9',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Oh?  Is that what I&#39;ve been suffering for the past nearly decade now?  Fantastic.',
#        'textOriginal': "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': 'Opterongeek',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVt4yeJJW8np-XYDvUBkAz5-TYroFVAy0eH8A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCvyTrDkATleMxCT8tW2NP_Q',
#        'authorChannelId': {'value': 'UCvyTrDkATleMxCT8tW2NP_Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-06T10:10:43Z',
#        'updatedAt': '2023-03-06T10:10:43Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'cVAnuwEQxSVJJYSveKfNuLWIgYk',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9muYLYpnSdE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'i am a 3D art student , and i can already feel it.<br><br>My futurer is focked even before starting out',
#        'textOriginal': 'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': "L' Avatr",
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWYJkeGxxqizDjFaNcOF2GEsfvlr2_muttabFtL3VAfOLSLSMpGUeSZsZYSNrAw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCKQdDASvGZdd8wCDPfXEfDQ',
#        'authorChannelId': {'value': 'UCKQdDASvGZdd8wCDPfXEfDQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-03-06T06:53:01Z',
#        'updatedAt': '2023-03-06T06:53:01Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'RkgjVNsnQh0SlOF4wTG_ti8N2Ks',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9mV_maTEEQ0',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'no, it&#39;s a fear of how big brother will use it to kill me somehow',
#        'textOriginal': "no, it's a fear of how big brother will use it to kill me somehow",
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': 'J P',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWXJ1yr-owZKFEVGL72vwhCCEThE6qxL16KeWwD0Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCbyLSBHiXk-CM1iJ1q4KR7A',
#        'authorChannelId': {'value': 'UCbyLSBHiXk-CM1iJ1q4KR7A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 8,
#        'publishedAt': '2023-02-24T04:54:04Z',
#        'updatedAt': '2023-02-24T04:54:04Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'andAvKyV1XHzBX-TKWsvdfijbw0',
#    'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M7QKPO9u4Aj240J4Bit3v3fTvOE',
#      'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I&#39;m shook. I asked it &quot;Write me an AutoHotkey script to adjust the volume with the arrow keys.&quot; Not only did it do that, but it also mapped a key to mute, which I wasn&#39;t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it&#39;s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'textOriginal': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'authorDisplayName': 'Osprey850glt',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUAC8KRCtcYqrnM4kMwsC9xuCs-jg_Fo7TYUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzDXZwQZHFdbyNZPTujX7qg',
#       'authorChannelId': {'value': 'UCzDXZwQZHFdbyNZPTujX7qg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 23,
#       'publishedAt': '2023-02-24T13:46:02Z',
#       'updatedAt': '2023-02-24T13:46:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'fGhh8yiDp2FOhKOaWknrplmpJ3U',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519msyeMeUvrB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@User_guy Maybe. If that&#39;s the case, all it&#39;ll do is most likely make private, proprietary languages more commonplace. Which isn&#39;t a bad thing if security becomes a real concern.',
#        'textOriginal': "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Jared Lilley',
# ...
#        'textOriginal': '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'kerawoot',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW4h9rUtOmjNGWmnoDd6_9orK_qlSPbpkO-PQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCNnH0GyEyWNgfWrhRQPMv8g',
#        'authorChannelId': {'value': 'UCNnH0GyEyWNgfWrhRQPMv8g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-22T16:30:36Z',
#        'updatedAt': '2023-02-22T16:30:36Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '7on_v4b0AK-9O_nkeYpGsoYEqgc',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPZ_zdZWDx',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m more concerned  that &quot;anyone&quot; who learns how to &quot;use&quot; the system (chatgtp) will be (potentially) deemed as &quot;competent and confident&quot; in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? &quot;Beware of virtues not earned&quot;',
#        'textOriginal': 'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Stephen Soles',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUxiymoUXElrOQ9z5aPpOPmNKH0NkzUTF0sAg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCylX_6xby1oprDADijbUygA',
#        'authorChannelId': {'value': 'UCylX_6xby1oprDADijbUygA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 10,
#        'publishedAt': '2023-02-21T20:48:10Z',
#        'updatedAt': '2023-02-21T20:48:10Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'dPX8WNC1ytvdPzuc_8-q6qQsfa8',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPRChqxhsI',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'textOriginal': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Walter Stuart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUyECuSdNoTm7z1R92QbaFe5byP_iVSQBaDJenevg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCugvk8-W3vm2P54-9bPxzdA',
#        'authorChannelId': {'value': 'UCugvk8-W3vm2P54-9bPxzdA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T19:34:56Z',
#        'updatedAt': '2023-02-21T19:34:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xk7LNXNUTNd_FOVyE6HGnQVpAf0',
#    'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DkR5QQxxZ6Mxyax4b_vcMcW8ewE',
#      'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. <br>What scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. <br>We have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#       'textOriginal': 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#       'authorDisplayName': 'mikedbarkerhotmail',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXeT98b9sQSI00R49YYSt9S1H4DOPTyAyh9Dg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-rteK65rnTbM1ORE3KDNaw',
#       'authorChannelId': {'value': 'UC-rteK65rnTbM1ORE3KDNaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 14,
#       'publishedAt': '2023-02-26T06:49:08Z',
#       'updatedAt': '2023-02-26T06:49:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Xkca5ZeRDFq4EbUP8_z6LQNeMP0',
#    'id': 'UgxCBVlGX1tCiiyNijF4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1TnJeu7k2nW7nH1NIbmMdCnpXXY',
#      'id': 'UgxCBVlGX1tCiiyNijF4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#       'textOriginal': 'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#       'authorDisplayName': 'DailyFrankPeter',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW6L5pp7Zuvhb0n6KbMbGykwSFC0-qCO3Rs4g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSsJOA51ew3nf6PZ99xgT2g',
#       'authorChannelId': {'value': 'UCSsJOA51ew3nf6PZ99xgT2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 12,
#       'publishedAt': '2023-02-22T17:07:06Z',
#       'updatedAt': '2023-02-23T00:36:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'lSo5SlZZWUzJbFchoHxTAJoSf4k',
#       'id': 'UgxCBVlGX1tCiiyNijF4AaABAg.9mRk4jtEmC59mlcF8TyiKS',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'That&#39;s a weird spelling of &quot;paid-a-cent Indians and Africans&quot; right there',
#        'textOriginal': 'That\'s a weird spelling of "paid-a-cent Indians and Africans" right there',
#        'parentId': 'UgxCBVlGX1tCiiyNijF4AaABAg',
#        'authorDisplayName': 'AmaçsızBirKişi',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXRmfAm8pPI28Vj_YeZFJX3Nh5CtYshCHmv9ER2hvazzbOHLJx4XYHAAjxkK6SX=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC5jl2bvbsUw2xbAtcL0ofIg',
#        'authorChannelId': {'value': 'UC5jl2bvbsUw2xbAtcL0ofIg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-03-02T19:42:40Z',
#        'updatedAt': '2023-03-02T19:42:40Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nuoKliP2YNE6P2XgA4LmD1cwGp8',
#    'id': 'Ugzo8t4hOlw3FIJft5h4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'i-oXIV1S2Hoa_IfuYZHxHF8hYsk',
#      'id': 'Ugzo8t4hOlw3FIJft5h4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Thank you. I&#39;ve been getting a similar feeling and I think I&#39;m even more out of date tech-wise. I worry most about my kids. They are getting close to adulting and I wonder what their lives, and jobs, will look like ten years on.',
#       'textOriginal': "Thank you. I've been getting a similar feeling and I think I'm even more out of date tech-wise. I worry most about my kids. They are getting close to adulting and I wonder what their lives, and jobs, will look like ten years on.",
#       'authorDisplayName': 'Jeff Nichols',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUMdj6X0k0sHKlgrCtbvwTOtCJUn6T3dwS9z6bbLw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJOAxXLszZgL30IGiYlTjIw',
#       'authorChannelId': {'value': 'UCJOAxXLszZgL30IGiYlTjIw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 11,
#       'publishedAt': '2023-02-21T06:33:21Z',
#       'updatedAt': '2023-02-21T06:33:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'd4W9LGUiGnkHYXk-OJEF6gPl2dc',
#       'id': 'Ugzo8t4hOlw3FIJft5h4AaABAg.9mO1lCGEzcD9mawCNZsJeY',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Lily Gazou You get it. Unfortunately, they will try to ban anything that could make you self-sufficient. There will be endless regulations to make it impossible to keep animals, grow food or own land -- and it&#39;s already started.',
#        'textOriginal': "@Lily Gazou You get it. Unfortunately, they will try to ban anything that could make you self-sufficient. There will be endless regulations to make it impossible to keep animals, grow food or own land -- and it's already started.",
#        'parentId': 'Ugzo8t4hOlw3FIJft5h4AaABAg',
#        'authorDisplayName': 'SquareRootOf2',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWKJthM46qQfAiPWTMRB-UD3ELp9jdQLXOYkvL7zQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCfOz0CmTzq6kax-kU49PDQw',
#        'authorChannelId': {'value': 'UCfOz0CmTzq6kax-kU49PDQw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T16:05:24Z',
#        'updatedAt': '2023-02-26T16:05:24Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'qRazalGLK0y80lI7RMZu3ixFlgU',
#       'id': 'Ugzo8t4hOlw3FIJft5h4AaABAg.9mO1lCGEzcD9mVUV4oC8Ds',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Farming is the future.',
#        'textOriginal': 'Farming is the future.',
#        'parentId': 'Ugzo8t4hOlw3FIJft5h4AaABAg',
#        'authorDisplayName': 'Lily Gazou',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/5EpTA9KxbD3lsipxfo2uMvJxkIk-x7K3FndJK9pGEDtJnuc6b5s4QpckE9gc79B9-SBrC5qPFA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCz8Ju2ZXRBPDQNSREFxrhwg',
#        'authorChannelId': {'value': 'UCz8Ju2ZXRBPDQNSREFxrhwg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-24T03:59:06Z',
#        'updatedAt': '2023-02-24T03:59:06Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'NjXEvTL0JJdO13NCFBMeF0hIrSk',
#       'id': 'Ugzo8t4hOlw3FIJft5h4AaABAg.9mO1lCGEzcD9mRpO8OuPNx',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'im turning 18 next month, was planning to become a teacher but now i&#39;m worried i&#39;ll be completely out of tech',
#        'textOriginal': "im turning 18 next month, was planning to become a teacher but now i'm worried i'll be completely out of tech",
#        'parentId': 'Ugzo8t4hOlw3FIJft5h4AaABAg',
#        'authorDisplayName': 'Amélie',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVX3vyXLIM-zl33z1O6SmFSzg58SqXKBX-f8zhkLA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCbu729LZb3Wqn9QJIsJE-xA',
#        'authorChannelId': {'value': 'UCbu729LZb3Wqn9QJIsJE-xA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-02-22T17:53:26Z',
#        'updatedAt': '2023-02-22T17:53:26Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cgalluVi5wCUvst4j1L0sStJmCo',
#    'id': 'UgxiF9QUVAfQA6pfq4V4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xsitFzJazYJibKOuKcO2y39_7Is',
#      'id': 'UgxiF9QUVAfQA6pfq4V4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It&#39;s easy to turn the machine off and face life for what it really is; authentic, challenging and even miserable at times.',
#       'textOriginal': "It's easy to turn the machine off and face life for what it really is; authentic, challenging and even miserable at times.",
#       'authorDisplayName': 'TheMajesticalAncient',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVt0MMTE-8oGL5J__GzMDMI68lOvykSif-NwEH6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCjAZQ_yF3mrsqPGeC7faggA',
#       'authorChannelId': {'value': 'UCjAZQ_yF3mrsqPGeC7faggA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 17,
#       'publishedAt': '2023-02-21T06:59:42Z',
#       'updatedAt': '2023-02-21T06:59:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JgB-uy2OK6X0kZ2Tm_pfViXYvm4',
#    'id': 'UgzTEERz6O0W8SWc2Rd4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7etyRScrxzwkzgjOpScbPuKcp44',
#      'id': 'UgzTEERz6O0W8SWc2Rd4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Thanks for putting into words something I&#39;ve felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!',
#       'textOriginal': "Thanks for putting into words something I've felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!",
#       'authorDisplayName': 'Arron Artikai',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJU7OxRVa6DkOyCIqD8EvMhB0mF99fK9gltNqEn45sg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCxBttQLnCFCrdBvtWIw1lXg',
#       'authorChannelId': {'value': 'UCxBttQLnCFCrdBvtWIw1lXg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2023-02-24T05:15:49Z',
#       'updatedAt': '2023-02-24T05:15:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
videoId = []
comment = []
author = []
authorChannelUrl = []
likeCount = []
publishedAt = []

# %%
for j in range(len(response_comments['items'])):
    videoId.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['videoId'])
    comment.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['textOriginal'])
    author.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
    authorChannelUrl.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['authorChannelUrl'])
    likeCount.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['likeCount'])
    publishedAt.append(response_comments['items'][j]['snippet']['topLevelComment']['snippet']['publishedAt'])

# %%
print(videoId)
print(len(response_comments))
print(comment)
print(len(response_comments['items']))
# Out:
# ['jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA', 'jPhJbKBuNnA']
# 5
# ["For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.", '"Tom Scott tries to predict the future, 2023, colorized."\n\nIn a few years Tom should do a prediction compilation and see how many he got right.', "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.", "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...", 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.', "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.", "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.", 'It’s not just the fear of slight change, it’s the fear of replacement', 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.', '"Wait, I should be able to code this!"-\nSaid by every programmer who doesn\'t know what they\'re getting themselves in to', 'A random ChatGPT prompt to test the ability of the program: Write a joke about a rat and an umbrella\n\nChatGPT response: Why did the rat take an umbrella to work?\n\nBecause it was raining cats and dogs.\n\nMe: Mind Blown!', "“I'm not scared of a computer passing the Turing Test. I'm terrified of one that intentionally fails it.”", 'Dude I remember watching that old KSI clip of him interacting with Cleverbot and laughing at how stupid it was. To see something like GPT3 and the results in can produce has been sobering to say the least', 'I remember Napster..... I worked there.', "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.", 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it t ...
# 20

# %%
comment
# Out:
# ["For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#  '"Tom Scott tries to predict the future, 2023, colorized."\n\nIn a few years Tom should do a prediction compilation and see how many he got right.',
#  "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#  "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#  'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#  "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.",
#  "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.",
#  'It’s not just the fear of slight change, it’s the fear of replacement',
#  'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#  '"Wait, I should be able to code this!"-\nSaid by every programmer who doesn\'t know what they\'re getting themselves in to',
#  'A random ChatGPT prompt to test the ability of the program: Write a joke about a rat and an umbrella\n\nChatGPT response: Why did the rat take an umbrella to work?\n\nBecause it was raining cats and dogs.\n\nMe: Mind Blown!',
#  "“I'm not scared of a computer passing the Turing Test. I'm terrified of one that intentionally fails it.”",
#  'Dude I remember watching that old KSI clip of him interacting with Cleverbot and laughing at how stupid it was. To see something like GPT3 and the results in can produce has been sobering to say the least',
#  'I remember Napster..... I worked there.',
#  "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.",
#  'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#  'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#  "Thank you. I've been getting a similar feeling and I think I'm even more out of date tech-wise. I worry most about my kids. They are getting close to adulting and I wonder what their lives, and jobs, will look like ten years on.",
#  "It's easy to turn the machine off and face life for what it really is; authentic, challenging and even miserable at times.",
#  "Thanks for putting into words something I've felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!"]

# %%
nextPageToken = 0
for i in range(2):
    nextPageToken = response_comments['nextPageToken']
    for j in range(len(response_comments['items'])):
        response_snippet = response_comments['items'][j]['snippet']['topLevelComment']['snippet']
        videoId.append(response_snippet['videoId'])
        comment.append(response_snippet['textOriginal'])
        author.append(response_snippet['authorDisplayName'])
        authorChannelUrl.append(response_snippet['authorChannelUrl'])
        likeCount.append(response_snippet['likeCount'])
        publishedAt.append(response_snippet['publishedAt'])
    request_comments = youtube.commentThreads().list(
        part="snippet, replies",
        order="relevance",
        videoId=list_videos_id[0], 
        pageToken= nextPageToken)
    response_comments = request_comments.execute()

# %%
comment
# Out:
# ["For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#  '"Tom Scott tries to predict the future, 2023, colorized."\n\nIn a few years Tom should do a prediction compilation and see how many he got right.',
#  "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#  "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#  'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#  "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.",
#  "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.",
#  'It’s not just the fear of slight change, it’s the fear of replacement',
#  'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#  '"Wait, I should be able to code this!"-\nSaid by every programmer who doesn\'t know what they\'re getting themselves in to',
#  'A random ChatGPT prompt to test the ability of the program: Write a joke about a rat and an umbrella\n\nChatGPT response: Why did the rat take an umbrella to work?\n\nBecause it was raining cats and dogs.\n\nMe: Mind Blown!',
#  "“I'm not scared of a computer passing the Turing Test. I'm terrified of one that intentionally fails it.”",
#  'Dude I remember watching that old KSI clip of him interacting with Cleverbot and laughing at how stupid it was. To see something like GPT3 and the results in can produce has been sobering to say the least',
#  'I remember Napster..... I worked there.',
#  "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.",
#  'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#  'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#  "Thank you. I've been getting a similar feeling and I think I'm even more out of date tech-wise. I worry most about my kids. They are getting close to adulting and I wonder what their lives, and jobs, will look like ten years on.",
#  "It's easy to turn the machine off and face life for what it really is; authentic, challenging and even miserable at times.",
#  "Thanks for putting into words something I've felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!",
#  "For the record, you're definitely not the only one annoyed by Gmail labels, there's dozens of us!\nAnd as an aside i too, got the same feeling, so if you're wrong, you won't be the only one.",
#  '"Tom Scott tries to predict the future, 2023, colorized."\n\nIn a few years Tom should do a prediction compilation and see how many he got right.',
#  "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#  "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#  'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#  "I love Tom Scott's dedication to do a one take for each segment. It's very difficult for those who haven't done it before.",
#  "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.",
#  'It’s not just the fear of slight change, it’s the fear of replacement',
#  'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#  '"Wait, I should be able to code this!"-\nSaid by every programmer who doesn\'t know what they\'re getting themselves in to',
#  'A random ChatGPT prompt to test the ability of the program: Write a joke about a rat and an umbrella\n\nChatGPT response: Why did the rat take an umbrella to work?\n\nBecause it was raining cats and dogs.\n\nMe: Mind Blown!',
#  "“I'm not scared of a computer passing the Turing Test. I'm terrified of one that intentionally fails it.”",
#  'Dude I remember watching that old KSI clip of him interacting with Cleverbot and laughing at how stupid it was. To see something like GPT3 and the results in can produce has been sobering to say the least',
#  'I remember Napster..... I worked there.',
#  "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.",
#  'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. \nWhat scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. \nWe have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
#  'Interesting to know that Google, with their notorious interviews aimed at filtering out everyone but math geniuses and coding demigods, also have bugs like these.',
#  "Thank you. I've been getting a similar feeling and I think I'm even more out of date tech-wise. I worry most about my kids. They are getting close to adulting and I wonder what their lives, and jobs, will look like ten years on.",
#  "It's easy to turn the machine off and face life for what it really is; authentic, challenging and even miserable at times.",
#  "Thanks for putting into words something I've felt but not been able to articulate. It feels like this is a napster moment to me, but X10000 in its capacity for a tsunami like impact across all of society. Buckle up!",
#  'I am fascinated how Tom can talk non stop with such perfect structure and occasional timely jokes.',
#  'When a Tom Scott video is longer than 6 minutes you know gets going to be deep.',
#  "Well for me ChatGPT failed. Miserably! The code it generated wasn't specific enough and had an obvious logical error. When I told it to fix the error it correctly explained to me what the error was but then wrote a new piece of code that was different but had exactly the same logical error.",
#  'As a uni student, I use it more than google now. It saves so much time and is able to do so much. It helped me rephrase my essay in different tones, and even helped me find references for particular facts in my essay. Today it helped me write an email to a professor, and with just a bit of tweeking, I sent it off.',
#  "i love how the second message tom sends to chatgpt , he says 'please' even when talking to robots with no sentience, a true brit is always polite",
#  'Fifty years ago I remember occasionally seeing in movies and on TV actors moving through a museum and there would be artists with their easels set up in front of paintings, I assume they would learning how to duplicate the techniques, so this is not just AIs learning this way.',
#  'the fact that you can reason with the code and point out its errors and it will fix them is both fascinating and terrifying to me',
#  "I remember having problems like this, but I found the solution. In fact, it's right behind you in this video.",
#  "As someone young and soon going to start university, I'm excited of what kind of technology is yet to come but there's always been one question on my mind. As these AIs become more advanced, so do their potential to cause harm. How are developers going to implement ethical guidelines without hindering the AI's functionality? It seems like no matter what guidelines they put in place there will always be a way around them whether that is through prompt engineering or outright hacking.",
#  'I used CGPT to write a cover letter for a job I was applying for, had to make some minor changes to make it more personalized and relevant for me but hey I got the job',
#  'Tom you have to look at it this way... As a struggling artist/creator this video game me hope and kinda "cured" my depression that the biggest opportunities for me are still to come. Be graceful about all what you have achieved. Not many have inspired millions and stayed true and pure in their way like you did. Things always change so lets welcome it and make the best out of it!',
#  'these sorts of shifts are exactly why its smart for successful creators to be frugal, even if theyre wildly successful. there is nothing money can buy that is greater in functional value than securing the ability to spend your entire life on your own terms.',
#  'Great video, hard not to think of all those who dismissively said “Learn to code” when technology started replacing jobs in the 90s.',
#  "It has been few years since I have had this take on real and artificial and that is that anything artificial is completely natural as well. Animals are smart enough to use tools and if they were as smart enough as us or be the dominant species, they would just do what we do and more but that being said, so far everything had a pinch of humanity behind it. Someone who has made a factory and automated his work, shows how smart or lazy that person is. Someone online that you text with could be at most a catfish and a pretender but still a human behind that interface. Every piece of art that has been made is either motivated by creative vision, experiences or heck even statistics filled with corporate greed but what really shook me is that though it may be far, we are reaching a point where almost no human interaction would even be needed to satisfy your needs, wants or getting things done. We listen to music and consume arts by discovering them, we like certain artists, we dislike others but if we are in an era where we wont be bothered by it even. We just wish for whatever experience, song, art etc we desire and we just experience it through a library of everything that exists. Your favorite song being the one that no human wrote for example. It feels like anyone beyond a certain point who did something creative and groundbreaking would only be trivial in the future if we even consider it important and share the same sentiments we do today. It feels like we are running out of time to make our mark in the world and there isn't even a guarantee if we even will choose to keep those marks!",
#  'I’m glad I’m not the only one feeling the dread. As a designer AND comms specialist, I’m feeling it on all sides.',
#  "Oh it's absolutely crazy. I work in tech, programming, config, design. I already expect my job to disappear within 5 to 10 years.\nIn essence, all computer programming is translation. You are translating natural language into machine language. You translate a list of requirements in english, to a set of  instructions in C/Python/Perl/whatever, which then gets translated into machine code by the assembler. \nBut if the computer could directly understand natural language?  If you could simply ask it to do things in english?\nThat makes virtually all programming jobs obsolete. Why would you need a translator or an interpreter if the machine can already understand you?",
#  'I know this wasn\'t the point you were making but in the back of my mind I kept thinking of the Douglas Adams quote: \n"I\'ve come up with a set of rules that describe our reactions to technologies:\n1. Anything that is in the world when you’re born is normal and ordinary and is just a natural part of the way the world works.\n2. Anything that\'s invented between when you’re fifteen and thirty-five is new and exciting and revolutionary and you can probably get a career in it.\n3. Anything invented after you\'re thirty-five is against the natural order of things."',
#  "Oh heck... I was a research analyst for Gartner and that was just about an everyday experience.  You get used to it eventually, and then you get scared when it isn't happening, because THAT means you aren't paying enough attention.",
#  "I have spent the last few days trying to figure out how to label my emails so that I can batch delete the ones I don't want. I appreciate this information on how the labels work. They aren't great...",
#  "I am taking a uni course in verilog in my BSEE and ChatGPT came out. I was curious, so I tried getting it to do a bunch of different verilog/system verilog programs. It does amazing and explains everything it does and even includes state diagrams without me asking. \n\nI've decided not to pursue that pathway any longer."]

# %%
response_comments
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'ZGp1ImCIAuPSZlNrqpepYBO8Q6Y',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'ZcGg2gGNIM1P7V6cfIThZqMFOe4',
#    'id': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DKcLrWB5z1L-Xj78XJLTXDth9Ks',
#      'id': 'UgxIZQ8lca0JURrNUh54AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I am fascinated how Tom can talk non stop with such perfect structure and occasional timely jokes.',
#       'textOriginal': 'I am fascinated how Tom can talk non stop with such perfect structure and occasional timely jokes.',
#       'authorDisplayName': 'Vasyl Boroviak',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVq5ochLl1nlgpmHPY7tZXHoffx1iExAs9F_lOuoq0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnvs76Ee8-1qizTckD2eDzw',
#       'authorChannelId': {'value': 'UCnvs76Ee8-1qizTckD2eDzw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 4051,
#       'publishedAt': '2023-02-14T12:28:45Z',
#       'updatedAt': '2023-02-14T12:28:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 40,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'iy8SW9Nh2lhULpZ0L1N5mwuz01I',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mdk9CUTT1B',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#        'textOriginal': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'dave bento',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWuKBEeloJWn9qyihl91FmBPELGc_HMlKHrYA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCWloOVPTGKatWGnQ8Y1xSMw',
#        'authorChannelId': {'value': 'UCWloOVPTGKatWGnQ8Y1xSMw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T18:17:50Z',
#        'updatedAt': '2023-02-27T18:17:50Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'PAsFcesPIqaVpQEKgpFAzcZxZLc',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mSCn6_xlby',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Senk Ju silenced him easily😂',
#        'textOriginal': '\u200b@Senk Ju silenced him easily😂',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'ilikefish',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/eeNJUft4-VIGopnmUTEF9CIk5aPYUZ9lO9zy7ehVRwqV2rU48zysEOrQg1SME99ZhZK8bopR=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCck_-AOidzq6l6ahgAB4Lhw',
#        'authorChannelId': {'value': 'UCck_-AOidzq6l6ahgAB4Lhw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-22T21:26:42Z',
#        'updatedAt': '2023-02-22T21:26:42Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '4_mc-YDtru8hJ3Ig37oCES23y8E',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mQOr66qurE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Mark Koetsier No more than you or I ..',
#        'textOriginal': '@Mark Koetsier No more than you or I ..',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'blucat4',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/5TlLhyJYqELPzlpo9WcGF5WSMqUEgw5wmiqD5N4-dcKvKEVLG3r9737g2zMCse8hmOeYfQzu=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCmkhEsnWvK1TIcSJ0UlaGbg',
#        'authorChannelId': {'value': 'UCmkhEsnWvK1TIcSJ0UlaGbg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-22T04:33:37Z',
#        'updatedAt': '2023-02-22T04:33:37Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'DpQlpgeS-DtZNMs67SW6aGxMwCQ',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mPkVG_WNnU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Tom is a bot.',
#        'textOriginal': 'Tom is a bot.',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'Mark Koetsier',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVy6_TL3RimhGIwWNHnLyQovLSbcr5v0MuCsg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCNIEj7-_Qx5OH3dEeWlBJWQ',
#        'authorChannelId': {'value': 'UCNIEj7-_Qx5OH3dEeWlBJWQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T22:32:14Z',
#        'updatedAt': '2023-02-21T22:32:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G1_AgiGTw8uXFzKW7UWbNyihEuY',
#       'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mNpSGX4Ov6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#        'textOriginal': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#        'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#        'authorDisplayName': 'Create A. Googleaccount',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZ_JPg7xHQ_i7F8TXeiHyMpffOusPB_25fknHN1EXqlv1G2O5MPkWnvYBK4FBC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UChteANI-UpaQfvWDNOPDD-w',
#        'authorChannelId': {'value': 'UChteANI-UpaQfvWDNOPDD-w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-21T04:37:02Z',
#        'updatedAt': '2023-02-21T04:37:02Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NGYnJWX6dwe0X6J7TQg3bt2dAkU',
#    'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DoC_mlAxnTIazIEXepZtV0504VA',
#      'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'textOriginal': 'As someone who uses a lot of these tools, I can tell you confidently that we are at the VERY beginning of the curve.',
#       'authorDisplayName': 'Derek Woods',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXR6puczs1o9QoBYjEitYikAe1ovkGY0p_K5Az3ml8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChgSMVDswJwip74E_DZDSEg',
#       'authorChannelId': {'value': 'UChgSMVDswJwip74E_DZDSEg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 620,
#       'publishedAt': '2023-02-22T04:38:15Z',
#       'updatedAt': '2023-02-22T04:38:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 15,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'hjofvp_8QFP9ZbI-n_ySjGePFOE',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9moYztAFcEa',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Peppermint Gal Why does he think the potential is limited? I&#39;m asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don&#39;t see any reason to be sceptical about the emergence of AGI within the next decade.',
#        'textOriginal': "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Max Khovanski',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWvX3RvAGYM1tcr3lKfBBXIpU9qC8V_CDoQSIMHgtI=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC3CmO-Mxq9f1xte8iePKq_w',
#        'authorChannelId': {'value': 'UC3CmO-Mxq9f1xte8iePKq_w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-03T23:03:13Z',
#        'updatedAt': '2023-03-03T23:03:13Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'eiL4eGymqC_lCVb0ZBCynlLnZmo',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9moOeD3LZA6',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Peppermint Gal<br>Wrong. The current danger of chat GPT isn&#39;t just writing code on its own. The main danger isn&#39;t allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.<br><br>This will lead to massive layoffs in the tech industry. The only question is when.',
#        'textOriginal': "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': '101IQ',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVGWqRtgMUxqd6jdaZT3Zdk3sGhBojSBLSOBhUmt38kbA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCJtym3nRvJCv1VKeQv8KngQ',
#        'authorChannelId': {'value': 'UCJtym3nRvJCv1VKeQv8KngQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-03T21:32:52Z',
#        'updatedAt': '2023-03-03T21:32:52Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'RhH2endsfPjxJkfl7LLzMFHtVSI',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5b8BrO6S',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'textOriginal': '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-03-02T14:48:42Z',
#        'updatedAt': '2023-03-02T14:48:42Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'G_sjHyTBrSpba17x4DOESCfWv1k',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9ml5P86k_Yd',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m not actually sure about that. There&#39;s been a lot of sensationalism around this issue. I know someone who actually works <b>developing</b> this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.',
#        'textOriginal': "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'Peppermint Gal',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfcw4KD-JhjOMubmMrB6qdIDWo9y8AaGaIuIGC=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCwygB8wFhw2ps0I2LbbA6Eg',
#        'authorChannelId': {'value': 'UCwygB8wFhw2ps0I2LbbA6Eg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-03-02T14:46:56Z',
#        'updatedAt': '2023-03-02T14:46:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jFlnTZeXaynVPR0DrgknyvJ8q38',
#       'id': 'UgwvxiLvL6jjDRdb0-h4AaABAg.9mQPO-3WD0u9mYJMHmjlgB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@voidhawk79 You are also under the spell. Snap out of it.<br><br>it&#39;s programming. it predicts and responds as it is programmed to do. Nothing more.<br><br>It may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it&#39;s purpose is to gather data and grow that library), but in the end it&#39;s nothing more than programming. <br><br>The general public is a combination of uninterested and also under the spell.<br><br>The future is dark if enough people buy this BS as it&#39;s being advertised. The more people who buy it, the darker it is like to be.',
#        'textOriginal': "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#        'parentId': 'UgwvxiLvL6jjDRdb0-h4AaABAg',
#        'authorDisplayName': 'DRourk',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW7SABHTq6OgFqavy0M5hQbYPnl25U-n7vfEA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCL9mmOumcr-JtxtW6CzOakg',
#        'authorChannelId': {'value': 'UCL9mmOumcr-JtxtW6CzOakg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-25T06:19:31Z',
#        'updatedAt': '2023-02-25T06:19:31Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ki8VOrkusG7Em06Oh-WFBxH600Y',
#    'id': 'UgwXKDa8PdreepuhcOl4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-APHHkEZnQiERMeC4sxB0SLT_Ec',
#      'id': 'UgwXKDa8PdreepuhcOl4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'When a Tom Scott video is longer than 6 minutes you know gets going to be deep.',
#       'textOriginal': 'When a Tom Scott video is longer than 6 minutes you know gets going to be deep.',
#       'authorDisplayName': 'TheAngryOwl',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX6X0NHzGqXMbNnyk0goPkGtGGsbozbYxlzcQ0VCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgfgWtxpGrh46jZsoAInKlg',
#       'authorChannelId': {'value': 'UCgfgWtxpGrh46jZsoAInKlg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 22133,
#       'publishedAt': '2023-02-13T17:21:50Z',
#       'updatedAt': '2023-02-13T17:21:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 51,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'cXeYGm8SK8YgUJSiH6P-dLkwDBI',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19ms9hmeh3kA',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'He didn’t say anything. Waste of time',
#        'textOriginal': 'He didn’t say anything. Waste of time',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'RM',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXMc_xqOcfpCGGdIMyQ51edgBgSU-lG1FTKsc6lpljzAg1XTvDU93F9Gy0XCIy-BA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCqPTcSpFkiZouHclM4PvsrA',
#        'authorChannelId': {'value': 'UCqPTcSpFkiZouHclM4PvsrA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-05T08:39:15Z',
#        'updatedAt': '2023-03-05T08:39:15Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Swt5x9UEGoZ0S-BqeIwnktjXMc4',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19ms8-sPfV6h',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Wuptidooalways have been.. 😐',
#        'textOriginal': '@Wuptidooalways have been.. 😐',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'Trey Wilson',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVXWy3M-gZXN0kHbu6Z_DXPX7R0_TGY-uCknA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC84FIz8pmRBZFpiPDgSKIOQ',
#        'authorChannelId': {'value': 'UC84FIz8pmRBZFpiPDgSKIOQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-05T08:24:23Z',
#        'updatedAt': '2023-03-05T08:24:23Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'H0XoQquLeMk8KMNvdAt995cm8_0',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mkc_9m7ogz',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When i see a guy type geta onstead of its you know gets a illiterate person',
#        'textOriginal': 'When i see a guy type geta onstead of its you know gets a illiterate person',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'gmyxt555',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/IUL21_I2Hbd03BIjnm8xBfbo_qwuHCFe0zl5bKEUhWU4la196k3_SQ8uE7fyzpaphXquCTL0bg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSmj4Rg_v_vIAoLbDvXPWbQ',
#        'authorChannelId': {'value': 'UCSmj4Rg_v_vIAoLbDvXPWbQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T10:26:17Z',
#        'updatedAt': '2023-03-02T10:26:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'okej0qdTry3nhOqIZh8M_Uo9l9M',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19mbweYSIapQ',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'This was deep? He&#39;s just saying what everyone else is saying. You could go snorkelling at this level.',
#        'textOriginal': "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'mentalmelt',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUfANxyp9eKx7j05YUBZP8xJMqGqHhmbrmSe8MuHg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCw7Tf05hehRkX3XloSXA8hQ',
#        'authorChannelId': {'value': 'UCw7Tf05hehRkX3XloSXA8hQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-27T01:28:37Z',
#        'updatedAt': '2023-02-27T01:28:37Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '9qyC9T-g9dUEX5JUieMzcGcF9Hk',
#       'id': 'UgwXKDa8PdreepuhcOl4AaABAg.9m4abqG-Gj19maE8Y1I3qv',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'and mo cap',
#        'textOriginal': 'and mo cap',
#        'parentId': 'UgwXKDa8PdreepuhcOl4AaABAg',
#        'authorDisplayName': 'Rocket Bunny',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaSdf2aIgwKGEIsiAaFCX5ar_ZKxUVCQhOVDQs9A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCHvKaQYlzBCseI5VFAp1scA',
#        'authorChannelId': {'value': 'UCHvKaQYlzBCseI5VFAp1scA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-26T09:31:40Z',
#        'updatedAt': '2023-02-26T09:31:40Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'andAvKyV1XHzBX-TKWsvdfijbw0',
#    'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M7QKPO9u4Aj240J4Bit3v3fTvOE',
#      'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I&#39;m shook. I asked it &quot;Write me an AutoHotkey script to adjust the volume with the arrow keys.&quot; Not only did it do that, but it also mapped a key to mute, which I wasn&#39;t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it&#39;s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'textOriginal': 'This inspired me to see if ChatGPT could write an AutoHotkey script for me. I\'m shook. I asked it "Write me an AutoHotkey script to adjust the volume with the arrow keys." Not only did it do that, but it also mapped a key to mute, which I wasn\'t expecting, then explained in English what the code did and gave instructions for creating the script and running it. I had doubts that it could even help me with AutoHotkey at all, because it\'s a proprietary language for Windows (i.e. certainly not widespread like C++ or Python). This really is both awesome and scary.',
#       'authorDisplayName': 'Osprey850glt',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUAC8KRCtcYqrnM4kMwsC9xuCs-jg_Fo7TYUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzDXZwQZHFdbyNZPTujX7qg',
#       'authorChannelId': {'value': 'UCzDXZwQZHFdbyNZPTujX7qg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 23,
#       'publishedAt': '2023-02-24T13:46:02Z',
#       'updatedAt': '2023-02-24T13:46:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'fGhh8yiDp2FOhKOaWknrplmpJ3U',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519msyeMeUvrB',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@User_guy Maybe. If that&#39;s the case, all it&#39;ll do is most likely make private, proprietary languages more commonplace. Which isn&#39;t a bad thing if security becomes a real concern.',
#        'textOriginal': "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Jared Lilley',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/PKqVzMTF4yLHhFThnIDWXWuHYyPgDs7qB1hH67ZmEm6YX6aD0jsedvHgVOvr5vv8JwKTl2Wvgg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCYQjGsUpa6H9nguIQOz09og',
#        'authorChannelId': {'value': 'UCYQjGsUpa6H9nguIQOz09og'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-05T16:13:10Z',
#        'updatedAt': '2023-03-05T16:13:10Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'yd2HhRYTaHFSrLHHmf90x-MBJLA',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519mh7Q7bwzY_',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#        'textOriginal': 'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Pat',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUyotuhv_hKleS6qc2HxTGeirp8_4tn99WujhdyyQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCA5ln5Bl3_epk2qBIiwf8Vw',
#        'authorChannelId': {'value': 'UCA5ln5Bl3_epk2qBIiwf8Vw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-01T01:47:35Z',
#        'updatedAt': '2023-03-01T01:47:35Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'a0HhKYI7M0HLx6BM0CAymW5Aido',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519m_AZmzUxY3',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Dream come true for hackers?',
#        'textOriginal': 'Dream come true for hackers?',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'User_guy',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/XiAhFLhfgkqv-EoshWUZ7m_v7BJc3pkYpWQhLUJeo2zfyzRhf54Utpucs0kctmJGV2RPwBjr=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCOJ1PjK5GUmr4vEEKq2ralw',
#        'authorChannelId': {'value': 'UCOJ1PjK5GUmr4vEEKq2ralw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-25T23:41:11Z',
#        'updatedAt': '2023-02-25T23:41:11Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'fTivulGGhGyydyLMFDZ98Nriwdw',
#       'id': 'UgyH2Y_PagHs0Tlyzq94AaABAg.9mWXen-CY519mZb_jLyKJV',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'It literally knows how to code in the strangest programming languages, which is really cool.',
#        'textOriginal': 'It literally knows how to code in the strangest programming languages, which is really cool.',
#        'parentId': 'UgyH2Y_PagHs0Tlyzq94AaABAg',
#        'authorDisplayName': 'Stefan Maring',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVaWwVhJd4b89I3FG-ZM2HxsImMum9ejkUFUbhMQg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCK8_AQWiU_fWkba7oYWInDg',
#        'authorChannelId': {'value': 'UCK8_AQWiU_fWkba7oYWInDg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-02-25T18:26:45Z',
#        'updatedAt': '2023-02-25T18:26:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'iQzf_na3euqi2ZOM9CMGpPYUlnU',
#    'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8tNygM0tAdT_cKl4o7XgH76JFyY',
#      'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'It’s not just the fear of slight change, it’s the fear of replacement',
#       'textOriginal': 'It’s not just the fear of slight change, it’s the fear of replacement',
#       'authorDisplayName': 'None',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/9XcEpHlQrJoCoDWLAIPetWzxFu9Vp9UrtfWEW2liRJzjEBdXoM72l_HW9vXeIE5oBVojAymz=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoFE_65rwBOgtEfDj98w82A',
#       'authorChannelId': {'value': 'UCoFE_65rwBOgtEfDj98w82A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 73,
#       'publishedAt': '2023-02-23T05:37:27Z',
#       'updatedAt': '2023-02-23T05:37:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 't4aAHIiu3M50BAHye_KVlJ6Qw68',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9mutyZ4S2-9',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Oh?  Is that what I&#39;ve been suffering for the past nearly decade now?  Fantastic.',
#        'textOriginal': "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': 'Opterongeek',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVt4yeJJW8np-XYDvUBkAz5-TYroFVAy0eH8A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCvyTrDkATleMxCT8tW2NP_Q',
#        'authorChannelId': {'value': 'UCvyTrDkATleMxCT8tW2NP_Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-06T10:10:43Z',
#        'updatedAt': '2023-03-06T10:10:43Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'cVAnuwEQxSVJJYSveKfNuLWIgYk',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9muYLYpnSdE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'i am a 3D art student , and i can already feel it.<br><br>My futurer is focked even before starting out',
#        'textOriginal': 'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': "L' Avatr",
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWYJkeGxxqizDjFaNcOF2GEsfvlr2_muttabFtL3VAfOLSLSMpGUeSZsZYSNrAw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCKQdDASvGZdd8wCDPfXEfDQ',
#        'authorChannelId': {'value': 'UCKQdDASvGZdd8wCDPfXEfDQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2023-03-06T06:53:01Z',
#        'updatedAt': '2023-03-06T06:53:01Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'RkgjVNsnQh0SlOF4wTG_ti8N2Ks',
#       'id': 'Ugz1yXOlQj_yfPIVpc94AaABAg.9mT4xVGgMpt9mV_maTEEQ0',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'no, it&#39;s a fear of how big brother will use it to kill me somehow',
#        'textOriginal': "no, it's a fear of how big brother will use it to kill me somehow",
#        'parentId': 'Ugz1yXOlQj_yfPIVpc94AaABAg',
#        'authorDisplayName': 'J P',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWXJ1yr-owZKFEVGL72vwhCCEThE6qxL16KeWwD0Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCbyLSBHiXk-CM1iJ1q4KR7A',
#        'authorChannelId': {'value': 'UCbyLSBHiXk-CM1iJ1q4KR7A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 8,
#        'publishedAt': '2023-02-24T04:54:04Z',
#        'updatedAt': '2023-02-24T04:54:04Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'U6rNIoSp45KFPIAVaeSRXr7NqHI',
#    'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AEHkCbFb4hL5z6AWQFOONMkvjX0',
#      'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn&#39;t since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  <br>For me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. <br><br>I hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it&#39;s a damn efficient one.',
#       'textOriginal': "I had my existential crisis with that a while back. Now I use chatGPT to write, among others, shaders in unity for me. It quite heavily reduces my workload and sometimes simply can do stuff I couldn't since I miss the knowledge, but then I understand it when I see it explained and can then adapt or correct it in fine tuning so it fits. I learned a lot and at a faster rate than usual since I started doing that.  \nFor me it feels now like a tool that allows me to build what I imagine. The whole development process has been sped up noticeably. \n\nI hope I can use it to build a procedural animation system for movement, fighting and such. Something that would simply be out of scope by myself, but now might just be achievable. It generally allows for more complexity and viewed as a tool, it's a damn efficient one.",
#       'authorDisplayName': 'Hellequin Maskharat',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV4TStWLBcX8KCPERFSoQSJkqsCgsBq_fNyKl72mw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKB35F97OYM751A7ETu7ADw',
#       'authorChannelId': {'value': 'UCKB35F97OYM751A7ETu7ADw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 44,
#       'publishedAt': '2023-02-20T21:35:51Z',
#       'updatedAt': '2023-02-20T21:35:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': '-CUmROXHPnzVMZd5VdE5VpH3RI8',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mRfuPzcVaU',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.<br>at least its how it is the way people are using image generator right now.',
#        'textOriginal': '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'kerawoot',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW4h9rUtOmjNGWmnoDd6_9orK_qlSPbpkO-PQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCNnH0GyEyWNgfWrhRQPMv8g',
#        'authorChannelId': {'value': 'UCNnH0GyEyWNgfWrhRQPMv8g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-22T16:30:36Z',
#        'updatedAt': '2023-02-22T16:30:36Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '7on_v4b0AK-9O_nkeYpGsoYEqgc',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPZ_zdZWDx',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I&#39;m more concerned  that &quot;anyone&quot; who learns how to &quot;use&quot; the system (chatgtp) will be (potentially) deemed as &quot;competent and confident&quot; in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? &quot;Beware of virtues not earned&quot;',
#        'textOriginal': 'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Stephen Soles',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUxiymoUXElrOQ9z5aPpOPmNKH0NkzUTF0sAg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCylX_6xby1oprDADijbUygA',
#        'authorChannelId': {'value': 'UCylX_6xby1oprDADijbUygA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 10,
#        'publishedAt': '2023-02-21T20:48:10Z',
#        'updatedAt': '2023-02-21T20:48:10Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'dPX8WNC1ytvdPzuc_8-q6qQsfa8',
#       'id': 'UgyvsJTmTkeUrbGPseZ4AaABAg.9mN4FRfkCZt9mPRChqxhsI',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'textOriginal': 'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#        'parentId': 'UgyvsJTmTkeUrbGPseZ4AaABAg',
#        'authorDisplayName': 'Walter Stuart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUyECuSdNoTm7z1R92QbaFe5byP_iVSQBaDJenevg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCugvk8-W3vm2P54-9bPxzdA',
#        'authorChannelId': {'value': 'UCugvk8-W3vm2P54-9bPxzdA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-02-21T19:34:56Z',
#        'updatedAt': '2023-02-21T19:34:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LeVHHw96kMYr-v74YSOX5p2LtvM',
#    'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4MPcIcyhJ1eVRpr-GACxgEjZPiQ',
#      'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn&#39;t believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.',
#       'textOriginal': "I remember we would have computer classes in high school and when Napster came around we where loading our high schools computers hard drives with music. Our teachers couldn't believe they where actually listening to their favorite music for free ! During there breaks the teachers would be going in the computer class to listen to music. Something we had never seen before.",
#       'authorDisplayName': 'doobyboy21',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/j6Li8CLYzmclgYoMQJed-gABKHu8fPzeHhAloLb5MsMuQVCJeGSVnYJoHdj6_o0PC14Fj_MAYg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCEbRckbxiCDm7PgBuvQq1hQ',
#       'authorChannelId': {'value': 'UCEbRckbxiCDm7PgBuvQq1hQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 72,
#       'publishedAt': '2023-02-22T14:08:19Z',
#       'updatedAt': '2023-02-22T14:08:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'S0AsQgtlzg2AGU_73tyjzpBhxWI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgFaF694HA',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I remember my elementary school&#39;s teacher workroom being as smoky as a pool hall',
#        'textOriginal': "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Nolan McKinney',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJV-xoC7uaFWVo_TC7TJ7uzS6cInHa5DE6LYD5lAXw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCCbYhC1yPa-_r7nu1WzzGvA',
#        'authorChannelId': {'value': 'UCCbYhC1yPa-_r7nu1WzzGvA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T17:39:46Z',
#        'updatedAt': '2023-02-28T17:39:46Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jI3KEREhIV-0em0eAVQSmaCrFwo',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mgB1ZmjsRb',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David And once in a while some teacher came and chased away the under 16&#39;s who were caught smoking.',
#        'textOriginal': "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T16:59:56Z',
#        'updatedAt': '2023-02-28T16:59:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'yqdCbiypwGDgpu7YmBbVhQYKntc',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mWdWdjj6sE',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@David I laughed at that but then realized that so did we.',
#        'textOriginal': '@David I laughed at that but then realized that so did we.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'Are',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUH6Dhs4uaLTzHDjjg9_5TnwLVL5e7RAPwXi97w=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCzssRp9ZfPhRvOp_jz_LIrg',
#        'authorChannelId': {'value': 'UCzssRp9ZfPhRvOp_jz_LIrg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2023-02-24T14:45:56Z',
#        'updatedAt': '2023-02-24T14:45:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'uDYjqLu2L0cboAVMo6z2gxOOcqI',
#       'id': 'UgwTkKtb7nJ-s2PmKal4AaABAg.9mRQcG1FPQC9mUoQ_K55Kq',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'When I was in high school they had a designated smoking area for the kids.',
#        'textOriginal': 'When I was in high school they had a designated smoking area for the kids.',
#        'parentId': 'UgwTkKtb7nJ-s2PmKal4AaABAg',
#        'authorDisplayName': 'David',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXMjfel-oX_0QuvNkpLLAP-V9EVxAeo3blkOJDSsA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC4iF04W04tbSZwwsTc2kMsg',
#        'authorChannelId': {'value': 'UC4iF04W04tbSZwwsTc2kMsg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 11,
#        'publishedAt': '2023-02-23T21:42:45Z',
#        'updatedAt': '2023-02-23T21:42:45Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xaJSMXaADW-J95JOuwWX_kcaOP8',
#    'id': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0i522ADG3HIzQoJ4qTn8Vvjb2O8',
#      'id': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I have absolutely always hated Gmail&#39;s label system. It&#39;s absurd and for storing/archiving it&#39;s not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.',
#       'textOriginal': "I have absolutely always hated Gmail's label system. It's absurd and for storing/archiving it's not a functional system nor assures actual saving of messages like you said. It hurts my IT brain deeply.",
#       'authorDisplayName': 'Andrew',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXgOF2PBNNFcIpx_fIcRowm7Ms_uEG7sdZT9va5UMI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCAn4RYo186_C7tSFAf0t2kw',
#       'authorChannelId': {'value': 'UCAn4RYo186_C7tSFAf0t2kw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 31,
#       'publishedAt': '2023-02-25T03:52:18Z',
#       'updatedAt': '2023-02-25T03:52:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'qikvgeMYQryG67vTLdUMRFfW6xc',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mjcbTKxw-A',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'I have a Gmail account because of my phone and YT. I rarely check it.<br>I have a Yahoo account that has folders.<br>I don&#39;t really use email when communicating with people.',
#        'textOriginal': "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Free The Birds',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUK2ALJsTFq4NKdNR-BmlbbfPaPJuMkwu9mpM5f=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCSV6jnfVxnnvLNvF2nqFekA',
#        'authorChannelId': {'value': 'UCSV6jnfVxnnvLNvF2nqFekA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T01:07:22Z',
#        'updatedAt': '2023-03-02T01:07:22Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'jvYzEtx4XarNprRySPc1cXDfHBw',
#       'id': 'UgxTH0WiSLNfF7b0qx94AaABAg.9mY2W1fMOzi9mfYGE_Ndg8',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'textOriginal': 'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#        'parentId': 'UgxTH0WiSLNfF7b0qx94AaABAg',
#        'authorDisplayName': 'Angel Heart',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVROIsdUQOtJXZr5barH2HdsiXY4T1amDs0r4gA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCn-KTNRp5EMTTn6h9SF5fRg',
#        'authorChannelId': {'value': 'UCn-KTNRp5EMTTn6h9SF5fRg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-28T11:03:41Z',
#        'updatedAt': '2023-02-28T11:03:41Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xk7LNXNUTNd_FOVyE6HGnQVpAf0',
#    'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DkR5QQxxZ6Mxyax4b_vcMcW8ewE',
#      'id': 'Ugw2kyvf2j7WhebCERt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Actually I still have Napster. In the eighties and nineties, I worked on the tech that made the internet. What came from that was astounding. I had GPT on my desktop from the beginning. <br>What scares me it that it was evaluating its approaches and changing to get to a result. It is still brute force but it doesn’t take a great leap in imagination for it to self program and with the rise of quantum computing, we could be talking about exponential change. <br>We have been forcing it to map human structures of thought but there are near infinite amounts of structures that can be created. Most will fail but given time and power, what maybe possible is beyond anything that I can imagine. Not intelligence but something else.',
# ...
#       'id': 'UgxdFiFClNfoxLuXKNx4AaABAg.9m5L-Il_R_-9mL6PxGUR4b',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Mark Colville or try to ask gpt to prove riemann hypothesis. Haha. Gpt on the ropes. Knock out',
#        'textOriginal': '@Mark Colville or try to ask gpt to prove riemann hypothesis. Haha. Gpt on the ropes. Knock out',
#        'parentId': 'UgxdFiFClNfoxLuXKNx4AaABAg',
#        'authorDisplayName': 'quant2011',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVje5Ll16bLyaFvi5SQvIYeuMyt8FggRMCuig=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCkvPEwpN8LaTVzHqMtKiLUA',
#        'authorChannelId': {'value': 'UCkvPEwpN8LaTVzHqMtKiLUA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-20T03:16:17Z',
#        'updatedAt': '2023-02-20T03:16:17Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'MJ1HTkL_YsWfDLVYLQeFFeRQ3R4',
#       'id': 'UgxdFiFClNfoxLuXKNx4AaABAg.9m5L-Il_R_-9mJEHtN1g5f',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '\u200b@Mark Colville chat gpt cannot do math because mathematics has so many permutations for it to generalize the logic and concepts therein from its training. However, it can generalize almost all language based concepts, including programming language. You could say, based on our current understanding of consciousness, its about 10 percent as conscious as humans are.',
#        'textOriginal': '\u200b@Mark Colville chat gpt cannot do math because mathematics has so many permutations for it to generalize the logic and concepts therein from its training. However, it can generalize almost all language based concepts, including programming language. You could say, based on our current understanding of consciousness, its about 10 percent as conscious as humans are.',
#        'parentId': 'UgxdFiFClNfoxLuXKNx4AaABAg',
#        'authorDisplayName': 'hepzibah',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJURGsqOzl81qLOHYtptXGE8Va8GuzegU9BpcYfl=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCtdoEuI-cn21hnFTGjGykuA',
#        'authorChannelId': {'value': 'UCtdoEuI-cn21hnFTGjGykuA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-19T09:46:36Z',
#        'updatedAt': '2023-02-19T09:46:36Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hTv1_eGcjmvCK1SDDJZ_DHnECb8',
#    'id': 'UgwUneby5bLlJp7uYW14AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Lewn1a-eVy0pTklQfoXkuwaNc_E',
#      'id': 'UgwUneby5bLlJp7uYW14AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'i love how the second message tom sends to chatgpt , he says &#39;please&#39; even when talking to robots with no sentience, a true brit is always polite',
#       'textOriginal': "i love how the second message tom sends to chatgpt , he says 'please' even when talking to robots with no sentience, a true brit is always polite",
#       'authorDisplayName': 'JustBecause Gaming',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWrP2TGtPg3IJDIRAPg3IQBBzmWTVjEnw0ejUb0oQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCA4loyWvC_hkgbPSX7au9nA',
#       'authorChannelId': {'value': 'UCA4loyWvC_hkgbPSX7au9nA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-03-05T23:55:46Z',
#       'updatedAt': '2023-03-05T23:55:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CymXKLJn_WdZdBc_tuEoJgFjMKQ',
#    'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0DW2vGk-IyFENBQalNkVR_z4CFU',
#      'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what&#39;s comming...',
#       'textOriginal': "my exact feeling when my boss has shown us what it could do... and I was flabbergasted that they do not seem to understand the impact of what's comming...",
#       'authorDisplayName': 'Radosław Wujec',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXfAB7UdK9Eh2U05daFqhmx5m52Fo9r559w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSdT3nFciNpl9NpZXwPm5EQ',
#       'authorChannelId': {'value': 'UCSdT3nFciNpl9NpZXwPm5EQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 38,
#       'publishedAt': '2023-02-21T22:51:57Z',
#       'updatedAt': '2023-02-21T22:51:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'XDc_gIbReynzNiWUa1hFUp2dZW4',
#       'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg.9mPmkaGJjgH9msQiorg0qc',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '@Achim Take home exams are already banned in many universities for that exact reason. Even before AIs you could simply hire someone to do it for you. It was such a problem that actual companies were created for that purpose: you paid them some amount of money and then their staff do the assignments you give them for you',
#        'textOriginal': '@Achim Take home exams are already banned in many universities for that exact reason. Even before AIs you could simply hire someone to do it for you. It was such a problem that actual companies were created for that purpose: you paid them some amount of money and then their staff do the assignments you give them for you',
#        'parentId': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#        'authorDisplayName': 'Alain Térieur',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJU1nrOSdKajm_yz12FCtu4F4_CJpeQPlsFRH-qojw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCA479uCl1ZtRNPwgemlO4Iw',
#        'authorChannelId': {'value': 'UCA479uCl1ZtRNPwgemlO4Iw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2023-03-05T11:07:56Z',
#        'updatedAt': '2023-03-05T11:13:35Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '5ZWdfLSG3a5EHD-zjHmetjd7eQU',
#       'id': 'UgxU5Fx5E23NX5UMjHd4AaABAg.9mPmkaGJjgH9mgBNYUciDX',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'textOriginal': 'Yes and I am happy that I will retire in six years or so. I recently heard a discussion among people from our local college, and they said non-supervised exams (take-home exams, longer papers, etc.) are about to be banned because we will never be able to tell who wrote the paper. What a pity.',
#        'parentId': 'UgxU5Fx5E23NX5UMjHd4AaABAg',
#        'authorDisplayName': 'Achim',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJX8ZoD8C59k7SSPqvQ3LDvKhV5tVqqmPXoNow=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCnGyrSPsI5iLWu_nrJ7kqgA',
#        'authorChannelId': {'value': 'UCnGyrSPsI5iLWu_nrJ7kqgA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 7,
#        'publishedAt': '2023-02-28T17:02:56Z',
#        'updatedAt': '2023-02-28T17:02:56Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '--zu3gzJd-x6kz5y9geHOUYznD4',
#    'id': 'UgycKzB5AfRlVlTZxbl4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-hTAj8MzHQegpFGRFkWK8bE1FcI',
#      'id': 'UgycKzB5AfRlVlTZxbl4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'Fifty years ago I remember occasionally seeing in movies and on TV actors moving through a museum and there would be artists with their easels set up in front of paintings, I assume they would learning how to duplicate the techniques, so this is not just AIs learning this way.',
#       'textOriginal': 'Fifty years ago I remember occasionally seeing in movies and on TV actors moving through a museum and there would be artists with their easels set up in front of paintings, I assume they would learning how to duplicate the techniques, so this is not just AIs learning this way.',
#       'authorDisplayName': 'Shorttimer',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUFjQzzRKdEg-ERhEwcmeyUkMq0jSFsV51zs2O40g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8tH79FRBScumc1UYkOfIkA',
#       'authorChannelId': {'value': 'UC8tH79FRBScumc1UYkOfIkA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-03-04T18:27:47Z',
#       'updatedAt': '2023-03-04T18:27:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LtqdDc2AEpfWnC8aXNx076Mbnok',
#    'id': 'Ugw-ho5yiyIBC1rJ5Mt4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3QSMTbbXQq8xopIIzXbuGgiI_Po',
#      'id': 'Ugw-ho5yiyIBC1rJ5Mt4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I remember having problems like this, but I found the solution. In fact, it&#39;s right behind you in this video.',
#       'textOriginal': "I remember having problems like this, but I found the solution. In fact, it's right behind you in this video.",
#       'authorDisplayName': 'irøn',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/zpNflpSSbjbBeUPQAjp_VP5UVIBQK4xOWyk5ATQDas3zEyYnY7vLcLDAj1C9aUtZZbM-9cc65A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCBdrJAtog_34NKvrcUZIRIg',
#       'authorChannelId': {'value': 'UCBdrJAtog_34NKvrcUZIRIg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-03-02T22:45:48Z',
#       'updatedAt': '2023-03-02T22:45:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fvGX2LUiyTRkZ_GnUP2byrfEUSs',
#    'id': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M2FOMjm07QcvIRiAd2qtl8iK3No',
#      'id': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#      'snippet': {'videoId': 'jPhJbKBuNnA',
#       'textDisplay': 'I remember Napster..... I worked there.',
#       'textOriginal': 'I remember Napster..... I worked there.',
#       'authorDisplayName': 'Scott Manley',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUYOLa4BI5lN6x8gsbfdo-oDqh5EriP93mgvPdu1Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCxzC4EngIsMrPmbm6Nxvb-A',
#       'authorChannelId': {'value': 'UCxzC4EngIsMrPmbm6Nxvb-A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3619,
#       'publishedAt': '2023-02-13T17:12:59Z',
#       'updatedAt': '2023-02-13T17:12:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 56,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'CTDr_c13bZ3twscyhZMDwVPBZcM',
#       'id': 'UgxelJ1eP46s8bKpMpB4AaABAg.9m4_b1jhSJ69muu4CXHNha',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Fire Bad!  Fire Bad!',
#        'textOriginal': 'Fire Bad!  Fire Bad!',
#        'parentId': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#        'authorDisplayName': 'Opterongeek',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVt4yeJJW8np-XYDvUBkAz5-TYroFVAy0eH8A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCvyTrDkATleMxCT8tW2NP_Q',
#        'authorChannelId': {'value': 'UCvyTrDkATleMxCT8tW2NP_Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-06T10:11:37Z',
#        'updatedAt': '2023-03-06T10:11:37Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'JOqnjDlNf9zO3K0-m6j0wIw2BTM',
#       'id': 'UgxelJ1eP46s8bKpMpB4AaABAg.9m4_b1jhSJ69moIT8RvL5C',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Well, there&#39;s something I didn&#39;t know and never expected. I was definitely wrong about what came next here.',
#        'textOriginal': "Well, there's something I didn't know and never expected. I was definitely wrong about what came next here.",
#        'parentId': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#        'authorDisplayName': 'Warmachine',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUd_2GX57DA3YdGRrdZj5ZMF4CBFLIsuu9yAdfM=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UC9RbWAUVFlBj1rmoZcUfKMg',
#        'authorChannelId': {'value': 'UC9RbWAUVFlBj1rmoZcUfKMg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-03T20:38:48Z',
#        'updatedAt': '2023-03-03T20:38:48Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '_LrZBo_PzJOAFABATUinT1d0p6k',
#       'id': 'UgxelJ1eP46s8bKpMpB4AaABAg.9m4_b1jhSJ69ml-_F11VgF',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Thank you for your service! I loved Napster.',
#        'textOriginal': 'Thank you for your service! I loved Napster.',
#        'parentId': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#        'authorDisplayName': 'HosenUltraViolento',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVOp6a-6YcmHleZudR24LCiIMeqkUM_ja81Mw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCAI7Lg7knTNpFIawEVsc0FQ',
#        'authorChannelId': {'value': 'UCAI7Lg7knTNpFIawEVsc0FQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-03-02T13:56:01Z',
#        'updatedAt': '2023-03-02T13:56:01Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'EXPcZj2MvFQ_t-IZ4wFVK68mbUg',
#       'id': 'UgxelJ1eP46s8bKpMpB4AaABAg.9m4_b1jhSJ69mdKVaSVsUJ',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': '&quot;So anyway I decided to hide from our new robot overlords in NZ..&quot; Great perspective!',
#        'textOriginal': '"So anyway I decided to hide from our new robot overlords in NZ.." Great perspective!',
#        'parentId': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#        'authorDisplayName': 'stevydoos',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVqLmz9ReQsh9ogpauBMwCfYCx8mTp367SQMw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCGp0WYmFjHzZ1S81lI_cxnQ',
#        'authorChannelId': {'value': 'UCGp0WYmFjHzZ1S81lI_cxnQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-27T14:24:57Z',
#        'updatedAt': '2023-02-27T14:24:57Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'pACDk6eZcWre4OoE5sP1qXAx780',
#       'id': 'UgxelJ1eP46s8bKpMpB4AaABAg.9m4_b1jhSJ69mKpddZ7Rlh',
#       'snippet': {'videoId': 'jPhJbKBuNnA',
#        'textDisplay': 'Beam me up Scottie',
#        'textOriginal': 'Beam me up Scottie',
#        'parentId': 'UgxelJ1eP46s8bKpMpB4AaABAg',
#        'authorDisplayName': 'Peterkjaerhtc Larsen',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVxHccnMJFA66Y-hqtGJR_mxX_hCEfIjKdodw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCsI-rMxBtv7wKFrdQNw2Gfw',
#        'authorChannelId': {'value': 'UCsI-rMxBtv7wKFrdQNw2Gfw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2023-02-20T00:41:00Z',
#        'updatedAt': '2023-02-20T00:41:00Z'}}]}}]}

# %%
len(response_comments['items'][0]['replies']['comments'])
# Out:
# 5

# %%
response_comments['items'][0]['replies']['comments']
# Out:
# [{'kind': 'youtube#comment',
#   'etag': 'iy8SW9Nh2lhULpZ0L1N5mwuz01I',
#   'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mdk9CUTT1B',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#    'textOriginal': 'Me too - I call it tech-rap    Not to be confused with tech crap',
#    'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'authorDisplayName': 'dave bento',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWuKBEeloJWn9qyihl91FmBPELGc_HMlKHrYA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCWloOVPTGKatWGnQ8Y1xSMw',
#    'authorChannelId': {'value': 'UCWloOVPTGKatWGnQ8Y1xSMw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2023-02-27T18:17:50Z',
#    'updatedAt': '2023-02-27T18:17:50Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'PAsFcesPIqaVpQEKgpFAzcZxZLc',
#   'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mSCn6_xlby',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': '\u200b@Senk Ju silenced him easily😂',
#    'textOriginal': '\u200b@Senk Ju silenced him easily😂',
#    'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'authorDisplayName': 'ilikefish',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/eeNJUft4-VIGopnmUTEF9CIk5aPYUZ9lO9zy7ehVRwqV2rU48zysEOrQg1SME99ZhZK8bopR=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCck_-AOidzq6l6ahgAB4Lhw',
#    'authorChannelId': {'value': 'UCck_-AOidzq6l6ahgAB4Lhw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1,
#    'publishedAt': '2023-02-22T21:26:42Z',
#    'updatedAt': '2023-02-22T21:26:42Z'}},
#  {'kind': 'youtube#comment',
#   'etag': '4_mc-YDtru8hJ3Ig37oCES23y8E',
#   'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mQOr66qurE',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': '@Mark Koetsier No more than you or I ..',
#    'textOriginal': '@Mark Koetsier No more than you or I ..',
#    'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'authorDisplayName': 'blucat4',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/5TlLhyJYqELPzlpo9WcGF5WSMqUEgw5wmiqD5N4-dcKvKEVLG3r9737g2zMCse8hmOeYfQzu=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCmkhEsnWvK1TIcSJ0UlaGbg',
#    'authorChannelId': {'value': 'UCmkhEsnWvK1TIcSJ0UlaGbg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2023-02-22T04:33:37Z',
#    'updatedAt': '2023-02-22T04:33:37Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'DpQlpgeS-DtZNMs67SW6aGxMwCQ',
#   'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mPkVG_WNnU',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': 'Tom is a bot.',
#    'textOriginal': 'Tom is a bot.',
#    'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'authorDisplayName': 'Mark Koetsier',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVy6_TL3RimhGIwWNHnLyQovLSbcr5v0MuCsg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCNIEj7-_Qx5OH3dEeWlBJWQ',
#    'authorChannelId': {'value': 'UCNIEj7-_Qx5OH3dEeWlBJWQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1,
#    'publishedAt': '2023-02-21T22:32:14Z',
#    'updatedAt': '2023-02-21T22:32:14Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'G1_AgiGTw8uXFzKW7UWbNyihEuY',
#   'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mNpSGX4Ov6',
#   'snippet': {'videoId': 'jPhJbKBuNnA',
#    'textDisplay': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#    'textOriginal': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#    'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#    'authorDisplayName': 'Create A. Googleaccount',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZ_JPg7xHQ_i7F8TXeiHyMpffOusPB_25fknHN1EXqlv1G2O5MPkWnvYBK4FBC=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UChteANI-UpaQfvWDNOPDD-w',
#    'authorChannelId': {'value': 'UChteANI-UpaQfvWDNOPDD-w'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2023-02-21T04:37:02Z',
#    'updatedAt': '2023-02-21T04:37:02Z'}}]

# %%
response_comments['items'][0]['replies']['comments'][4]
# Out:
# {'kind': 'youtube#comment',
#  'etag': 'G1_AgiGTw8uXFzKW7UWbNyihEuY',
#  'id': 'UgxIZQ8lca0JURrNUh54AaABAg.9m6ds6thDwO9mNpSGX4Ov6',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'textDisplay': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#   'textOriginal': '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#   'parentId': 'UgxIZQ8lca0JURrNUh54AaABAg',
#   'authorDisplayName': 'Create A. Googleaccount',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVZ_JPg7xHQ_i7F8TXeiHyMpffOusPB_25fknHN1EXqlv1G2O5MPkWnvYBK4FBC=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelUrl': 'http://www.youtube.com/channel/UChteANI-UpaQfvWDNOPDD-w',
#   'authorChannelId': {'value': 'UChteANI-UpaQfvWDNOPDD-w'},
#   'canRate': True,
#   'viewerRating': 'none',
#   'likeCount': 0,
#   'publishedAt': '2023-02-21T04:37:02Z',
#   'updatedAt': '2023-02-21T04:37:02Z'}}

# %%
replies_response_snippet = response_comments['items'][0]['replies']['comments'][0]['snippet']

replies_videoId = replies_response_snippet['videoId']
replies_comment = replies_response_snippet['textOriginal']
replies_author = replies_response_snippet['authorDisplayName']
replies_authorChannelUrl = replies_response_snippet['authorChannelUrl']
replies_likeCount = replies_response_snippet['likeCount']
replies_publishedAt = replies_response_snippet['publishedAt']

# %%
replies_comment
# Out:
# 'Me too - I call it tech-rap    Not to be confused with tech crap'

# %%
videoId = []
comment = []
author = []
authorChannelUrl = []
likeCount = []
publishedAt = []
replies_videoId = []
replies_comment = []
replies_author = []
replies_authorChannelUrl = []
replies_likeCount = []
replies_publishedAt = []

# %%
list_videos_id

# %%
request_comments = youtube.commentThreads().list(
    part="snippet, replies",
    order="relevance",
    videoId=list_videos_id[0], 
    )
response_comments = request_comments.execute()

# %%
nextPageToken = 0
for i in range(2):
    nextPageToken = response_comments['nextPageToken']
    response_count = len(response_comments['items'])
    for j in range(response_count):
        response_snippet = response_comments['items'][j]['snippet']['topLevelComment']['snippet']
        videoId.append(response_snippet['videoId'])
        comment.append(response_snippet['textOriginal'])
        author.append(response_snippet['authorDisplayName'])
        authorChannelUrl.append(response_snippet['authorChannelUrl'])
        likeCount.append(response_snippet['likeCount'])
        publishedAt.append(response_snippet['publishedAt'])
        if "replies" in response_comments['items'][2]:
            number_replies = len(response_comments['items'][j]['replies']['comments'])
            print(number_replies)
            for k in range(number_replies):
                replies_response_snippet = response_comments['items'][j]['replies']['comments'][k]['snippet']
                replies_videoId.append(replies_response_snippet['videoId'])
                replies_comment.append(replies_response_snippet['textOriginal'])
                replies_author.append(replies_response_snippet['authorDisplayName'])
                replies_authorChannelUrl.append(replies_response_snippet['authorChannelUrl'])
                replies_likeCount.append(replies_response_snippet['likeCount'])
                replies_publishedAt.append(replies_response_snippet['publishedAt'])
    request_comments = youtube.commentThreads().list(part="snippet, replies", order="relevance", videoId=list_videos_id[0], pageToken= nextPageToken)
    response_comments = request_comments.execute()

# %%
replies_comment
# Out:
# ['Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders',
#  'Me too - I call it tech-rap    Not to be confused with tech crap',
#  '\u200b@Senk Ju silenced him easily😂',
#  '@Mark Koetsier No more than you or I ..',
#  'Tom is a bot.',
#  '@Burt Sidefish Scripted? LMAO, Like any Good Military Planted Intelligence Operative',
#  "@Peppermint Gal Why does he think the potential is limited? I'm asking because I also work in a closely related industry, and I as well as most of my colleagues think its potential is just as Tom described. I don't see any reason to be sceptical about the emergence of AGI within the next decade.",
#  "\u200b@Peppermint Gal\nWrong. The current danger of chat GPT isn't just writing code on its own. The main danger isn't allows one trained developer to replace five untrained developers because of how dramatically it increases your coding speed.\n\nThis will lead to massive layoffs in the tech industry. The only question is when.",
#  '@voidhawk79 I mean, its tech ENTHUSIASTS who think this stuff is going to have that big an effect on the world, that and tech unsavvy journalists. I know someone who is not only tech savvy, but literally programs this stuff for a living, and his opinion of the technology is a lot more moderate in nature. Its really not that special, its a kind of lossy data compression and chimerization. Its like if winzip stored files as strings of calculus operations.',
#  "I'm not actually sure about that. There's been a lot of sensationalism around this issue. I know someone who actually works *developing* this software and its potential is... a lot more limited than people think. People should wait for the analogue computer to come back before getting emotional about this.",
#  "@voidhawk79 You are also under the spell. Snap out of it.\n\nit's programming. it predicts and responds as it is programmed to do. Nothing more.\n\nIt may be some sophistcated programming, it may reference of gigundous library of info (of course it does, as a large part of it's purpose is to gather data and grow that library), but in the end it's nothing more than programming. \n\nThe general public is a combination of uninterested and also under the spell.\n\nThe future is dark if enough people buy this BS as it's being advertised. The more people who buy it, the darker it is like to be.",
#  'He didn’t say anything. Waste of time',
#  '@Wuptidooalways have been.. 😐',
#  'When i see a guy type geta onstead of its you know gets a illiterate person',
#  "This was deep? He's just saying what everyone else is saying. You could go snorkelling at this level.",
#  'and mo cap',
#  "@User_guy Maybe. If that's the case, all it'll do is most likely make private, proprietary languages more commonplace. Which isn't a bad thing if security becomes a real concern.",
#  'I tried to use ChatGPT suggested hotkey scripts for setting Night Mode on Windows 10 but that scripts did not work!',
#  'Dream come true for hackers?',
#  'It literally knows how to code in the strangest programming languages, which is really cool.',
#  "Oh?  Is that what I've been suffering for the past nearly decade now?  Fantastic.",
#  'i am a 3D art student , and i can already feel it.\n\nMy futurer is focked even before starting out',
#  "no, it's a fear of how big brother will use it to kill me somehow",
#  '@Walter Stuart it always has been a prime skill... and ideas alone are never enough, since we all have ideas... i agree its how you present/describe it, which take the real knowledge and real skill. thats why most people using image generator  are will stay subpar creator. because they dont have the primary skill of putting your idea in image, that makes you someone experimented enough to recognize what is a good idea or what isnt.\nat least its how it is the way people are using image generator right now.',
#  'I\'m more concerned  that "anyone" who learns how to "use" the system (chatgtp) will be (potentially) deemed as "competent and confident" in an area of study, for instance, which that individual has not studied. In the old days when writing a paper ,for instance, this was called plagiarism. How is an educator, or employer, going to tell the difference? "Beware of virtues not earned"',
#  'I agree, ideas and imagination will be the new prime skill. Yet that takes knowledge and practice. Knowing how to describe your idea.',
#  "@David I remember my elementary school's teacher workroom being as smoky as a pool hall",
#  "@David And once in a while some teacher came and chased away the under 16's who were caught smoking.",
#  '@David I laughed at that but then realized that so did we.',
#  'When I was in high school they had a designated smoking area for the kids.',
#  "I have a Gmail account because of my phone and YT. I rarely check it.\nI have a Yahoo account that has folders.\nI don't really use email when communicating with people.",
#  'Me too! I hate it. The Org OCD in me can’t function without neat folders']

# %%
len(response_comments['items'][2])
# Out:
# 4

# %%
len(response_comments['items'][0])
# Out:
# 4

# %%
if "replies" in response_comments['items'][2]:
    print("false")
# Out:
# false

# %%
response_comments['items'][2]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'y007Be1ms5RsIORBsc05UgbPSDo',
#  'id': 'UgwlN7xO7D5tZriSkzB4AaABAg',
#  'snippet': {'videoId': 'jPhJbKBuNnA',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'vhN19Psrq_6npdb3X8afTyf1RSY',
#    'id': 'UgwlN7xO7D5tZriSkzB4AaABAg',
#    'snippet': {'videoId': 'jPhJbKBuNnA',
#     'textDisplay': 'I rewrite everything I need to flatten libraries written by others, not on my design and changing without notice and you are in a constant clean up. Use email, phone to set up meetings in person you are right.',
#     'textOriginal': 'I rewrite everything I need to flatten libraries written by others, not on my design and changing without notice and you are in a constant clean up. Use email, phone to set up meetings in person you are right.',
#     'authorDisplayName': 'Lutz Filor',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWYJkeGxxqizDjFaNcOF2GEsfvlr2_muttabFtL3VAfOLSLSMpGUeSZsZYSNrAw=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCDvbwZPd__zx5aauUdn_DRg',
#     'authorChannelId': {'value': 'UCDvbwZPd__zx5aauUdn_DRg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2023-03-06T16:57:27Z',
#     'updatedAt': '2023-03-06T16:57:27Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
import pandas as pd

columns=['videoId','comment','author', 'authorChannelUrl', 'likeCount', 'publishedAt', 'replies_videoId', 'replies_comment',
                            'replies_author', 'replies_authorChannelUrl', 'replies_likeCount', 'replies_publishedAt']
df = pd.DataFrame(list(zip(videoId, comment, author, authorChannelUrl, likeCount, publishedAt, replies_videoId, replies_comment,
                            replies_author, replies_authorChannelUrl, replies_likeCount, replies_publishedAt)),
                 columns=columns )
print(df)
# Out:
#           videoId                                            comment  \
# 0     jPhJbKBuNnA  It's an opinion piece this week! Been a while ...
# 1     jPhJbKBuNnA  “I've come up with a set of rules that describ...
# 2     jPhJbKBuNnA  I was genuinely expecting and terrified that t...
# 3     jPhJbKBuNnA  “Surprise is just a fancy word for being wrong...
# 4     jPhJbKBuNnA  My aunt worked for AT&T in the 80s.  I remembe...
# ...           ...                                                ...
# 4993  zNRvAMJOfAI                                    小Lin 的廣告真的是最實用的
# 4994  zNRvAMJOfAI                  还有一个问题值得思考，小lin这么优秀的人，需要咋样的人才能配得上
# 4995  zNRvAMJOfAI                                           這期太棒了!!!
# 4996  zNRvAMJOfAI  我看到一半就在想小Lin回不會就落下了GPT其實是有偏頗的這件事,就開始提人工反饋.\n沒錯...
# 4997  zNRvAMJOfAI    突然感觉有时候ChatGPT有点像一类印度朋友😂不管答案对不对，总之能说敢说，说出来特别笃定😂
#
#                 author                                   authorChannelUrl  \
# 0            Tom Scott  http://www.youtube.com/channel/UCBa659QWEk1AI4...
# 1     SmallAdvantages   http://www.youtube.com/channel/UCskEPRzGlsYHs_...
# 2          SkyKnight34  http://www.youtube.com/channel/UCK7tlnWujz3ZAV...
# 3       Brandon Miller  http://www.youtube.com/channel/UCOf6tUaLD39bn0...
# 4             Festyguy  http://www.youtube.com/channel/UCcM-vnGmAHfknb...
# ...                ...                                                ...
# 4993       Joshua Wang  http://www.youtube.com/channel/UC_Fk1-bL4xALBm...
# 4994          crypto梧桐  http://www.youtube.com/channel/UCVW32HVaK3nqXG...
# 4995               j c  http://www.youtube.com/channel/UC6nDzG8rW8y6cb...
# 4996         Kevin Lee  http://www.youtube.com/channel/UClhBDTZdtjjJEV...
# 4997          NY Huang  http://www.youtube.com/channel/UCVgdKLfDXvqlxr...
#
#       likeCount           publishedAt replies_videoId  \
# 0          9081  2023-02-08T05:47:56Z     jPhJbKBuNnA
# 1          9736  2023-02-19T07:16:30Z     jPhJbKBuNnA
# 2          1812  2023-02-23T20:36:15Z     jPhJbKBuNnA
# 3          1070  2023-02-21T17:14:50Z     jPhJbKBuNnA
# 4           906  2023-02-23T14:29:36Z     jPhJbKBuNnA
# ...         ...                   ...             ...
# 4993          1  2023-03-02T05:52:28Z     zNRvAMJOfAI
# 4994          1  2023-02-26T09:21:49Z     zNRvAMJOfAI
# 4995          1  2023-02-26T07:35:04Z     zNRvAMJOfAI
# 4996         19  2023-02-26T04:29:46Z     zNRvAMJOfAI
# 4997          0  2023-03-01T04:46:44Z     zNRvAMJOfAI
#
#                                         replies_comment   replies_author  \
# 0     Tom, I like your analyses and opinions, and I ...      HuntingTarg
# 1                           Playing runescape sense 99.       Lone Rider
# 2                                             Tom scott     Righteous 2k
# 3     @Timo Pint All of the VPN providers sell your ...    Alberta Wheat
# 4                                  Nord sells Data.....        Timo Pint
# ...                                                 ...              ...
# 4993                                  @Jack ABC 那是不可能的。       zhikun sun
# 4994                            你还是关注的博主水平太低，林亦早就说得很清楚了     Series Black
# 4995  @himeka s 比较难 老高讲的大部分人是休闲看 小Lin我不确定 但我都是抱着学东西看...        Elliot W.
# 4996              @himeka s 两个我一样会继续看😍，老高偏哲学点，小lin偏完整讯息       Henry Thew
# 4997                      小Lin偷偷告诉你，这里面其实有一半是ChatGPT写的😏  中國既不中華也不人民更非共和國
#
#                                replies_authorChannelUrl  replies_likeCount  \
# 0     http://www.youtube.com/channel/UCXBX0IVKvfhgEX...                  1
# 1     http://www.youtube.com/channel/UC5FqI13wkZKe_A...                  0
# 2     http://www.youtube.com/channel/UC7jOomH47gzA9T...                  0
# 3     http://www.youtube.com/channel/UCoEFFOsmzcKLMU...                  0
# 4     http://www.youtube.com/channel/UCKvMTb60Hs6QIy...                  0
# ...                                                 ...                ...
# 4993  http://www.youtube.com/channel/UC5YL0tuT5JJjG8...                  0
# 4994  http://www.youtube.com/channel/UCDYHvIJtnccoov...                  0
# 4995  http://www.youtube.com/channel/UCL_983th7__ABF...                  0
# 4996  http://www.youtube.com/channel/UCIUlYtwrj26EOD...                  2
# 4997  http://www.youtube.com/channel/UC4FB3cwwNWop46...                  0
#
#        replies_publishedAt
# 0     2023-03-06T04:08:33Z
# 1     2023-03-05T14:00:19Z
# 2     2023-03-02T23:44:35Z
# 3     2023-02-28T13:40:33Z
# 4     2023-02-28T12:52:55Z
# ...                    ...
# 4993  2023-03-03T16:15:19Z
# 4994  2023-03-03T00:47:24Z
# 4995  2023-02-26T14:46:28Z
# 4996  2023-02-26T10:49:08Z
# 4997  2023-02-26T06:05:24Z
#
# [4998 rows x 12 columns]

# %%
df.to_excel(r'D:\maxim\Documents\Projects\CollecteDesDonnees\Youtube\YoutubeComments.xlsx', index=False)

# %%
import time

# %%
videoId = []
comment = []
author = []
authorChannelUrl = []
likeCount = []
publishedAt = []
replies_videoId = []
replies_comment = []
replies_author = []
replies_authorChannelUrl = []
replies_likeCount = []
replies_publishedAt = []

# %%
for id in list_videos_id:
    request_comments = youtube.commentThreads().list(
        part="snippet, replies",
        order="relevance",
        videoId= id, 
        )
    response_comments = request_comments.execute()

    nextPageToken = 0
    for i in range(5):
        nextPageToken = response_comments['nextPageToken']
        response_count = len(response_comments['items'])
        for j in range(response_count):
            response_snippet = response_comments['items'][j]['snippet']['topLevelComment']['snippet']
            videoId.append(response_snippet['videoId'])
            comment.append(response_snippet['textOriginal'])
            author.append(response_snippet['authorDisplayName'])
            authorChannelUrl.append(response_snippet['authorChannelUrl'])
            likeCount.append(response_snippet['likeCount'])
            publishedAt.append(response_snippet['publishedAt'])
            if "replies" in response_comments['items'][j]:
                number_replies = len(response_comments['items'][j]['replies']['comments'])
                #time.sleep(3)
                for k in range(number_replies):
                    replies_response_snippet = response_comments['items'][j]['replies']['comments'][k]['snippet']
                    replies_videoId.append(replies_response_snippet['videoId'])
                    replies_comment.append(replies_response_snippet['textOriginal'])
                    replies_author.append(replies_response_snippet['authorDisplayName'])
                    replies_authorChannelUrl.append(replies_response_snippet['authorChannelUrl'])
                    replies_likeCount.append(replies_response_snippet['likeCount'])
                    replies_publishedAt.append(replies_response_snippet['publishedAt'])
        #time.sleep(5)
        request_comments = youtube.commentThreads().list(part="snippet, replies", order="relevance", 
                                                         videoId=id, pageToken= nextPageToken)
        response_comments = request_comments.execute()
